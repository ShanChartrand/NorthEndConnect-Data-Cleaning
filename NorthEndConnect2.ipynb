# %% [markdown]
# <a href="https://colab.research.google.com/github/InternetSocietyManitobaChapter/JupyterNotebook_NorthEndConnect/blob/main/NorthEndConnect2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

# %%
# Read the North End Connect data file

northEndConnect = pd.read_csv("northendconnect5.csv")

# %%
# Display a feww rows of the data

display(northEndConnect.head(10))
# Out:
#    TEST ID TEST DATE / UTC HOUR  GEO LATITUDE  GEO LONGITUDE  DOWNLOAD SPEED  \
# 0      NaN                  NaN           NaN            NaN             NaN
# 1    261.0      5/23/2015 10:00     49.869556     -97.296739           16.22
# 2      NaN                  NaN           NaN            NaN             NaN
# 3    284.0      5/20/2015 10:01     49.852738     -97.270058           14.89
# 4      NaN                  NaN           NaN            NaN             NaN
# 5    622.0      5/19/2015 10:00     49.887575     -97.140091            9.89
# 6      NaN                  NaN           NaN            NaN             NaN
# 7    701.0      5/24/2015 10:00     49.814284     -97.160235           10.62
# 8      NaN                  NaN           NaN            NaN             NaN
# 9    707.0      5/19/2015 10:00     49.882706     -97.161829            9.89
#
#    UPLOAD SPEED  JITTER  LATENCY  PACKET LOSS MOBILE TEST  ...  \
# 0           NaN     NaN      NaN          NaN         NaN  ...
# 1          2.79     NaN      NaN          NaN       False  ...
# 2           NaN     NaN      NaN          NaN         NaN  ...
# 3          2.74     NaN      NaN          NaN       False  ...
# 4           NaN     NaN      NaN          NaN         NaN  ...
# 5          5.64     NaN      NaN          NaN       False  ...
# 6           NaN     NaN      NaN          NaN         NaN  ...
# 7          2.09     NaN      NaN          NaN       False  ...
# 8           NaN     NaN      NaN          NaN         NaN  ...
# 9          2.60     NaN      NaN          NaN       False  ...
#
#   CONTRACTED UPLOAD SPEED CONTRACTED DATA CAP CONTRACTED MONTHLY COST  \
# 0                     NaN                 NaN                     NaN
# 1                     NaN                 NaN                     NaN
# 2                     NaN                 NaN                     NaN
# 3                     NaN                 NaN                     NaN
# 4                     NaN                 NaN                     NaN
# 5                     NaN                 NaN                     NaN
# 6                     NaN                 NaN                     NaN
# 7                     NaN                 NaN                     NaN
# 8                     NaN                 NaN                     NaN
# 9                     NaN                 NaN                     NaN
#
#   SERVICE TYPE USER SATISFACTION CONNECTION TYPE USER COMMENTS  \
# 0          NaN               NaN             NaN           NaN
# 1          NaN               NaN             NaN           NaN
# 2          NaN               NaN             NaN           NaN
# 3          NaN               NaN             NaN           NaN
# 4          NaN               NaN             NaN           NaN
# 5          NaN               NaN             NaN           NaN
# 6          NaN               NaN             NaN           NaN
# 7          NaN               NaN             NaN           NaN
# 8          NaN               NaN             NaN           NaN
# 9          NaN               NaN             NaN           NaN
#
#   HEATMAP_MUNICIPALITY HEATMAP_CENSUS_TRACTS HEATMAP_PROJECT_AREA
# 0                  NaN                   NaN                  NaN
# 1             Winnipeg            6020537.02                  NaN
# 2                  NaN                   NaN                  NaN
# 3             Winnipeg            6020522.02                  NaN
# 4                  NaN                   NaN                  NaN
# 5             Winnipeg            6020014.00                  NaN
# 6                  NaN                   NaN                  NaN
# 7             Winnipeg            6020501.02                  NaN
# 8                  NaN                   NaN                  NaN
# 9             Winnipeg            6020016.00                  NaN
#
# [10 rows x 31 columns]

# %%
northEndConnect.shape
# Out:
# (37888, 31)

# %%
# From the output above, it is seen that ENTIRELY blank rows occur at even number indexes
# These ENTIRELY BLANK rows will be contributing to the number of rows of data in the file.
# Besides blank rows are indicative of missing data so need to be removed to avoid errors.

# Remove these ENTIRELY blank rows, and save the changes in the data frame

northEndConnect_RemoveALLBlankRows = northEndConnect.dropna(how = 'all')

# %%
northEndConnect_RemoveALLBlankRows
# Out:
#          TEST ID TEST DATE / UTC HOUR  GEO LATITUDE  GEO LONGITUDE  \
# 1          261.0      5/23/2015 10:00     49.869556     -97.296739
# 3          284.0      5/20/2015 10:01     49.852738     -97.270058
# 5          622.0      5/19/2015 10:00     49.887575     -97.140091
# 7          701.0      5/24/2015 10:00     49.814284     -97.160235
# 9          707.0      5/19/2015 10:00     49.882706     -97.161829
# ...          ...                  ...           ...            ...
# 37879  1616011.0      12/11/2022 0:28     49.829862     -97.185759
# 37881  1616040.0      12/11/2022 1:28     49.829862     -97.185759
# 37883  1616060.0      12/11/2022 2:28     49.829862     -97.185759
# 37885  1616076.0      12/11/2022 3:28     49.829862     -97.185759
# 37887  1616089.0      12/11/2022 4:28     49.829862     -97.185759
#
#        DOWNLOAD SPEED  UPLOAD SPEED  JITTER  LATENCY  PACKET LOSS MOBILE TEST  \
# 1               16.22          2.79     NaN      NaN          NaN       False
# 3               14.89          2.74     NaN      NaN          NaN       False
# 5                9.89          5.64     NaN      NaN          NaN       False
# 7               10.62          2.09     NaN      NaN          NaN       False
# 9                9.89          2.60     NaN      NaN          NaN       False
# ...               ...           ...     ...      ...          ...         ...
# 37879           81.77         14.35    0.15    60.86        12.27       False
# 37881           84.76         14.22    0.24    52.72        11.52       False
# 37883           84.05         14.73    0.21    52.73        11.74       False
# 37885           85.74         13.76    0.23    51.39        11.09       False
# 37887           85.45         14.74    0.30    51.37        11.04       False
#
#        ... CONTRACTED UPLOAD SPEED CONTRACTED DATA CAP  \
# 1      ...                     NaN                 NaN
# 3      ...                     NaN                 NaN
# 5      ...                     NaN                 NaN
# 7      ...                     NaN                 NaN
# 9      ...                     NaN                 NaN
# ...    ...                     ...                 ...
# 37879  ...                      10           Unlimited
# 37881  ...                      10           Unlimited
# 37883  ...                      10           Unlimited
# 37885  ...                      10           Unlimited
# 37887  ...                      10           Unlimited
#
#       CONTRACTED MONTHLY COST SERVICE TYPE USER SATISFACTION CONNECTION TYPE  \
# 1                         NaN          NaN               NaN             NaN
# 3                         NaN          NaN               NaN             NaN
# 5                         NaN          NaN               NaN             NaN
# 7                         NaN          NaN               NaN             NaN
# 9                         NaN          NaN               NaN             NaN
# ...                       ...          ...               ...             ...
# 37879                     100         Home               4.0             DSL
# 37881                     100         Home               4.0             DSL
# 37883                     100         Home               4.0             DSL
# 37885                     100         Home               4.0             DSL
# 37887                     100         Home               4.0             DSL
#
#                              USER COMMENTS HEATMAP_MUNICIPALITY  \
# 1                                      NaN             Winnipeg
# 3                                      NaN             Winnipeg
# 5                                      NaN             Winnipeg
# 7                                      NaN             Winnipeg
# 9                                      NaN             Winnipeg
# ...                                    ...                  ...
# 37879  internet price promotion paying $40             Winnipeg
# 37881  internet price promotion paying $40             Winnipeg
# 37883  internet price promotion paying $40             Winnipeg
# 37885  internet price promotion paying $40             Winnipeg
# 37887  internet price promotion paying $40             Winnipeg
#
#       HEATMAP_CENSUS_TRACTS HEATMAP_PROJECT_AREA
# 1                6020537.02                  NaN
# 3                6020522.02                  NaN
# 5                6020014.00                  NaN
# 7                6020501.02                  NaN
# 9                6020016.00                  NaN
# ...                     ...                  ...
# 37879            6020510.06                  NaN
# 37881            6020510.06                  NaN
# 37883            6020510.06                  NaN
# 37885            6020510.06                  NaN
# 37887            6020510.06                  NaN
#
# [18944 rows x 31 columns]

# %%
# Reset the index of the data set and save the change in place

northEndConnect_RemoveALLBlankRows.reset_index(inplace = True)

# %%
northEndConnect_RemoveALLBlankRows
# Out:
#        index    TEST ID TEST DATE / UTC HOUR  GEO LATITUDE  GEO LONGITUDE  \
# 0          1      261.0      5/23/2015 10:00     49.869556     -97.296739
# 1          3      284.0      5/20/2015 10:01     49.852738     -97.270058
# 2          5      622.0      5/19/2015 10:00     49.887575     -97.140091
# 3          7      701.0      5/24/2015 10:00     49.814284     -97.160235
# 4          9      707.0      5/19/2015 10:00     49.882706     -97.161829
# ...      ...        ...                  ...           ...            ...
# 18939  37879  1616011.0      12/11/2022 0:28     49.829862     -97.185759
# 18940  37881  1616040.0      12/11/2022 1:28     49.829862     -97.185759
# 18941  37883  1616060.0      12/11/2022 2:28     49.829862     -97.185759
# 18942  37885  1616076.0      12/11/2022 3:28     49.829862     -97.185759
# 18943  37887  1616089.0      12/11/2022 4:28     49.829862     -97.185759
#
#        DOWNLOAD SPEED  UPLOAD SPEED  JITTER  LATENCY  PACKET LOSS  ...  \
# 0               16.22          2.79     NaN      NaN          NaN  ...
# 1               14.89          2.74     NaN      NaN          NaN  ...
# 2                9.89          5.64     NaN      NaN          NaN  ...
# 3               10.62          2.09     NaN      NaN          NaN  ...
# 4                9.89          2.60     NaN      NaN          NaN  ...
# ...               ...           ...     ...      ...          ...  ...
# 18939           81.77         14.35    0.15    60.86        12.27  ...
# 18940           84.76         14.22    0.24    52.72        11.52  ...
# 18941           84.05         14.73    0.21    52.73        11.74  ...
# 18942           85.74         13.76    0.23    51.39        11.09  ...
# 18943           85.45         14.74    0.30    51.37        11.04  ...
#
#       CONTRACTED UPLOAD SPEED CONTRACTED DATA CAP CONTRACTED MONTHLY COST  \
# 0                         NaN                 NaN                     NaN
# 1                         NaN                 NaN                     NaN
# 2                         NaN                 NaN                     NaN
# 3                         NaN                 NaN                     NaN
# 4                         NaN                 NaN                     NaN
# ...                       ...                 ...                     ...
# 18939                      10           Unlimited                     100
# 18940                      10           Unlimited                     100
# 18941                      10           Unlimited                     100
# 18942                      10           Unlimited                     100
# 18943                      10           Unlimited                     100
#
#       SERVICE TYPE USER SATISFACTION CONNECTION TYPE  \
# 0              NaN               NaN             NaN
# 1              NaN               NaN             NaN
# 2              NaN               NaN             NaN
# 3              NaN               NaN             NaN
# 4              NaN               NaN             NaN
# ...            ...               ...             ...
# 18939         Home               4.0             DSL
# 18940         Home               4.0             DSL
# 18941         Home               4.0             DSL
# 18942         Home               4.0             DSL
# 18943         Home               4.0             DSL
#
#                              USER COMMENTS HEATMAP_MUNICIPALITY  \
# 0                                      NaN             Winnipeg
# 1                                      NaN             Winnipeg
# 2                                      NaN             Winnipeg
# 3                                      NaN             Winnipeg
# 4                                      NaN             Winnipeg
# ...                                    ...                  ...
# 18939  internet price promotion paying $40             Winnipeg
# 18940  internet price promotion paying $40             Winnipeg
# 18941  internet price promotion paying $40             Winnipeg
# 18942  internet price promotion paying $40             Winnipeg
# 18943  internet price promotion paying $40             Winnipeg
#
#       HEATMAP_CENSUS_TRACTS HEATMAP_PROJECT_AREA
# 0                6020537.02                  NaN
# 1                6020522.02                  NaN
# 2                6020014.00                  NaN
# 3                6020501.02                  NaN
# 4                6020016.00                  NaN
# ...                     ...                  ...
# 18939            6020510.06                  NaN
# 18940            6020510.06                  NaN
# 18941            6020510.06                  NaN
# 18942            6020510.06                  NaN
# 18943            6020510.06                  NaN
#
# [18944 rows x 32 columns]

# %%
# Drop the index column as it is not useful and save the change in place

northEndConnect_RemoveALLBlankRows.drop(columns = ['index'], inplace = True)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
northEndConnect_RemoveALLBlankRows
# Out:
#          TEST ID TEST DATE / UTC HOUR  GEO LATITUDE  GEO LONGITUDE  \
# 0          261.0      5/23/2015 10:00     49.869556     -97.296739
# 1          284.0      5/20/2015 10:01     49.852738     -97.270058
# 2          622.0      5/19/2015 10:00     49.887575     -97.140091
# 3          701.0      5/24/2015 10:00     49.814284     -97.160235
# 4          707.0      5/19/2015 10:00     49.882706     -97.161829
# ...          ...                  ...           ...            ...
# 18939  1616011.0      12/11/2022 0:28     49.829862     -97.185759
# 18940  1616040.0      12/11/2022 1:28     49.829862     -97.185759
# 18941  1616060.0      12/11/2022 2:28     49.829862     -97.185759
# 18942  1616076.0      12/11/2022 3:28     49.829862     -97.185759
# 18943  1616089.0      12/11/2022 4:28     49.829862     -97.185759
#
#        DOWNLOAD SPEED  UPLOAD SPEED  JITTER  LATENCY  PACKET LOSS MOBILE TEST  \
# 0               16.22          2.79     NaN      NaN          NaN       False
# 1               14.89          2.74     NaN      NaN          NaN       False
# 2                9.89          5.64     NaN      NaN          NaN       False
# 3               10.62          2.09     NaN      NaN          NaN       False
# 4                9.89          2.60     NaN      NaN          NaN       False
# ...               ...           ...     ...      ...          ...         ...
# 18939           81.77         14.35    0.15    60.86        12.27       False
# 18940           84.76         14.22    0.24    52.72        11.52       False
# 18941           84.05         14.73    0.21    52.73        11.74       False
# 18942           85.74         13.76    0.23    51.39        11.09       False
# 18943           85.45         14.74    0.30    51.37        11.04       False
#
#        ... CONTRACTED UPLOAD SPEED CONTRACTED DATA CAP  \
# 0      ...                     NaN                 NaN
# 1      ...                     NaN                 NaN
# 2      ...                     NaN                 NaN
# 3      ...                     NaN                 NaN
# 4      ...                     NaN                 NaN
# ...    ...                     ...                 ...
# 18939  ...                      10           Unlimited
# 18940  ...                      10           Unlimited
# 18941  ...                      10           Unlimited
# 18942  ...                      10           Unlimited
# 18943  ...                      10           Unlimited
#
#       CONTRACTED MONTHLY COST SERVICE TYPE USER SATISFACTION CONNECTION TYPE  \
# 0                         NaN          NaN               NaN             NaN
# 1                         NaN          NaN               NaN             NaN
# 2                         NaN          NaN               NaN             NaN
# 3                         NaN          NaN               NaN             NaN
# 4                         NaN          NaN               NaN             NaN
# ...                       ...          ...               ...             ...
# 18939                     100         Home               4.0             DSL
# 18940                     100         Home               4.0             DSL
# 18941                     100         Home               4.0             DSL
# 18942                     100         Home               4.0             DSL
# 18943                     100         Home               4.0             DSL
#
#                              USER COMMENTS HEATMAP_MUNICIPALITY  \
# 0                                      NaN             Winnipeg
# 1                                      NaN             Winnipeg
# 2                                      NaN             Winnipeg
# 3                                      NaN             Winnipeg
# 4                                      NaN             Winnipeg
# ...                                    ...                  ...
# 18939  internet price promotion paying $40             Winnipeg
# 18940  internet price promotion paying $40             Winnipeg
# 18941  internet price promotion paying $40             Winnipeg
# 18942  internet price promotion paying $40             Winnipeg
# 18943  internet price promotion paying $40             Winnipeg
#
#       HEATMAP_CENSUS_TRACTS HEATMAP_PROJECT_AREA
# 0                6020537.02                  NaN
# 1                6020522.02                  NaN
# 2                6020014.00                  NaN
# 3                6020501.02                  NaN
# 4                6020016.00                  NaN
# ...                     ...                  ...
# 18939            6020510.06                  NaN
# 18940            6020510.06                  NaN
# 18941            6020510.06                  NaN
# 18942            6020510.06                  NaN
# 18943            6020510.06                  NaN
#
# [18944 rows x 31 columns]

# %%
# Save the dataset into another aptly named variable

northEndConnectData = northEndConnect_RemoveALLBlankRows

# %%
# Display the names of the columns of the dataset

northEndConnectData.columns
# Out:
# Index(['TEST ID', 'TEST DATE / UTC HOUR', 'GEO LATITUDE', 'GEO LONGITUDE',
#        'DOWNLOAD SPEED', 'UPLOAD SPEED', 'JITTER', 'LATENCY', 'PACKET LOSS',
#        'MOBILE TEST', 'ISP', 'CLIENT IP', 'CLIENT CITY', 'CLIENT PROVINCE',
#        'CLIENT POSTAL CODE', 'AS NUMBER', 'IPV6 SUPPORTED', 'DNSSEC SUPPORTED',
#        'TEST SERVER', 'browser_test_url', 'CONTRACTED DOWNLOAD SPEED',
#        'CONTRACTED UPLOAD SPEED', 'CONTRACTED DATA CAP',
#        'CONTRACTED MONTHLY COST', 'SERVICE TYPE', 'USER SATISFACTION',
#        'CONNECTION TYPE', 'USER COMMENTS', 'HEATMAP_MUNICIPALITY',
#        'HEATMAP_CENSUS_TRACTS', 'HEATMAP_PROJECT_AREA'],
#       dtype='object')

# %%
northEndConnectData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18944 entries, 0 to 18943
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   TEST ID                    18944 non-null  float64
#  1   TEST DATE / UTC HOUR       18944 non-null  object
#  2   GEO LATITUDE               18944 non-null  float64
#  3   GEO LONGITUDE              18944 non-null  float64
#  4   DOWNLOAD SPEED             18944 non-null  float64
#  5   UPLOAD SPEED               18944 non-null  float64
#  6   JITTER                     10894 non-null  float64
#  7   LATENCY                    10894 non-null  float64
#  8   PACKET LOSS                10894 non-null  float64
#  9   MOBILE TEST                18944 non-null  object
#  10  ISP                        18943 non-null  object
#  11  CLIENT IP                  18944 non-null  object
#  12  CLIENT CITY                18889 non-null  object
#  13  CLIENT PROVINCE            18866 non-null  object
#  14  CLIENT POSTAL CODE         18918 non-null  object
#  15  AS NUMBER                  18923 non-null  object
#  16  IPV6 SUPPORTED             18944 non-null  object
#  17  DNSSEC SUPPORTED           18944 non-null  object
#  18  TEST SERVER                18944 non-null  object
#  19  browser_test_url           12028 non-null  object
#  20  CONTRACTED DOWNLOAD SPEED  3420 non-null   object
#  21  CONTRACTED UPLOAD SPEED    2067 non-null   object
#  22  CONTRACTED DATA CAP        1233 non-null   object
#  23  CONTRACTED MONTHLY COST    2986 non-null   object
#  24  SERVICE TYPE               3970 non-null   object
#  25  USER SATISFACTION          3030 non-null   float64
#  26  CONNECTION TYPE            1186 non-null   object
#  27  USER COMMENTS              4609 non-null   object
#  28  HEATMAP_MUNICIPALITY       18944 non-null  object
#  29  HEATMAP_CENSUS_TRACTS      18944 non-null  float64
#  30  HEATMAP_PROJECT_AREA       692 non-null    object
# dtypes: float64(10), object(21)
# memory usage: 4.5+ MB

# %%
# Display the percentage of missing values in each column/field of data

northEndConnectData.isnull().sum()/len(northEndConnectData)*100
# Out:
# TEST ID                       0.000000
# TEST DATE / UTC HOUR          0.000000
# GEO LATITUDE                  0.000000
# GEO LONGITUDE                 0.000000
# DOWNLOAD SPEED                0.000000
# UPLOAD SPEED                  0.000000
# JITTER                       42.493666
# LATENCY                      42.493666
# PACKET LOSS                  42.493666
# MOBILE TEST                   0.000000
# ISP                           0.005279
# CLIENT IP                     0.000000
# CLIENT CITY                   0.290329
# CLIENT PROVINCE               0.411740
# CLIENT POSTAL CODE            0.137247
# AS NUMBER                     0.110853
# IPV6 SUPPORTED                0.000000
# DNSSEC SUPPORTED              0.000000
# TEST SERVER                   0.000000
# browser_test_url             36.507601
# CONTRACTED DOWNLOAD SPEED    81.946791
# CONTRACTED UPLOAD SPEED      89.088894
# CONTRACTED DATA CAP          93.491343
# CONTRACTED MONTHLY COST      84.237753
# SERVICE TYPE                 79.043497
# USER SATISFACTION            84.005490
# CONNECTION TYPE              93.739443
# USER COMMENTS                75.670397
# HEATMAP_MUNICIPALITY          0.000000
# HEATMAP_CENSUS_TRACTS         0.000000
# HEATMAP_PROJECT_AREA         96.347128
# dtype: float64

# %%
# From the above line, it can be seen that the missing values in the columns
# CONTRACTED DOWNLOAD SPEED, CONTRACTED UPLOAD SPEED, CONTRACTED DATA CAP, CONTRACTED MONTHLY COST, 
# SERVICE TYPE, USER SATISFACTION, CONNECTION TYPE, USER COMMENTS and HEATMAP_PROJECT_AREA
# ARE MORE THAN FIFTY PERCENT (50%). Infact they are in their 70s, 80s, and 90 PERCENTS.
# These columns are CANDIDATES FOR REMOVAL.

# %% [markdown]
# #### Split the TEST DATE/UTC HOUR column into two columns.One holding TEST DATE and the other UTC HOUR

# %%
northEndConnectData_TimeSplit = northEndConnectData
testDate = []
utcHour = []

for value in northEndConnectData['TEST DATE / UTC HOUR']:
    spaceIndex = value.index(" ")
    dateData = value[:spaceIndex]
    timeData = value[spaceIndex:]
    testDate.append(dateData)
    utcHour.append(timeData)
    
northEndConnectData_TimeSplit["TEST DATE"] = testDate
northEndConnectData_TimeSplit["TEST TIME"] = utcHour
# Out:
# <ipython-input-16-7f8b915efd51>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   northEndConnectData_TimeSplit["TEST DATE"] = testDate
# <ipython-input-16-7f8b915efd51>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   northEndConnectData_TimeSplit["TEST TIME"] = utcHour

# %%
northEndConnectData_TimeSplit
# Out:
#          TEST ID TEST DATE / UTC HOUR  GEO LATITUDE  GEO LONGITUDE  \
# 0          261.0      5/23/2015 10:00     49.869556     -97.296739
# 1          284.0      5/20/2015 10:01     49.852738     -97.270058
# 2          622.0      5/19/2015 10:00     49.887575     -97.140091
# 3          701.0      5/24/2015 10:00     49.814284     -97.160235
# 4          707.0      5/19/2015 10:00     49.882706     -97.161829
# ...          ...                  ...           ...            ...
# 18939  1616011.0      12/11/2022 0:28     49.829862     -97.185759
# 18940  1616040.0      12/11/2022 1:28     49.829862     -97.185759
# 18941  1616060.0      12/11/2022 2:28     49.829862     -97.185759
# 18942  1616076.0      12/11/2022 3:28     49.829862     -97.185759
# 18943  1616089.0      12/11/2022 4:28     49.829862     -97.185759
#
#        DOWNLOAD SPEED  UPLOAD SPEED  JITTER  LATENCY  PACKET LOSS MOBILE TEST  \
# 0               16.22          2.79     NaN      NaN          NaN       False
# 1               14.89          2.74     NaN      NaN          NaN       False
# 2                9.89          5.64     NaN      NaN          NaN       False
# 3               10.62          2.09     NaN      NaN          NaN       False
# 4                9.89          2.60     NaN      NaN          NaN       False
# ...               ...           ...     ...      ...          ...         ...
# 18939           81.77         14.35    0.15    60.86        12.27       False
# 18940           84.76         14.22    0.24    52.72        11.52       False
# 18941           84.05         14.73    0.21    52.73        11.74       False
# 18942           85.74         13.76    0.23    51.39        11.09       False
# 18943           85.45         14.74    0.30    51.37        11.04       False
#
#        ... CONTRACTED MONTHLY COST SERVICE TYPE USER SATISFACTION  \
# 0      ...                     NaN          NaN               NaN
# 1      ...                     NaN          NaN               NaN
# 2      ...                     NaN          NaN               NaN
# 3      ...                     NaN          NaN               NaN
# 4      ...                     NaN          NaN               NaN
# ...    ...                     ...          ...               ...
# 18939  ...                     100         Home               4.0
# 18940  ...                     100         Home               4.0
# 18941  ...                     100         Home               4.0
# 18942  ...                     100         Home               4.0
# 18943  ...                     100         Home               4.0
#
#       CONNECTION TYPE                        USER COMMENTS  \
# 0                 NaN                                  NaN
# 1                 NaN                                  NaN
# 2                 NaN                                  NaN
# 3                 NaN                                  NaN
# 4                 NaN                                  NaN
# ...               ...                                  ...
# 18939             DSL  internet price promotion paying $40
# 18940             DSL  internet price promotion paying $40
# 18941             DSL  internet price promotion paying $40
# 18942             DSL  internet price promotion paying $40
# 18943             DSL  internet price promotion paying $40
#
#       HEATMAP_MUNICIPALITY HEATMAP_CENSUS_TRACTS HEATMAP_PROJECT_AREA  \
# 0                 Winnipeg            6020537.02                  NaN
# 1                 Winnipeg            6020522.02                  NaN
# 2                 Winnipeg            6020014.00                  NaN
# 3                 Winnipeg            6020501.02                  NaN
# 4                 Winnipeg            6020016.00                  NaN
# ...                    ...                   ...                  ...
# 18939             Winnipeg            6020510.06                  NaN
# 18940             Winnipeg            6020510.06                  NaN
# 18941             Winnipeg            6020510.06                  NaN
# 18942             Winnipeg            6020510.06                  NaN
# 18943             Winnipeg            6020510.06                  NaN
#
#         TEST DATE TEST TIME
# 0       5/23/2015     10:00
# 1       5/20/2015     10:01
# 2       5/19/2015     10:00
# 3       5/24/2015     10:00
# 4       5/19/2015     10:00
# ...           ...       ...
# 18939  12/11/2022      0:28
# 18940  12/11/2022      1:28
# 18941  12/11/2022      2:28
# 18942  12/11/2022      3:28
# 18943  12/11/2022      4:28
#
# [18944 rows x 33 columns]

# %%
northEndConnect_SplitDate = northEndConnectData_TimeSplit

year = []
month = []
day = []

for value in northEndConnect_SplitDate["TEST DATE"]:
    first_delimiter = value.index("/")
    second_delimiter = value.index("/", first_delimiter+1)
    monthOfDate = value[:first_delimiter]
    dayOfDate = value[first_delimiter+1:second_delimiter]
    yearOfDate = value[-4:]
    
    day.append(dayOfDate)
    month.append(monthOfDate)
    year.append(yearOfDate)
    
#northEndConnect_SplitDate["YEAR"] = year
#northEndConnect_SplitDate["MONTH"] = month
#northEndConnect_SplitDate["DAY"] = day
northEndConnect_SplitDate.insert(2, "YEAR", year, True)
northEndConnect_SplitDate.insert(3, "MONTH", month, True)
northEndConnect_SplitDate.insert(4, "DAY", day, True)

# %%
northEndConnect_SplitDate
# Out:
#          TEST ID TEST DATE / UTC HOUR  YEAR MONTH DAY  GEO LATITUDE  \
# 0          261.0      5/23/2015 10:00  2015     5  23     49.869556
# 1          284.0      5/20/2015 10:01  2015     5  20     49.852738
# 2          622.0      5/19/2015 10:00  2015     5  19     49.887575
# 3          701.0      5/24/2015 10:00  2015     5  24     49.814284
# 4          707.0      5/19/2015 10:00  2015     5  19     49.882706
# ...          ...                  ...   ...   ...  ..           ...
# 18939  1616011.0      12/11/2022 0:28  2022    12  11     49.829862
# 18940  1616040.0      12/11/2022 1:28  2022    12  11     49.829862
# 18941  1616060.0      12/11/2022 2:28  2022    12  11     49.829862
# 18942  1616076.0      12/11/2022 3:28  2022    12  11     49.829862
# 18943  1616089.0      12/11/2022 4:28  2022    12  11     49.829862
#
#        GEO LONGITUDE  DOWNLOAD SPEED  UPLOAD SPEED  JITTER  ...  \
# 0         -97.296739           16.22          2.79     NaN  ...
# 1         -97.270058           14.89          2.74     NaN  ...
# 2         -97.140091            9.89          5.64     NaN  ...
# 3         -97.160235           10.62          2.09     NaN  ...
# 4         -97.161829            9.89          2.60     NaN  ...
# ...              ...             ...           ...     ...  ...
# 18939     -97.185759           81.77         14.35    0.15  ...
# 18940     -97.185759           84.76         14.22    0.24  ...
# 18941     -97.185759           84.05         14.73    0.21  ...
# 18942     -97.185759           85.74         13.76    0.23  ...
# 18943     -97.185759           85.45         14.74    0.30  ...
#
#        CONTRACTED MONTHLY COST  SERVICE TYPE USER SATISFACTION  \
# 0                          NaN           NaN               NaN
# 1                          NaN           NaN               NaN
# 2                          NaN           NaN               NaN
# 3                          NaN           NaN               NaN
# 4                          NaN           NaN               NaN
# ...                        ...           ...               ...
# 18939                      100          Home               4.0
# 18940                      100          Home               4.0
# 18941                      100          Home               4.0
# 18942                      100          Home               4.0
# 18943                      100          Home               4.0
#
#       CONNECTION TYPE                        USER COMMENTS  \
# 0                 NaN                                  NaN
# 1                 NaN                                  NaN
# 2                 NaN                                  NaN
# 3                 NaN                                  NaN
# 4                 NaN                                  NaN
# ...               ...                                  ...
# 18939             DSL  internet price promotion paying $40
# 18940             DSL  internet price promotion paying $40
# 18941             DSL  internet price promotion paying $40
# 18942             DSL  internet price promotion paying $40
# 18943             DSL  internet price promotion paying $40
#
#       HEATMAP_MUNICIPALITY HEATMAP_CENSUS_TRACTS HEATMAP_PROJECT_AREA  \
# 0                 Winnipeg            6020537.02                  NaN
# 1                 Winnipeg            6020522.02                  NaN
# 2                 Winnipeg            6020014.00                  NaN
# 3                 Winnipeg            6020501.02                  NaN
# 4                 Winnipeg            6020016.00                  NaN
# ...                    ...                   ...                  ...
# 18939             Winnipeg            6020510.06                  NaN
# 18940             Winnipeg            6020510.06                  NaN
# 18941             Winnipeg            6020510.06                  NaN
# 18942             Winnipeg            6020510.06                  NaN
# 18943             Winnipeg            6020510.06                  NaN
#
#         TEST DATE TEST TIME
# 0       5/23/2015     10:00
# 1       5/20/2015     10:01
# 2       5/19/2015     10:00
# 3       5/24/2015     10:00
# 4       5/19/2015     10:00
# ...           ...       ...
# 18939  12/11/2022      0:28
# 18940  12/11/2022      1:28
# 18941  12/11/2022      2:28
# 18942  12/11/2022      3:28
# 18943  12/11/2022      4:28
#
# [18944 rows x 36 columns]

# %%
# Having split the "TEST DATE / UTC TIME" column into the YEAR, MONTH, DAY, and TIME columns, we can
# Drop the "TEST DATE / UTC TIME" column.

northEndConnect_SplitDate_dropTESTDATE_UTCHOUR = northEndConnect_SplitDate.drop(columns = ['TEST DATE / UTC HOUR'])

# %%
northEndConnect_SplitDate_dropTESTDATE_UTCHOUR
# Out:
#          TEST ID  YEAR MONTH DAY  GEO LATITUDE  GEO LONGITUDE  DOWNLOAD SPEED  \
# 0          261.0  2015     5  23     49.869556     -97.296739           16.22
# 1          284.0  2015     5  20     49.852738     -97.270058           14.89
# 2          622.0  2015     5  19     49.887575     -97.140091            9.89
# 3          701.0  2015     5  24     49.814284     -97.160235           10.62
# 4          707.0  2015     5  19     49.882706     -97.161829            9.89
# ...          ...   ...   ...  ..           ...            ...             ...
# 18939  1616011.0  2022    12  11     49.829862     -97.185759           81.77
# 18940  1616040.0  2022    12  11     49.829862     -97.185759           84.76
# 18941  1616060.0  2022    12  11     49.829862     -97.185759           84.05
# 18942  1616076.0  2022    12  11     49.829862     -97.185759           85.74
# 18943  1616089.0  2022    12  11     49.829862     -97.185759           85.45
#
#        UPLOAD SPEED  JITTER  LATENCY  ...  CONTRACTED MONTHLY COST  \
# 0              2.79     NaN      NaN  ...                      NaN
# 1              2.74     NaN      NaN  ...                      NaN
# 2              5.64     NaN      NaN  ...                      NaN
# 3              2.09     NaN      NaN  ...                      NaN
# 4              2.60     NaN      NaN  ...                      NaN
# ...             ...     ...      ...  ...                      ...
# 18939         14.35    0.15    60.86  ...                      100
# 18940         14.22    0.24    52.72  ...                      100
# 18941         14.73    0.21    52.73  ...                      100
# 18942         13.76    0.23    51.39  ...                      100
# 18943         14.74    0.30    51.37  ...                      100
#
#       SERVICE TYPE USER SATISFACTION CONNECTION TYPE  \
# 0              NaN               NaN             NaN
# 1              NaN               NaN             NaN
# 2              NaN               NaN             NaN
# 3              NaN               NaN             NaN
# 4              NaN               NaN             NaN
# ...            ...               ...             ...
# 18939         Home               4.0             DSL
# 18940         Home               4.0             DSL
# 18941         Home               4.0             DSL
# 18942         Home               4.0             DSL
# 18943         Home               4.0             DSL
#
#                              USER COMMENTS HEATMAP_MUNICIPALITY  \
# 0                                      NaN             Winnipeg
# 1                                      NaN             Winnipeg
# 2                                      NaN             Winnipeg
# 3                                      NaN             Winnipeg
# 4                                      NaN             Winnipeg
# ...                                    ...                  ...
# 18939  internet price promotion paying $40             Winnipeg
# 18940  internet price promotion paying $40             Winnipeg
# 18941  internet price promotion paying $40             Winnipeg
# 18942  internet price promotion paying $40             Winnipeg
# 18943  internet price promotion paying $40             Winnipeg
#
#       HEATMAP_CENSUS_TRACTS HEATMAP_PROJECT_AREA   TEST DATE TEST TIME
# 0                6020537.02                  NaN   5/23/2015     10:00
# 1                6020522.02                  NaN   5/20/2015     10:01
# 2                6020014.00                  NaN   5/19/2015     10:00
# 3                6020501.02                  NaN   5/24/2015     10:00
# 4                6020016.00                  NaN   5/19/2015     10:00
# ...                     ...                  ...         ...       ...
# 18939            6020510.06                  NaN  12/11/2022      0:28
# 18940            6020510.06                  NaN  12/11/2022      1:28
# 18941            6020510.06                  NaN  12/11/2022      2:28
# 18942            6020510.06                  NaN  12/11/2022      3:28
# 18943            6020510.06                  NaN  12/11/2022      4:28
#
# [18944 rows x 35 columns]

# %%
# Display the contents of the ISP column

# Retrieve the contents of the ISP column as a DataFrame.
ispColumn = northEndConnect_SplitDate_dropTESTDATE_UTCHOUR[["ISP"]]

# Sort the contents of the obtained ISP column in ascending order. Save the change in the same DataFrame object.
ispColumn.sort_values(by = ['ISP'], inplace = True, ascending = True) 

# Display the the Unique entries of the ISP column.
ispColumn['ISP'].unique()
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# array(['ACN', 'Access Communications  Co-operative Limited',
#        'Access Communications Co-operative Limited',
#        'Akamai Technologies, Inc.', 'Alberta Health Services',
#        'Alentus Corporation', 'Altima Telecom', 'Amanah Tech',
#        'Amanah Tech Inc.', 'Amazon Technologies Inc.', 'Amazon.com, Inc.',
#        'BH Telecom Corp.', 'BIGPIPE', 'Bell Canada', 'Bell MTS',
#        'Bell MTS Data Centres G.P', 'Bell Mobility', 'Bell Mobility, Inc',
#        'Business Development Bank of Canada', 'CIBC World Markets',
#        'CIK Telecom', 'CIK Telecom INC', 'Canada Drugs',
#        'Cipherkey Exchange Corp.', 'City of Winnipeg', 'Cloudflare, Inc.',
#        'Cogecodata', 'Cogent Communications', 'Commstream Communications',
#        'Commstream Communications Inc', 'Corridor Communications',
#        'Corridor Communications, INC.', 'Corus Entertainment Inc',
#        'Daemon Defense Systems', 'DataCamp Limited', 'DigitalOcean, LLC',
#        'Epic Information Solutions', 'Fastnet Communications',
#        'Full Throttle Networks', 'Full Throttle Networks Inc.',
#        'GTCOMM - GloboTech Communications', 'GloboTech Communications',
#        'Google, LLC', 'Health Sciences Center', 'Hextet Systems',
#        'High Speed Crow', 'Hurricane Electric IPv6 tunnel broker',
#        'Hutterian Broadband Network Inc', 'I Voice Comm Telnetwork',
#        'Infotec Manitoba', 'Ipxo Limited', 'KMTS Internet', 'LES.NET',
#        'MERLIN', 'MRNet', 'MTS Allstream', 'MTS Allstream Inc.',
#        'MTS Data Centres', 'MTS Inc', 'MTS Inc.',
#        'Manitoba First Nations Education Resource Centre',
#        'Manitoba First Nations Education Resource Centre Inc.',
#        'Manitoba Hydro', 'Manitoba Hydro International LTD',
#        'Manitoba Hydro Telecom', 'Manitoba NetSet', 'Net1 GmbH',
#        'Netminders Data Solution', 'NoLimits Internet Solutions',
#        'OVH Hosting', 'Oxio', 'Packet Exchange Limited', 'PacketHub S.A.',
#        'Performive LLC', 'Postmedia Network', 'Postmedia Network Inc',
#        'Powerhouse Management', 'Prairie-Sky Wireless',
#        'Primus Telecommunications Canada Inc.', 'Questzone.Net, Inc.',
#        'RBC Convention Centre Winnipeg', 'Radiant Communications Canada',
#        'Radiant Communications Canada Ltd.', 'Rainy Day Software Corp.',
#        'Red River College of Applied Arts',
#        'Red River College of Applied Arts, Science and Tec',
#        'Rogers Cable', 'Rogers Communications Canada Inc.',
#        'Saskatchewan Telecommunications', 'Shared Services Canada',
#        'Shaw Communications', 'Shaw Communications Inc.',
#        'Shaw Telecom G.P.', 'South Winnipeg Technical Centre',
#        'Space Exploration Technologies Corporation', 'SpaceX Services',
#        'SpaceX Starlink', 'Stafford Communications, Inc.', 'SurfEasy Inc',
#        'Swift High Speed.com', 'T. Grand Networks Inc.', 'TBayTel',
#        'TELUS Communications Inc', 'TELUS Communications Inc.',
#        'Tefincom S.A.', 'TekSavvy Solutions', 'TekSavvy Solutions, Inc.',
#        'Telus Communications', 'TeraGo Networks', 'TeraGo Networks Inc',
#        'TeraGo Networks Inc.', 'The Exchange Global Server Center',
#        'The Winnipeg School Division No. 1',
#        'Total Server Solutions L.L.C', 'Total Server Solutions L.L.C.',
#        'University of Manitoba', 'University of Ottawa',
#        'University of Winnipeg', 'VMedia', 'VOI NET INC.', 'VPN',
#        'Verizon Business', 'ViaNetTV Inc', 'Voi Networks',
#        'Voyageur Internet', 'Voyageur Internet Inc',
#        'WiBand Communications', 'Xplornet Communications',
#        'Xplornet Communications Inc', 'Xplornet Communications Inc.',
#        'Yesup Ecommerce Solutions', 'Your.org', nan], dtype=object)

# %%
# From the Unique entries of the ISP, it is obvious that there are discrepancies in some entries.
# Some correction is needed.

# %% [markdown]
# ## Checking and Correcting the ISP names for Consistency and Uniformity.....

# %%
northEndConnect1 = northEndConnect_SplitDate_dropTESTDATE_UTCHOUR

for i in range(len(northEndConnect1)):
    if(northEndConnect1.loc[i, 'ISP'] == 'Access Communications  Co-operative Limited'):
        northEndConnect1 = northEndConnect1.replace('Access Communications  Co-operative Limited', 
                                                   'Access Communications Co-operative Limited')
        
    elif(northEndConnect1.loc[i, 'ISP'] == 'Amanah Tech'):
        northEndConnect1 = northEndConnect1.replace('Amanah Tech', 'Amanah Tech Inc.')
        
    elif(northEndConnect1.loc[i, 'ISP'] == 'Amazon.com, Inc.'):
        northEndConnect1 = northEndConnect1.replace('Amazon.com, Inc.', 'Amazon Technologies Inc.')
        
    elif(northEndConnect1.loc[i, 'ISP'] == 'Bell Mobility, Inc'):
        northEndConnect1 = northEndConnect1.replace('Bell Mobility, Inc', 'Bell Mobility')  
    
    elif(northEndConnect1.loc[i, 'ISP'] == 'CIK Telecom INC'):
        northEndConnect1 = northEndConnect1.replace('CIK Telecom INC', 'CIK Telecom')
        
    elif(northEndConnect1.loc[i, 'ISP'] == 'Commstream Communications Inc'):
        northEndConnect1 = northEndConnect1.replace('Commstream Communications Inc', 'Commstream Communications')    
        
    elif(northEndConnect1.loc[i, 'ISP'] == 'Corridor Communications, INC.'):
        northEndConnect1 = northEndConnect1.replace('Corridor Communications, INC.', 'Corridor Communications') 
        
    elif(northEndConnect1.loc[i, 'ISP'] == 'Full Throttle Networks Inc.'):
        northEndConnect1 = northEndConnect1.replace('Full Throttle Networks Inc.', 'Full Throttle Networks')
        
               
    elif(northEndConnect1.loc[i, 'ISP'] == 'Shaw Communications Inc.'):
        northEndConnect1 = northEndConnect1.replace('Shaw Communications Inc.', 'Shaw Communications')     
    
    else:    
        pass

# %%
for i in range(len(northEndConnect1)):
    if(northEndConnect1.loc[i, 'ISP'] == 'MTS Allstream Inc.'):
        northEndConnect1 = northEndConnect1.replace('MTS Allstream Inc.', 'MTS Allstream')
        
    elif(northEndConnect1.loc[i, 'ISP'] == 'MTS Inc.'):
        northEndConnect1 = northEndConnect1.replace('MTS Inc.', 'MTS Inc')
        
    elif(northEndConnect1.loc[i, 'ISP'] == 'Manitoba First Nations Education Resource Centre Inc.'):
        northEndConnect1 = northEndConnect1.replace('Manitoba First Nations Education Resource Centre Inc.', 
                                                    'Manitoba First Nations Education Resource Centre')
        
    elif(northEndConnect1.loc[i, 'ISP'] == 'Manitoba Hydro International LTD') or (northEndConnect1.loc[i, 'ISP'] == 'Manitoba Hydro Telecom'):
        northEndConnect1 = northEndConnect1.replace('Manitoba Hydro International LTD', 'Manitoba Hydro') 
        northEndConnect1 = northEndConnect1.replace('Manitoba Hydro Telecom', 'Manitoba Hydro')
    
    elif(northEndConnect1.loc[i, 'ISP'] == 'Postmedia Network Inc'):
        northEndConnect1 = northEndConnect1.replace('Postmedia Network Inc', 'Postmedia Network')
        
    elif(northEndConnect1.loc[i, 'ISP'] == 'Red River College of Applied Arts'):
        northEndConnect1 = northEndConnect1.replace('Red River College of Applied Arts', 
                                                    'Red River College of Applied Arts, Science and Tec')    
        
    elif(northEndConnect1.loc[i, 'ISP'] == 'Rogers Communications Canada Inc.'):
        northEndConnect1 = northEndConnect1.replace('Rogers Communications Canada Inc.', 'Rogers Cable') 
        
    elif(northEndConnect1.loc[i, 'ISP'] == 'Shaw Communications Inc.') or (northEndConnect1.loc[i, 'ISP'] == 'Shaw Telecom G.P.'):
        northEndConnect1 = northEndConnect1.replace('Shaw Communications Inc.', 'Shaw Communications')
        northEndConnect1 = northEndConnect1.replace('Shaw Telecom G.P.', 'Shaw Communications')
        
    elif(northEndConnect1.loc[i, 'ISP'] == 'Space Exploration Technologies Corporation') or (northEndConnect1.loc[i, 'ISP'] == 'SpaceX Services'):
        northEndConnect1 = northEndConnect1.replace('Space Exploration Technologies Corporation', 'SpaceX Starlink')
        northEndConnect1 = northEndConnect1.replace('SpaceX Services', 'SpaceX Starlink')
    
    else:    
        pass

# %%
for i in range(len(northEndConnect1)):
    if(northEndConnect1.loc[i, 'ISP'] == 'TELUS Communications Inc') or (northEndConnect1.loc[i, 'ISP'] == 'TELUS Communications Inc.'):
        northEndConnect1 = northEndConnect1.replace('TELUS Communications Inc', 'Telus Communications')
        northEndConnect1 = northEndConnect1.replace('TELUS Communications Inc.', 'Telus Communications')
        
    elif(northEndConnect1.loc[i, 'ISP'] == 'TeraGo Networks Inc.') or (northEndConnect1.loc[i, 'ISP'] == 'TeraGo Networks Inc'):
        northEndConnect1 = northEndConnect1.replace('TeraGo Networks Inc.', 'TeraGo Networks') 
        northEndConnect1 = northEndConnect1.replace('TeraGo Networks Inc', 'TeraGo Networks')    
        
    elif(northEndConnect1.loc[i, 'ISP'] == 'Total Server Solutions L.L.C'):
        northEndConnect1 = northEndConnect1.replace('Total Server Solutions L.L.C', 'Total Server Solutions L.L.C.')
        
    elif(northEndConnect1.loc[i, 'ISP'] == 'VOI NET INC.'):
        northEndConnect1 = northEndConnect1.replace('VOI NET INC.', 'Voi Networks')
        
        
    elif(northEndConnect1.loc[i, 'ISP'] == 'Voyageur Internet Inc'):
        northEndConnect1 = northEndConnect1.replace('Voyageur Internet Inc', 'Voyageur Internet')
        
    
    elif(northEndConnect1.loc[i, 'ISP'] == 'Xplornet Communications Inc') or (northEndConnect1.loc[i, 'ISP'] == 'Xplornet Communications Inc.'):
        northEndConnect1 = northEndConnect1.replace('Xplornet Communications Inc', 'Xplornet Communications')
        northEndConnect1 = northEndConnect1.replace('Xplornet Communications Inc.', 'Xplornet Communications')
    
    else:    
        pass
    
values1 = northEndConnect1[['ISP']]  
values1.sort_values(by=['ISP'], inplace = True, ascending = True)
print(values1['ISP'].nunique())
print(northEndConnect1.shape)
values1['ISP'].unique()
# Out:
# 103
# (18944, 35)
# array(['ACN', 'Access Communications Co-operative Limited',
#        'Akamai Technologies, Inc.', 'Alberta Health Services',
#        'Alentus Corporation', 'Altima Telecom', 'Amanah Tech Inc.',
#        'Amazon Technologies Inc.', 'BH Telecom Corp.', 'BIGPIPE',
#        'Bell Canada', 'Bell MTS', 'Bell MTS Data Centres G.P',
#        'Bell Mobility', 'Business Development Bank of Canada',
#        'CIBC World Markets', 'CIK Telecom', 'Canada Drugs',
#        'Cipherkey Exchange Corp.', 'City of Winnipeg', 'Cloudflare, Inc.',
#        'Cogecodata', 'Cogent Communications', 'Commstream Communications',
#        'Corridor Communications', 'Corus Entertainment Inc',
#        'Daemon Defense Systems', 'DataCamp Limited', 'DigitalOcean, LLC',
#        'Epic Information Solutions', 'Fastnet Communications',
#        'Full Throttle Networks', 'GTCOMM - GloboTech Communications',
#        'GloboTech Communications', 'Google, LLC',
#        'Health Sciences Center', 'Hextet Systems', 'High Speed Crow',
#        'Hurricane Electric IPv6 tunnel broker',
#        'Hutterian Broadband Network Inc', 'I Voice Comm Telnetwork',
#        'Infotec Manitoba', 'Ipxo Limited', 'KMTS Internet', 'LES.NET',
#        'MERLIN', 'MRNet', 'MTS Allstream', 'MTS Data Centres', 'MTS Inc',
#        'Manitoba First Nations Education Resource Centre',
#        'Manitoba Hydro', 'Manitoba NetSet', 'Net1 GmbH',
#        'Netminders Data Solution', 'NoLimits Internet Solutions',
#        'OVH Hosting', 'Oxio', 'Packet Exchange Limited', 'PacketHub S.A.',
#        'Performive LLC', 'Postmedia Network', 'Powerhouse Management',
#        'Prairie-Sky Wireless', 'Primus Telecommunications Canada Inc.',
#        'Questzone.Net, Inc.', 'RBC Convention Centre Winnipeg',
#        'Radiant Communications Canada',
#        'Radiant Communications Canada Ltd.', 'Rainy Day Software Corp.',
#        'Red River College of Applied Arts, Science and Tec',
#        'Rogers Cable', 'Saskatchewan Telecommunications',
#        'Shared Services Canada', 'Shaw Communications',
#        'South Winnipeg Technical Centre', 'SpaceX Starlink',
#        'Stafford Communications, Inc.', 'SurfEasy Inc',
#        'Swift High Speed.com', 'T. Grand Networks Inc.', 'TBayTel',
#        'Tefincom S.A.', 'TekSavvy Solutions', 'TekSavvy Solutions, Inc.',
#        'Telus Communications', 'TeraGo Networks',
#        'The Exchange Global Server Center',
#        'The Winnipeg School Division No. 1',
#        'Total Server Solutions L.L.C.', 'University of Manitoba',
#        'University of Ottawa', 'University of Winnipeg', 'VMedia', 'VPN',
#        'Verizon Business', 'ViaNetTV Inc', 'Voi Networks',
#        'Voyageur Internet', 'WiBand Communications',
#        'Xplornet Communications', 'Yesup Ecommerce Solutions', 'Your.org',
#        nan], dtype=object)

# %%
 northEndConnect1
# Out:
#          TEST ID  YEAR MONTH DAY  GEO LATITUDE  GEO LONGITUDE  DOWNLOAD SPEED  \
# 0          261.0  2015     5  23     49.869556     -97.296739           16.22
# 1          284.0  2015     5  20     49.852738     -97.270058           14.89
# 2          622.0  2015     5  19     49.887575     -97.140091            9.89
# 3          701.0  2015     5  24     49.814284     -97.160235           10.62
# 4          707.0  2015     5  19     49.882706     -97.161829            9.89
# ...          ...   ...   ...  ..           ...            ...             ...
# 18939  1616011.0  2022    12  11     49.829862     -97.185759           81.77
# 18940  1616040.0  2022    12  11     49.829862     -97.185759           84.76
# 18941  1616060.0  2022    12  11     49.829862     -97.185759           84.05
# 18942  1616076.0  2022    12  11     49.829862     -97.185759           85.74
# 18943  1616089.0  2022    12  11     49.829862     -97.185759           85.45
#
#        UPLOAD SPEED  JITTER  LATENCY  ...  CONTRACTED MONTHLY COST  \
# 0              2.79     NaN      NaN  ...                      NaN
# 1              2.74     NaN      NaN  ...                      NaN
# 2              5.64     NaN      NaN  ...                      NaN
# 3              2.09     NaN      NaN  ...                      NaN
# 4              2.60     NaN      NaN  ...                      NaN
# ...             ...     ...      ...  ...                      ...
# 18939         14.35    0.15    60.86  ...                      100
# 18940         14.22    0.24    52.72  ...                      100
# 18941         14.73    0.21    52.73  ...                      100
# 18942         13.76    0.23    51.39  ...                      100
# 18943         14.74    0.30    51.37  ...                      100
#
#        SERVICE TYPE USER SATISFACTION CONNECTION TYPE  \
# 0               NaN               NaN             NaN
# 1               NaN               NaN             NaN
# 2               NaN               NaN             NaN
# 3               NaN               NaN             NaN
# 4               NaN               NaN             NaN
# ...             ...               ...             ...
# 18939          Home               4.0             DSL
# 18940          Home               4.0             DSL
# 18941          Home               4.0             DSL
# 18942          Home               4.0             DSL
# 18943          Home               4.0             DSL
#
#                              USER COMMENTS HEATMAP_MUNICIPALITY  \
# 0                                      NaN             Winnipeg
# 1                                      NaN             Winnipeg
# 2                                      NaN             Winnipeg
# 3                                      NaN             Winnipeg
# 4                                      NaN             Winnipeg
# ...                                    ...                  ...
# 18939  internet price promotion paying $40             Winnipeg
# 18940  internet price promotion paying $40             Winnipeg
# 18941  internet price promotion paying $40             Winnipeg
# 18942  internet price promotion paying $40             Winnipeg
# 18943  internet price promotion paying $40             Winnipeg
#
#       HEATMAP_CENSUS_TRACTS HEATMAP_PROJECT_AREA   TEST DATE  TEST TIME
# 0                6020537.02                  NaN   5/23/2015      10:00
# 1                6020522.02                  NaN   5/20/2015      10:01
# 2                6020014.00                  NaN   5/19/2015      10:00
# 3                6020501.02                  NaN   5/24/2015      10:00
# 4                6020016.00                  NaN   5/19/2015      10:00
# ...                     ...                  ...         ...        ...
# 18939            6020510.06                  NaN  12/11/2022       0:28
# 18940            6020510.06                  NaN  12/11/2022       1:28
# 18941            6020510.06                  NaN  12/11/2022       2:28
# 18942            6020510.06                  NaN  12/11/2022       3:28
# 18943            6020510.06                  NaN  12/11/2022       4:28
#
# [18944 rows x 35 columns]

# %%
# Replacing the DataFrame with that having the Editted and Cleaned ISP names.

northEndConnect_SplitDate_dropTESTDATE_UTCHOUR = northEndConnect1

# %%
# There is need to check that the test was performed for each IP Address at MOST
# ONCE FOR EACH MONTH IN EACH YEAR. EACH IP ADDRESS IN A MONTH MUST BE TESTED ONLY ONCE.
# Where there is a test of more than one per month for each IP Adrress, ONE RECORD WILL BE DELETED

northEndConnect_dropREPEATED_DAILYTEST = northEndConnect_SplitDate_dropTESTDATE_UTCHOUR.drop_duplicates(subset = ['CLIENT IP', 'YEAR', 'MONTH'])

# %%
northEndConnect_dropREPEATED_DAILYTEST
# Out:
#          TEST ID  YEAR MONTH DAY  GEO LATITUDE  GEO LONGITUDE  DOWNLOAD SPEED  \
# 0          261.0  2015     5  23     49.869556     -97.296739           16.22
# 1          284.0  2015     5  20     49.852738     -97.270058           14.89
# 2          622.0  2015     5  19     49.887575     -97.140091            9.89
# 3          701.0  2015     5  24     49.814284     -97.160235           10.62
# 4          707.0  2015     5  19     49.882706     -97.161829            9.89
# ...          ...   ...   ...  ..           ...            ...             ...
# 18914  1615719.0  2022    12  10     49.919200     -97.126300           40.23
# 18917  1615791.0  2022    12  10     49.829862     -97.185759           82.13
# 18918  1615795.0  2022    12  10     49.931980     -97.180791           43.99
# 18928  1615849.0  2022    12  10     49.774494     -97.187254          118.67
# 18936  1615978.0  2022    12  10     49.951400     -97.113300          264.96
#
#        UPLOAD SPEED  JITTER  LATENCY  ...  CONTRACTED MONTHLY COST  \
# 0              2.79     NaN      NaN  ...                      NaN
# 1              2.74     NaN      NaN  ...                      NaN
# 2              5.64     NaN      NaN  ...                      NaN
# 3              2.09     NaN      NaN  ...                      NaN
# 4              2.60     NaN      NaN  ...                      NaN
# ...             ...     ...      ...  ...                      ...
# 18914          4.49    0.18    59.98  ...                      NaN
# 18917         14.36    0.20    53.23  ...                      100
# 18918          3.80    0.04    44.40  ...                      NaN
# 18928          9.98   23.54    71.83  ...                      NaN
# 18936         69.69    0.42    68.67  ...                      NaN
#
#        SERVICE TYPE USER SATISFACTION CONNECTION TYPE  \
# 0               NaN               NaN             NaN
# 1               NaN               NaN             NaN
# 2               NaN               NaN             NaN
# 3               NaN               NaN             NaN
# 4               NaN               NaN             NaN
# ...             ...               ...             ...
# 18914           NaN               NaN             NaN
# 18917          Home               4.0             DSL
# 18918           NaN               NaN             NaN
# 18928           NaN               NaN             NaN
# 18936           NaN               NaN             NaN
#
#                              USER COMMENTS HEATMAP_MUNICIPALITY  \
# 0                                      NaN             Winnipeg
# 1                                      NaN             Winnipeg
# 2                                      NaN             Winnipeg
# 3                                      NaN             Winnipeg
# 4                                      NaN             Winnipeg
# ...                                    ...                  ...
# 18914                                  NaN             Winnipeg
# 18917  internet price promotion paying $40             Winnipeg
# 18918                                  NaN             Winnipeg
# 18928                                  NaN             Winnipeg
# 18936                                  NaN             Winnipeg
#
#       HEATMAP_CENSUS_TRACTS HEATMAP_PROJECT_AREA   TEST DATE  TEST TIME
# 0                6020537.02                  NaN   5/23/2015      10:00
# 1                6020522.02                  NaN   5/20/2015      10:01
# 2                6020014.00                  NaN   5/19/2015      10:00
# 3                6020501.02                  NaN   5/24/2015      10:00
# 4                6020016.00                  NaN   5/19/2015      10:00
# ...                     ...                  ...         ...        ...
# 18914            6020041.00                  R2W  12/10/2022       5:15
# 18917            6020510.06                  NaN  12/10/2022      13:29
# 18918            6020050.02                  NaN  12/10/2022      13:38
# 18928            6020500.13                  NaN  12/10/2022      17:57
# 18936            6020553.00                  NaN  12/10/2022      23:31
#
# [6414 rows x 35 columns]

# %%
# Resetting the Index of the Dataframe

northEndConnect_dropREPEATED_DAILYTEST.reset_index(inplace = True)

# %%
northEndConnect_dropREPEATED_DAILYTEST
# Out:
#       index    TEST ID  YEAR MONTH DAY  GEO LATITUDE  GEO LONGITUDE  \
# 0         0      261.0  2015     5  23     49.869556     -97.296739
# 1         1      284.0  2015     5  20     49.852738     -97.270058
# 2         2      622.0  2015     5  19     49.887575     -97.140091
# 3         3      701.0  2015     5  24     49.814284     -97.160235
# 4         4      707.0  2015     5  19     49.882706     -97.161829
# ...     ...        ...   ...   ...  ..           ...            ...
# 6409  18914  1615719.0  2022    12  10     49.919200     -97.126300
# 6410  18917  1615791.0  2022    12  10     49.829862     -97.185759
# 6411  18918  1615795.0  2022    12  10     49.931980     -97.180791
# 6412  18928  1615849.0  2022    12  10     49.774494     -97.187254
# 6413  18936  1615978.0  2022    12  10     49.951400     -97.113300
#
#       DOWNLOAD SPEED  UPLOAD SPEED  JITTER  ...  CONTRACTED MONTHLY COST  \
# 0              16.22          2.79     NaN  ...                      NaN
# 1              14.89          2.74     NaN  ...                      NaN
# 2               9.89          5.64     NaN  ...                      NaN
# 3              10.62          2.09     NaN  ...                      NaN
# 4               9.89          2.60     NaN  ...                      NaN
# ...              ...           ...     ...  ...                      ...
# 6409           40.23          4.49    0.18  ...                      NaN
# 6410           82.13         14.36    0.20  ...                      100
# 6411           43.99          3.80    0.04  ...                      NaN
# 6412          118.67          9.98   23.54  ...                      NaN
# 6413          264.96         69.69    0.42  ...                      NaN
#
#       SERVICE TYPE  USER SATISFACTION CONNECTION TYPE  \
# 0              NaN                NaN             NaN
# 1              NaN                NaN             NaN
# 2              NaN                NaN             NaN
# 3              NaN                NaN             NaN
# 4              NaN                NaN             NaN
# ...            ...                ...             ...
# 6409           NaN                NaN             NaN
# 6410          Home                4.0             DSL
# 6411           NaN                NaN             NaN
# 6412           NaN                NaN             NaN
# 6413           NaN                NaN             NaN
#
#                             USER COMMENTS HEATMAP_MUNICIPALITY  \
# 0                                     NaN             Winnipeg
# 1                                     NaN             Winnipeg
# 2                                     NaN             Winnipeg
# 3                                     NaN             Winnipeg
# 4                                     NaN             Winnipeg
# ...                                   ...                  ...
# 6409                                  NaN             Winnipeg
# 6410  internet price promotion paying $40             Winnipeg
# 6411                                  NaN             Winnipeg
# 6412                                  NaN             Winnipeg
# 6413                                  NaN             Winnipeg
#
#      HEATMAP_CENSUS_TRACTS HEATMAP_PROJECT_AREA   TEST DATE  TEST TIME
# 0               6020537.02                  NaN   5/23/2015      10:00
# 1               6020522.02                  NaN   5/20/2015      10:01
# 2               6020014.00                  NaN   5/19/2015      10:00
# 3               6020501.02                  NaN   5/24/2015      10:00
# 4               6020016.00                  NaN   5/19/2015      10:00
# ...                    ...                  ...         ...        ...
# 6409            6020041.00                  R2W  12/10/2022       5:15
# 6410            6020510.06                  NaN  12/10/2022      13:29
# 6411            6020050.02                  NaN  12/10/2022      13:38
# 6412            6020500.13                  NaN  12/10/2022      17:57
# 6413            6020553.00                  NaN  12/10/2022      23:31
#
# [6414 rows x 36 columns]

# %%
# Drop / Remove the column titled 'index' AND SAVE IT IN THE SAME DATAFRAME OBJECT.

northEndConnect_dropREPEATED_DAILYTEST.drop(labels = ['index'], axis = 1, inplace = True)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
northEndConnect_dropREPEATED_DAILYTEST
# Out:
#         TEST ID  YEAR MONTH DAY  GEO LATITUDE  GEO LONGITUDE  DOWNLOAD SPEED  \
# 0         261.0  2015     5  23     49.869556     -97.296739           16.22
# 1         284.0  2015     5  20     49.852738     -97.270058           14.89
# 2         622.0  2015     5  19     49.887575     -97.140091            9.89
# 3         701.0  2015     5  24     49.814284     -97.160235           10.62
# 4         707.0  2015     5  19     49.882706     -97.161829            9.89
# ...         ...   ...   ...  ..           ...            ...             ...
# 6409  1615719.0  2022    12  10     49.919200     -97.126300           40.23
# 6410  1615791.0  2022    12  10     49.829862     -97.185759           82.13
# 6411  1615795.0  2022    12  10     49.931980     -97.180791           43.99
# 6412  1615849.0  2022    12  10     49.774494     -97.187254          118.67
# 6413  1615978.0  2022    12  10     49.951400     -97.113300          264.96
#
#       UPLOAD SPEED  JITTER  LATENCY  ...  CONTRACTED MONTHLY COST  \
# 0             2.79     NaN      NaN  ...                      NaN
# 1             2.74     NaN      NaN  ...                      NaN
# 2             5.64     NaN      NaN  ...                      NaN
# 3             2.09     NaN      NaN  ...                      NaN
# 4             2.60     NaN      NaN  ...                      NaN
# ...            ...     ...      ...  ...                      ...
# 6409          4.49    0.18    59.98  ...                      NaN
# 6410         14.36    0.20    53.23  ...                      100
# 6411          3.80    0.04    44.40  ...                      NaN
# 6412          9.98   23.54    71.83  ...                      NaN
# 6413         69.69    0.42    68.67  ...                      NaN
#
#       SERVICE TYPE USER SATISFACTION CONNECTION TYPE  \
# 0              NaN               NaN             NaN
# 1              NaN               NaN             NaN
# 2              NaN               NaN             NaN
# 3              NaN               NaN             NaN
# 4              NaN               NaN             NaN
# ...            ...               ...             ...
# 6409           NaN               NaN             NaN
# 6410          Home               4.0             DSL
# 6411           NaN               NaN             NaN
# 6412           NaN               NaN             NaN
# 6413           NaN               NaN             NaN
#
#                             USER COMMENTS HEATMAP_MUNICIPALITY  \
# 0                                     NaN             Winnipeg
# 1                                     NaN             Winnipeg
# 2                                     NaN             Winnipeg
# 3                                     NaN             Winnipeg
# 4                                     NaN             Winnipeg
# ...                                   ...                  ...
# 6409                                  NaN             Winnipeg
# 6410  internet price promotion paying $40             Winnipeg
# 6411                                  NaN             Winnipeg
# 6412                                  NaN             Winnipeg
# 6413                                  NaN             Winnipeg
#
#      HEATMAP_CENSUS_TRACTS HEATMAP_PROJECT_AREA   TEST DATE  TEST TIME
# 0               6020537.02                  NaN   5/23/2015      10:00
# 1               6020522.02                  NaN   5/20/2015      10:01
# 2               6020014.00                  NaN   5/19/2015      10:00
# 3               6020501.02                  NaN   5/24/2015      10:00
# 4               6020016.00                  NaN   5/19/2015      10:00
# ...                    ...                  ...         ...        ...
# 6409            6020041.00                  R2W  12/10/2022       5:15
# 6410            6020510.06                  NaN  12/10/2022      13:29
# 6411            6020050.02                  NaN  12/10/2022      13:38
# 6412            6020500.13                  NaN  12/10/2022      17:57
# 6413            6020553.00                  NaN  12/10/2022      23:31
#
# [6414 rows x 35 columns]

# %%
# creating a CSV file

northEndConnect_dropREPEATED_DAILYTEST.to_csv("northEndConnect_dropREPEATED_DAILYTEST.csv")

# %%
# Display information about the DataFrame.

northEndConnect_dropREPEATED_DAILYTEST.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6414 entries, 0 to 6413
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   TEST ID                    6414 non-null   float64
#  1   YEAR                       6414 non-null   object
#  2   MONTH                      6414 non-null   object
#  3   DAY                        6414 non-null   object
#  4   GEO LATITUDE               6414 non-null   float64
#  5   GEO LONGITUDE              6414 non-null   float64
#  6   DOWNLOAD SPEED             6414 non-null   float64
#  7   UPLOAD SPEED               6414 non-null   float64
#  8   JITTER                     3227 non-null   float64
#  9   LATENCY                    3227 non-null   float64
#  10  PACKET LOSS                3227 non-null   float64
#  11  MOBILE TEST                6414 non-null   bool
#  12  ISP                        6413 non-null   object
#  13  CLIENT IP                  6414 non-null   object
#  14  CLIENT CITY                6393 non-null   object
#  15  CLIENT PROVINCE            6381 non-null   object
#  16  CLIENT POSTAL CODE         6403 non-null   object
#  17  AS NUMBER                  6400 non-null   object
#  18  IPV6 SUPPORTED             6414 non-null   bool
#  19  DNSSEC SUPPORTED           6414 non-null   bool
#  20  TEST SERVER                6414 non-null   object
#  21  browser_test_url           3735 non-null   object
#  22  CONTRACTED DOWNLOAD SPEED  1202 non-null   object
#  23  CONTRACTED UPLOAD SPEED    674 non-null    object
#  24  CONTRACTED DATA CAP        512 non-null    object
#  25  CONTRACTED MONTHLY COST    1110 non-null   object
#  26  SERVICE TYPE               1556 non-null   object
#  27  USER SATISFACTION          1152 non-null   float64
#  28  CONNECTION TYPE            537 non-null    object
#  29  USER COMMENTS              1834 non-null   object
#  30  HEATMAP_MUNICIPALITY       6414 non-null   object
#  31  HEATMAP_CENSUS_TRACTS      6414 non-null   float64
#  32  HEATMAP_PROJECT_AREA       321 non-null    object
#  33  TEST DATE                  6414 non-null   object
#  34  TEST TIME                  6414 non-null   object
# dtypes: bool(3), float64(10), object(22)
# memory usage: 1.6+ MB

# %%
# Check the percentage of missing data in the new dataframe

northEndConnect_dropREPEATED_DAILYTEST.isnull().sum()/len(northEndConnect_dropREPEATED_DAILYTEST)*100
# Out:
# TEST ID                       0.000000
# YEAR                          0.000000
# MONTH                         0.000000
# DAY                           0.000000
# GEO LATITUDE                  0.000000
# GEO LONGITUDE                 0.000000
# DOWNLOAD SPEED                0.000000
# UPLOAD SPEED                  0.000000
# JITTER                       49.688182
# LATENCY                      49.688182
# PACKET LOSS                  49.688182
# MOBILE TEST                   0.000000
# ISP                           0.015591
# CLIENT IP                     0.000000
# CLIENT CITY                   0.327409
# CLIENT PROVINCE               0.514500
# CLIENT POSTAL CODE            0.171500
# AS NUMBER                     0.218273
# IPV6 SUPPORTED                0.000000
# DNSSEC SUPPORTED              0.000000
# TEST SERVER                   0.000000
# browser_test_url             41.768007
# CONTRACTED DOWNLOAD SPEED    81.259744
# CONTRACTED UPLOAD SPEED      89.491737
# CONTRACTED DATA CAP          92.017462
# CONTRACTED MONTHLY COST      82.694107
# SERVICE TYPE                 75.740568
# USER SATISFACTION            82.039289
# CONNECTION TYPE              91.627689
# USER COMMENTS                71.406299
# HEATMAP_MUNICIPALITY          0.000000
# HEATMAP_CENSUS_TRACTS         0.000000
# HEATMAP_PROJECT_AREA         94.995323
# TEST DATE                     0.000000
# TEST TIME                     0.000000
# dtype: float64

# %% [markdown]
# ## Filter for City values that have Winnipeg. Filter from 2019 upwards

# %%
WinnipegArea = northEndConnect_dropREPEATED_DAILYTEST[northEndConnect_dropREPEATED_DAILYTEST['CLIENT CITY'].str.contains('Winnipeg', case = False, na = False)]

# %%
WinnipegArea
# Out:
#         TEST ID  YEAR MONTH DAY  GEO LATITUDE  GEO LONGITUDE  DOWNLOAD SPEED  \
# 0         261.0  2015     5  23     49.869556     -97.296739           16.22
# 1         284.0  2015     5  20     49.852738     -97.270058           14.89
# 2         622.0  2015     5  19     49.887575     -97.140091            9.89
# 3         701.0  2015     5  24     49.814284     -97.160235           10.62
# 4         707.0  2015     5  19     49.882706     -97.161829            9.89
# ...         ...   ...   ...  ..           ...            ...             ...
# 6409  1615719.0  2022    12  10     49.919200     -97.126300           40.23
# 6410  1615791.0  2022    12  10     49.829862     -97.185759           82.13
# 6411  1615795.0  2022    12  10     49.931980     -97.180791           43.99
# 6412  1615849.0  2022    12  10     49.774494     -97.187254          118.67
# 6413  1615978.0  2022    12  10     49.951400     -97.113300          264.96
#
#       UPLOAD SPEED  JITTER  LATENCY  ...  CONTRACTED MONTHLY COST  \
# 0             2.79     NaN      NaN  ...                      NaN
# 1             2.74     NaN      NaN  ...                      NaN
# 2             5.64     NaN      NaN  ...                      NaN
# 3             2.09     NaN      NaN  ...                      NaN
# 4             2.60     NaN      NaN  ...                      NaN
# ...            ...     ...      ...  ...                      ...
# 6409          4.49    0.18    59.98  ...                      NaN
# 6410         14.36    0.20    53.23  ...                      100
# 6411          3.80    0.04    44.40  ...                      NaN
# 6412          9.98   23.54    71.83  ...                      NaN
# 6413         69.69    0.42    68.67  ...                      NaN
#
#       SERVICE TYPE USER SATISFACTION CONNECTION TYPE  \
# 0              NaN               NaN             NaN
# 1              NaN               NaN             NaN
# 2              NaN               NaN             NaN
# 3              NaN               NaN             NaN
# 4              NaN               NaN             NaN
# ...            ...               ...             ...
# 6409           NaN               NaN             NaN
# 6410          Home               4.0             DSL
# 6411           NaN               NaN             NaN
# 6412           NaN               NaN             NaN
# 6413           NaN               NaN             NaN
#
#                             USER COMMENTS HEATMAP_MUNICIPALITY  \
# 0                                     NaN             Winnipeg
# 1                                     NaN             Winnipeg
# 2                                     NaN             Winnipeg
# 3                                     NaN             Winnipeg
# 4                                     NaN             Winnipeg
# ...                                   ...                  ...
# 6409                                  NaN             Winnipeg
# 6410  internet price promotion paying $40             Winnipeg
# 6411                                  NaN             Winnipeg
# 6412                                  NaN             Winnipeg
# 6413                                  NaN             Winnipeg
#
#      HEATMAP_CENSUS_TRACTS HEATMAP_PROJECT_AREA   TEST DATE  TEST TIME
# 0               6020537.02                  NaN   5/23/2015      10:00
# 1               6020522.02                  NaN   5/20/2015      10:01
# 2               6020014.00                  NaN   5/19/2015      10:00
# 3               6020501.02                  NaN   5/24/2015      10:00
# 4               6020016.00                  NaN   5/19/2015      10:00
# ...                    ...                  ...         ...        ...
# 6409            6020041.00                  R2W  12/10/2022       5:15
# 6410            6020510.06                  NaN  12/10/2022      13:29
# 6411            6020050.02                  NaN  12/10/2022      13:38
# 6412            6020500.13                  NaN  12/10/2022      17:57
# 6413            6020553.00                  NaN  12/10/2022      23:31
#
# [6053 rows x 35 columns]

# %%
# Checking to make sure only Client City names containing Winnipeg are retrieved

WinnipegArea['CLIENT CITY'].unique()
# Out:
# array(['Winnipeg', 'Winnipeg (Portage & Main)',
#        'Winnipeg (Tuxedo Industrials)', 'Winnipeg (Downtown)',
#        'Winnipeg (Sir John Franklin)', 'Winnipeg (Earl Grey)',
#        'Winnipeg (Kildare - Redonda)'], dtype=object)

# %%
# Extracting Winnipeg Area data from 2019 upwards

WinnipegArea_from2019 = WinnipegArea[WinnipegArea['YEAR'] >= '2019'] 

# Reset the index. Save change in same DataFrame object.
WinnipegArea_from2019.reset_index(inplace = True)

# Delete the column titled "index".Save change in same DataFrame object.
WinnipegArea_from2019.drop(columns = ['index'], inplace = True)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
WinnipegArea_from2019
# Out:
#         TEST ID  YEAR MONTH DAY  GEO LATITUDE  GEO LONGITUDE  DOWNLOAD SPEED  \
# 0      720944.0  2019     1   1     49.898256     -97.137208            6.03
# 1      721229.0  2019     1   2     49.917298     -97.080932          376.89
# 2      721330.0  2019     1   3     49.904890     -97.072620          214.95
# 3      721410.0  2019     1   3     49.850816     -97.071719           29.61
# 4      721902.0  2019     1   4     49.881523     -97.142242            0.57
# ...         ...   ...   ...  ..           ...            ...             ...
# 3434  1615719.0  2022    12  10     49.919200     -97.126300           40.23
# 3435  1615791.0  2022    12  10     49.829862     -97.185759           82.13
# 3436  1615795.0  2022    12  10     49.931980     -97.180791           43.99
# 3437  1615849.0  2022    12  10     49.774494     -97.187254          118.67
# 3438  1615978.0  2022    12  10     49.951400     -97.113300          264.96
#
#       UPLOAD SPEED  JITTER  LATENCY  ...  CONTRACTED MONTHLY COST  \
# 0             2.22     NaN      NaN  ...                      100
# 1            15.96     NaN      NaN  ...                      NaN
# 2            10.64     NaN      NaN  ...                      110
# 3            15.71     NaN      NaN  ...                      NaN
# 4            14.06     NaN      NaN  ...                      NaN
# ...            ...     ...      ...  ...                      ...
# 3434          4.49    0.18    59.98  ...                      NaN
# 3435         14.36    0.20    53.23  ...                      100
# 3436          3.80    0.04    44.40  ...                      NaN
# 3437          9.98   23.54    71.83  ...                      NaN
# 3438         69.69    0.42    68.67  ...                      NaN
#
#       SERVICE TYPE USER SATISFACTION CONNECTION TYPE  \
# 0             Home               3.0             NaN
# 1             Home               NaN             NaN
# 2             Home               5.0             NaN
# 3              NaN               NaN             NaN
# 4             Home               NaN             NaN
# ...            ...               ...             ...
# 3434           NaN               NaN             NaN
# 3435          Home               4.0             DSL
# 3436           NaN               NaN             NaN
# 3437           NaN               NaN             NaN
# 3438           NaN               NaN             NaN
#
#                             USER COMMENTS HEATMAP_MUNICIPALITY  \
# 0                                    None             Winnipeg
# 1                                    None             Winnipeg
# 2                                    None             Winnipeg
# 3                                     NaN             Winnipeg
# 4                                    None             Winnipeg
# ...                                   ...                  ...
# 3434                                  NaN             Winnipeg
# 3435  internet price promotion paying $40             Winnipeg
# 3436                                  NaN             Winnipeg
# 3437                                  NaN             Winnipeg
# 3438                                  NaN             Winnipeg
#
#      HEATMAP_CENSUS_TRACTS HEATMAP_PROJECT_AREA   TEST DATE  TEST TIME
# 0               6020024.00                  NaN    1/1/2019      22:01
# 1               6020130.01                  NaN    1/2/2019      23:29
# 2               6020130.02                  NaN    1/3/2019      12:36
# 3               6020110.02                  NaN    1/3/2019      19:57
# 4               6020012.00                  NaN    1/4/2019      17:46
# ...                    ...                  ...         ...        ...
# 3434            6020041.00                  R2W  12/10/2022       5:15
# 3435            6020510.06                  NaN  12/10/2022      13:29
# 3436            6020050.02                  NaN  12/10/2022      13:38
# 3437            6020500.13                  NaN  12/10/2022      17:57
# 3438            6020553.00                  NaN  12/10/2022      23:31
#
# [3439 rows x 35 columns]

# %%
WinnipegArea_from2019.isnull().sum()/len(WinnipegArea_from2019)*100
# Out:
# TEST ID                       0.000000
# YEAR                          0.000000
# MONTH                         0.000000
# DAY                           0.000000
# GEO LATITUDE                  0.000000
# GEO LONGITUDE                 0.000000
# DOWNLOAD SPEED                0.000000
# UPLOAD SPEED                  0.000000
# JITTER                       11.253271
# LATENCY                      11.253271
# PACKET LOSS                  11.253271
# MOBILE TEST                   0.000000
# ISP                           0.000000
# CLIENT IP                     0.000000
# CLIENT CITY                   0.000000
# CLIENT PROVINCE               0.000000
# CLIENT POSTAL CODE            0.000000
# AS NUMBER                     0.000000
# IPV6 SUPPORTED                0.000000
# DNSSEC SUPPORTED              0.000000
# TEST SERVER                   0.000000
# browser_test_url              0.000000
# CONTRACTED DOWNLOAD SPEED    69.845885
# CONTRACTED UPLOAD SPEED      80.982844
# CONTRACTED DATA CAP          85.606281
# CONTRACTED MONTHLY COST      72.782786
# SERVICE TYPE                 63.332364
# USER SATISFACTION            71.328875
# CONNECTION TYPE              84.850247
# USER COMMENTS                55.888340
# HEATMAP_MUNICIPALITY          0.000000
# HEATMAP_CENSUS_TRACTS         0.000000
# HEATMAP_PROJECT_AREA         96.219831
# TEST DATE                     0.000000
# TEST TIME                     0.000000
# dtype: float64

# %%
# dropping the columns with percentage missing values greater than fifty (50) percent

WinnipegArea_from2019_ColumnsRemoved = WinnipegArea_from2019.drop(columns = ['CONTRACTED DOWNLOAD SPEED', 'CONTRACTED UPLOAD SPEED', 'CONTRACTED DATA CAP',
                                                 'CONTRACTED MONTHLY COST', 'SERVICE TYPE', 'USER SATISFACTION',
                                                 'CONNECTION TYPE', 'USER COMMENTS', 'HEATMAP_PROJECT_AREA'])

# %%
WinnipegArea_from2019_ColumnsRemoved
# Out:
#         TEST ID  YEAR MONTH DAY  GEO LATITUDE  GEO LONGITUDE  DOWNLOAD SPEED  \
# 0      720944.0  2019     1   1     49.898256     -97.137208            6.03
# 1      721229.0  2019     1   2     49.917298     -97.080932          376.89
# 2      721330.0  2019     1   3     49.904890     -97.072620          214.95
# 3      721410.0  2019     1   3     49.850816     -97.071719           29.61
# 4      721902.0  2019     1   4     49.881523     -97.142242            0.57
# ...         ...   ...   ...  ..           ...            ...             ...
# 3434  1615719.0  2022    12  10     49.919200     -97.126300           40.23
# 3435  1615791.0  2022    12  10     49.829862     -97.185759           82.13
# 3436  1615795.0  2022    12  10     49.931980     -97.180791           43.99
# 3437  1615849.0  2022    12  10     49.774494     -97.187254          118.67
# 3438  1615978.0  2022    12  10     49.951400     -97.113300          264.96
#
#       UPLOAD SPEED  JITTER  LATENCY  ...  CLIENT POSTAL CODE  AS NUMBER  \
# 0             2.22     NaN      NaN  ...              R3B0R4     AS7122
# 1            15.96     NaN      NaN  ...              R2K1S1     AS6327
# 2            10.64     NaN      NaN  ...              R2K3C9     AS6327
# 3            15.71     NaN      NaN  ...              R2J2V4     AS6327
# 4            14.06     NaN      NaN  ...              R3L0G1     AS6327
# ...            ...     ...      ...  ...                 ...        ...
# 3434          4.49    0.18    59.98  ...              R2W1E2     AS7122
# 3435         14.36    0.20    53.23  ...              R3P1S7     AS7122
# 3436          3.80    0.04    44.40  ...              R2X0S7      AS577
# 3437          9.98   23.54    71.83  ...              R3Y2B4     AS6327
# 3438         69.69    0.42    68.67  ...              R2V3J2     AS6327
#
#      IPV6 SUPPORTED DNSSEC SUPPORTED TEST SERVER  \
# 0              True            False     Toronto
# 1              True            False     Toronto
# 2             False            False    Winnipeg
# 3             False            False    Winnipeg
# 4             False            False    Winnipeg
# ...             ...              ...         ...
# 3434          False            False     Toronto
# 3435          False             True     Toronto
# 3436          False            False     Toronto
# 3437           True            False     Toronto
# 3438           True            False     Toronto
#
#                                        browser_test_url HEATMAP_MUNICIPALITY  \
# 0     https://performance.cira.ca/? ga 2.196819116.1...             Winnipeg
# 1                          https://performance.cira.ca/             Winnipeg
# 2                          https://performance.cira.ca/             Winnipeg
# 3     https://performance.cira.ca/? ga 2.100004318.1...             Winnipeg
# 4                          https://performance.cira.ca/             Winnipeg
# ...                                                 ...                  ...
# 3434                   https://performance.cira.ca/mini             Winnipeg
# 3435                       https://performance.cira.ca/             Winnipeg
# 3436                        http://performance.cira.ca/             Winnipeg
# 3437  https://performance.cira.ca/?utm_campaign=corp...             Winnipeg
# 3438                   https://performance.cira.ca/mini             Winnipeg
#
#      HEATMAP_CENSUS_TRACTS   TEST DATE  TEST TIME
# 0               6020024.00    1/1/2019      22:01
# 1               6020130.01    1/2/2019      23:29
# 2               6020130.02    1/3/2019      12:36
# 3               6020110.02    1/3/2019      19:57
# 4               6020012.00    1/4/2019      17:46
# ...                    ...         ...        ...
# 3434            6020041.00  12/10/2022       5:15
# 3435            6020510.06  12/10/2022      13:29
# 3436            6020050.02  12/10/2022      13:38
# 3437            6020500.13  12/10/2022      17:57
# 3438            6020553.00  12/10/2022      23:31
#
# [3439 rows x 26 columns]

# %%
WinnipegArea_from2019_ColumnsRemoved.isnull().sum()/len(WinnipegArea_from2019_ColumnsRemoved)*100
# Out:
# TEST ID                   0.000000
# YEAR                      0.000000
# MONTH                     0.000000
# DAY                       0.000000
# GEO LATITUDE              0.000000
# GEO LONGITUDE             0.000000
# DOWNLOAD SPEED            0.000000
# UPLOAD SPEED              0.000000
# JITTER                   11.253271
# LATENCY                  11.253271
# PACKET LOSS              11.253271
# MOBILE TEST               0.000000
# ISP                       0.000000
# CLIENT IP                 0.000000
# CLIENT CITY               0.000000
# CLIENT PROVINCE           0.000000
# CLIENT POSTAL CODE        0.000000
# AS NUMBER                 0.000000
# IPV6 SUPPORTED            0.000000
# DNSSEC SUPPORTED          0.000000
# TEST SERVER               0.000000
# browser_test_url          0.000000
# HEATMAP_MUNICIPALITY      0.000000
# HEATMAP_CENSUS_TRACTS     0.000000
# TEST DATE                 0.000000
# TEST TIME                 0.000000
# dtype: float64

# %%
# Creating a CSV file of the Filtered data -- Winnipeg Only, from 2019, No Totally empty columns, no daily repeated IP Address tests

WinnipegArea_2019upwards_NoBlankColumns_NoDailyTestRepeat = WinnipegArea_from2019_ColumnsRemoved

WinnipegArea_2019upwards_NoBlankColumns_NoDailyTestRepeat.to_csv('WinnipegArea_2019upwards_NoBlankColumns_NoDailyTestRepeat.csv')

# %%
# Removing the rows/record that is missing a value for any field

WinnipegAreaData_from2019_NoMissingDataPoint = WinnipegArea_from2019_ColumnsRemoved 

WinnipegAreaData_from2019_NoMissingDataPoint.dropna(inplace = True)

# %%
WinnipegAreaData_from2019_NoMissingDataPoint
# Out:
#         TEST ID  YEAR MONTH DAY  GEO LATITUDE  GEO LONGITUDE  DOWNLOAD SPEED  \
# 336    805747.0  2019     9  15     49.908017     -97.069539          193.17
# 337    805777.0  2019     9  15     49.855453     -97.287733           57.92
# 338    805828.0  2019     9  16     49.821856     -97.195052            2.17
# 342    808371.0  2019     9  21     49.869896     -97.155372           14.34
# 350    810587.0  2019     9  29     49.877336     -97.182648            2.33
# ...         ...   ...   ...  ..           ...            ...             ...
# 3434  1615719.0  2022    12  10     49.919200     -97.126300           40.23
# 3435  1615791.0  2022    12  10     49.829862     -97.185759           82.13
# 3436  1615795.0  2022    12  10     49.931980     -97.180791           43.99
# 3437  1615849.0  2022    12  10     49.774494     -97.187254          118.67
# 3438  1615978.0  2022    12  10     49.951400     -97.113300          264.96
#
#       UPLOAD SPEED  JITTER  LATENCY  ...  CLIENT POSTAL CODE  AS NUMBER  \
# 336          19.75    1.48    34.36  ...              R2K3L4     AS6327
# 337          16.05    2.81    40.71  ...              R3R1E6     AS6327
# 338          10.92   11.99    51.75  ...              R3Y0R3     AS6327
# 342           3.74    2.07    62.16  ...              R3M0Y3     AS7122
# 350           1.82   29.84    72.49  ...              R3N0A2     AS7122
# ...            ...     ...      ...  ...                 ...        ...
# 3434          4.49    0.18    59.98  ...              R2W1E2     AS7122
# 3435         14.36    0.20    53.23  ...              R3P1S7     AS7122
# 3436          3.80    0.04    44.40  ...              R2X0S7      AS577
# 3437          9.98   23.54    71.83  ...              R3Y2B4     AS6327
# 3438         69.69    0.42    68.67  ...              R2V3J2     AS6327
#
#      IPV6 SUPPORTED DNSSEC SUPPORTED TEST SERVER  \
# 336            True            False    Winnipeg
# 337            True            False    Winnipeg
# 338           False            False   Vancouver
# 342           False            False    Winnipeg
# 350           False            False    Winnipeg
# ...             ...              ...         ...
# 3434          False            False     Toronto
# 3435          False             True     Toronto
# 3436          False            False     Toronto
# 3437           True            False     Toronto
# 3438           True            False     Toronto
#
#                                        browser_test_url HEATMAP_MUNICIPALITY  \
# 336                        https://performance.cira.ca/             Winnipeg
# 337                        https://performance.cira.ca/             Winnipeg
# 338                        https://performance.cira.ca/             Winnipeg
# 342                        https://performance.cira.ca/             Winnipeg
# 350                        https://performance.cira.ca/             Winnipeg
# ...                                                 ...                  ...
# 3434                   https://performance.cira.ca/mini             Winnipeg
# 3435                       https://performance.cira.ca/             Winnipeg
# 3436                        http://performance.cira.ca/             Winnipeg
# 3437  https://performance.cira.ca/?utm_campaign=corp...             Winnipeg
# 3438                   https://performance.cira.ca/mini             Winnipeg
#
#      HEATMAP_CENSUS_TRACTS   TEST DATE  TEST TIME
# 336             6020130.02   9/15/2019      16:46
# 337             6020521.01   9/15/2019      20:08
# 338             6020500.11   9/16/2019       1:06
# 342             6020003.00   9/21/2019       4:22
# 350             6020008.00   9/29/2019      17:56
# ...                    ...         ...        ...
# 3434            6020041.00  12/10/2022       5:15
# 3435            6020510.06  12/10/2022      13:29
# 3436            6020050.02  12/10/2022      13:38
# 3437            6020500.13  12/10/2022      17:57
# 3438            6020553.00  12/10/2022      23:31
#
# [3052 rows x 26 columns]

# %%
WinnipegAreaData_from2019_NoMissingDataPoint.to_csv('WinnipegAreaData_from2019_NoMissingDataPoint.csv')

# %%
WinnipegAreaData_from2019_NoMissingDataPoint.shape
# Out:
# (3052, 26)

# %% [markdown]
# ## For the Winnipeg Area data, extract the Area Code from Postal Code

# %%
WinnipegAreaData_from2019_AreaCode = WinnipegAreaData_from2019_NoMissingDataPoint
WinnipegAreaData_from2019_AreaCode.dropna(inplace = True)

areaCode = []

for code in WinnipegAreaData_from2019_AreaCode['CLIENT POSTAL CODE']:
    aCode = code[:3]
    areaCode.append(aCode)
    
WinnipegAreaData_from2019_AreaCode["AREA CODE"] = areaCode

# %%
WinnipegAreaData_from2019_AreaCode
# Out:
#         TEST ID  YEAR MONTH DAY  GEO LATITUDE  GEO LONGITUDE  DOWNLOAD SPEED  \
# 336    805747.0  2019     9  15     49.908017     -97.069539          193.17
# 337    805777.0  2019     9  15     49.855453     -97.287733           57.92
# 338    805828.0  2019     9  16     49.821856     -97.195052            2.17
# 342    808371.0  2019     9  21     49.869896     -97.155372           14.34
# 350    810587.0  2019     9  29     49.877336     -97.182648            2.33
# ...         ...   ...   ...  ..           ...            ...             ...
# 3434  1615719.0  2022    12  10     49.919200     -97.126300           40.23
# 3435  1615791.0  2022    12  10     49.829862     -97.185759           82.13
# 3436  1615795.0  2022    12  10     49.931980     -97.180791           43.99
# 3437  1615849.0  2022    12  10     49.774494     -97.187254          118.67
# 3438  1615978.0  2022    12  10     49.951400     -97.113300          264.96
#
#       UPLOAD SPEED  JITTER  LATENCY  ...  AS NUMBER  IPV6 SUPPORTED  \
# 336          19.75    1.48    34.36  ...     AS6327            True
# 337          16.05    2.81    40.71  ...     AS6327            True
# 338          10.92   11.99    51.75  ...     AS6327           False
# 342           3.74    2.07    62.16  ...     AS7122           False
# 350           1.82   29.84    72.49  ...     AS7122           False
# ...            ...     ...      ...  ...        ...             ...
# 3434          4.49    0.18    59.98  ...     AS7122           False
# 3435         14.36    0.20    53.23  ...     AS7122           False
# 3436          3.80    0.04    44.40  ...      AS577           False
# 3437          9.98   23.54    71.83  ...     AS6327            True
# 3438         69.69    0.42    68.67  ...     AS6327            True
#
#      DNSSEC SUPPORTED TEST SERVER  \
# 336             False    Winnipeg
# 337             False    Winnipeg
# 338             False   Vancouver
# 342             False    Winnipeg
# 350             False    Winnipeg
# ...               ...         ...
# 3434            False     Toronto
# 3435             True     Toronto
# 3436            False     Toronto
# 3437            False     Toronto
# 3438            False     Toronto
#
#                                        browser_test_url HEATMAP_MUNICIPALITY  \
# 336                        https://performance.cira.ca/             Winnipeg
# 337                        https://performance.cira.ca/             Winnipeg
# 338                        https://performance.cira.ca/             Winnipeg
# 342                        https://performance.cira.ca/             Winnipeg
# 350                        https://performance.cira.ca/             Winnipeg
# ...                                                 ...                  ...
# 3434                   https://performance.cira.ca/mini             Winnipeg
# 3435                       https://performance.cira.ca/             Winnipeg
# 3436                        http://performance.cira.ca/             Winnipeg
# 3437  https://performance.cira.ca/?utm_campaign=corp...             Winnipeg
# 3438                   https://performance.cira.ca/mini             Winnipeg
#
#      HEATMAP_CENSUS_TRACTS   TEST DATE  TEST TIME  AREA CODE
# 336             6020130.02   9/15/2019      16:46        R2K
# 337             6020521.01   9/15/2019      20:08        R3R
# 338             6020500.11   9/16/2019       1:06        R3Y
# 342             6020003.00   9/21/2019       4:22        R3M
# 350             6020008.00   9/29/2019      17:56        R3N
# ...                    ...         ...        ...        ...
# 3434            6020041.00  12/10/2022       5:15        R2W
# 3435            6020510.06  12/10/2022      13:29        R3P
# 3436            6020050.02  12/10/2022      13:38        R2X
# 3437            6020500.13  12/10/2022      17:57        R3Y
# 3438            6020553.00  12/10/2022      23:31        R2V
#
# [3052 rows x 27 columns]

# %%
# Reset the index

WinnipegAreaData_from2019_AreaCode.reset_index(inplace=True)

# Drop the 'index' column

WinnipegAreaData_from2019_AreaCode.drop(columns = ['index'], inplace = True)

# %%
WinnipegAreaData_from2019_AreaCode
# Out:
#         TEST ID  YEAR MONTH DAY  GEO LATITUDE  GEO LONGITUDE  DOWNLOAD SPEED  \
# 0      805747.0  2019     9  15     49.908017     -97.069539          193.17
# 1      805777.0  2019     9  15     49.855453     -97.287733           57.92
# 2      805828.0  2019     9  16     49.821856     -97.195052            2.17
# 3      808371.0  2019     9  21     49.869896     -97.155372           14.34
# 4      810587.0  2019     9  29     49.877336     -97.182648            2.33
# ...         ...   ...   ...  ..           ...            ...             ...
# 3047  1615719.0  2022    12  10     49.919200     -97.126300           40.23
# 3048  1615791.0  2022    12  10     49.829862     -97.185759           82.13
# 3049  1615795.0  2022    12  10     49.931980     -97.180791           43.99
# 3050  1615849.0  2022    12  10     49.774494     -97.187254          118.67
# 3051  1615978.0  2022    12  10     49.951400     -97.113300          264.96
#
#       UPLOAD SPEED  JITTER  LATENCY  ...  AS NUMBER  IPV6 SUPPORTED  \
# 0            19.75    1.48    34.36  ...     AS6327            True
# 1            16.05    2.81    40.71  ...     AS6327            True
# 2            10.92   11.99    51.75  ...     AS6327           False
# 3             3.74    2.07    62.16  ...     AS7122           False
# 4             1.82   29.84    72.49  ...     AS7122           False
# ...            ...     ...      ...  ...        ...             ...
# 3047          4.49    0.18    59.98  ...     AS7122           False
# 3048         14.36    0.20    53.23  ...     AS7122           False
# 3049          3.80    0.04    44.40  ...      AS577           False
# 3050          9.98   23.54    71.83  ...     AS6327            True
# 3051         69.69    0.42    68.67  ...     AS6327            True
#
#      DNSSEC SUPPORTED TEST SERVER  \
# 0               False    Winnipeg
# 1               False    Winnipeg
# 2               False   Vancouver
# 3               False    Winnipeg
# 4               False    Winnipeg
# ...               ...         ...
# 3047            False     Toronto
# 3048             True     Toronto
# 3049            False     Toronto
# 3050            False     Toronto
# 3051            False     Toronto
#
#                                        browser_test_url HEATMAP_MUNICIPALITY  \
# 0                          https://performance.cira.ca/             Winnipeg
# 1                          https://performance.cira.ca/             Winnipeg
# 2                          https://performance.cira.ca/             Winnipeg
# 3                          https://performance.cira.ca/             Winnipeg
# 4                          https://performance.cira.ca/             Winnipeg
# ...                                                 ...                  ...
# 3047                   https://performance.cira.ca/mini             Winnipeg
# 3048                       https://performance.cira.ca/             Winnipeg
# 3049                        http://performance.cira.ca/             Winnipeg
# 3050  https://performance.cira.ca/?utm_campaign=corp...             Winnipeg
# 3051                   https://performance.cira.ca/mini             Winnipeg
#
#      HEATMAP_CENSUS_TRACTS   TEST DATE  TEST TIME  AREA CODE
# 0               6020130.02   9/15/2019      16:46        R2K
# 1               6020521.01   9/15/2019      20:08        R3R
# 2               6020500.11   9/16/2019       1:06        R3Y
# 3               6020003.00   9/21/2019       4:22        R3M
# 4               6020008.00   9/29/2019      17:56        R3N
# ...                    ...         ...        ...        ...
# 3047            6020041.00  12/10/2022       5:15        R2W
# 3048            6020510.06  12/10/2022      13:29        R3P
# 3049            6020050.02  12/10/2022      13:38        R2X
# 3050            6020500.13  12/10/2022      17:57        R3Y
# 3051            6020553.00  12/10/2022      23:31        R2V
#
# [3052 rows x 27 columns]

# %%
WinnipegAreaData_from2019_AreaCode.to_csv("WinnipegAreaData_from2019_AreaCode.csv")

# %%
# At this point, We have a dataset for the Winnipeg Region from 2019 onwards.
# The dataset does not contain any missing values as shown below

WinnipegAreaData_from2019_AreaCode.isnull().sum()/len(WinnipegAreaData_from2019_AreaCode)*100
# Out:
# TEST ID                  0.0
# YEAR                     0.0
# MONTH                    0.0
# DAY                      0.0
# GEO LATITUDE             0.0
# GEO LONGITUDE            0.0
# DOWNLOAD SPEED           0.0
# UPLOAD SPEED             0.0
# JITTER                   0.0
# LATENCY                  0.0
# PACKET LOSS              0.0
# MOBILE TEST              0.0
# ISP                      0.0
# CLIENT IP                0.0
# CLIENT CITY              0.0
# CLIENT PROVINCE          0.0
# CLIENT POSTAL CODE       0.0
# AS NUMBER                0.0
# IPV6 SUPPORTED           0.0
# DNSSEC SUPPORTED         0.0
# TEST SERVER              0.0
# browser_test_url         0.0
# HEATMAP_MUNICIPALITY     0.0
# HEATMAP_CENSUS_TRACTS    0.0
# TEST DATE                0.0
# TEST TIME                0.0
# AREA CODE                0.0
# dtype: float64

# %%
WinnipegAreaData_from2019_AreaCode.groupby('ISP').YEAR.value_counts().unstack()
# Out:
# YEAR                                                2019   2020   2021   2022
# ISP
# ACN                                                  NaN    NaN    1.0    3.0
# Access Communications Co-operative Limited           NaN    3.0    NaN    1.0
# Akamai Technologies, Inc.                            NaN    NaN    NaN    6.0
# Alberta Health Services                              NaN    3.0    NaN    NaN
# Altima Telecom                                       1.0    6.0    3.0    7.0
# BH Telecom Corp.                                     NaN    1.0    NaN    1.0
# BIGPIPE                                              NaN    1.0    1.0    NaN
# Bell Canada                                          1.0  130.0  315.0  365.0
# Bell MTS                                            16.0  108.0    9.0   10.0
# Bell MTS Data Centres G.P                            NaN    NaN    1.0    NaN
# CIK Telecom                                          NaN   10.0    9.0    3.0
# Cipherkey Exchange Corp.                             NaN    6.0   11.0   12.0
# City of Winnipeg                                     NaN    1.0    1.0    1.0
# Cloudflare, Inc.                                     NaN    NaN    1.0   11.0
# Corridor Communications                              NaN    1.0    1.0    3.0
# Epic Information Solutions                           NaN    NaN    NaN    1.0
# Fastnet Communications                               NaN    1.0    2.0    2.0
# Full Throttle Networks                               NaN    5.0    3.0    2.0
# Hutterian Broadband Network Inc                      NaN    NaN    1.0    NaN
# LES.NET                                              NaN    1.0    2.0    3.0
# MERLIN                                               NaN    5.0    6.0   16.0
# MRNet                                                NaN    NaN    1.0    NaN
# MTS Inc                                              NaN    1.0    NaN    NaN
# Manitoba First Nations Education Resource Centre     NaN    NaN    NaN    1.0
# Manitoba Hydro                                       NaN    2.0    NaN    4.0
# Oxio                                                 NaN    NaN    NaN    2.0
# Postmedia Network                                    NaN    1.0    NaN    NaN
# Prairie-Sky Wireless                                 NaN    NaN    5.0    NaN
# Primus Telecommunications Canada Inc.                NaN    7.0   11.0    7.0
# Questzone.Net, Inc.                                  NaN    1.0    NaN    NaN
# RBC Convention Centre Winnipeg                       NaN    1.0    NaN    NaN
# Red River College of Applied Arts, Science and Tec   NaN    1.0    NaN    NaN
# Rogers Cable                                         NaN    3.0    1.0    1.0
# Shaw Communications                                 32.0  508.0  527.0  496.0
# South Winnipeg Technical Centre                      NaN    1.0    NaN    NaN
# SpaceX Starlink                                      NaN    3.0   61.0   33.0
# Stafford Communications, Inc.                        NaN    1.0    NaN    NaN
# Swift High Speed.com                                 NaN    NaN    NaN    1.0
# TekSavvy Solutions, Inc.                             1.0   10.0   25.0   28.0
# Telus Communications                                 NaN    1.0    NaN    NaN
# TeraGo Networks                                      NaN    1.0    NaN    NaN
# The Exchange Global Server Center                    NaN    2.0    1.0    1.0
# University of Manitoba                               NaN    9.0    6.0    4.0
# ViaNetTV Inc                                         NaN    7.0    1.0    7.0
# Voyageur Internet                                    NaN    4.0    1.0    1.0
# WiBand Communications                                1.0    NaN    NaN    NaN
# Xplornet Communications                              NaN   73.0   32.0    9.0

# %%
WinnipegAreaData_from2019_AreaCode.groupby('YEAR').YEAR.value_counts().unstack()
# Out:
# YEAR  2019   2020    2021    2022
# YEAR
# 2019  52.0    NaN     NaN     NaN
# 2020   NaN  919.0     NaN     NaN
# 2021   NaN    NaN  1039.0     NaN
# 2022   NaN    NaN     NaN  1042.0

# %%
# A comparison of the total number of tests performed per IP address on a monthly basis over the years. 

WinnipegAreaData_from2019_AreaCode.groupby('YEAR').YEAR.value_counts().unstack().plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='YEAR'>

# %%
WinnipegAreaData_from2019_AreaCode.columns
# Out:
# Index(['TEST ID', 'YEAR', 'MONTH', 'DAY', 'GEO LATITUDE', 'GEO LONGITUDE',
#        'DOWNLOAD SPEED', 'UPLOAD SPEED', 'JITTER', 'LATENCY', 'PACKET LOSS',
#        'MOBILE TEST', 'ISP', 'CLIENT IP', 'CLIENT CITY', 'CLIENT PROVINCE',
#        'CLIENT POSTAL CODE', 'AS NUMBER', 'IPV6 SUPPORTED', 'DNSSEC SUPPORTED',
#        'TEST SERVER', 'browser_test_url', 'HEATMAP_MUNICIPALITY',
#        'HEATMAP_CENSUS_TRACTS', 'TEST DATE', 'TEST TIME', 'AREA CODE'],
#       dtype='object')

# %%
Winnipeg1 = WinnipegAreaData_from2019_AreaCode

Winnipeg1.groupby('MONTH').YEAR.value_counts().unstack().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='MONTH'>

# %%
Winnipeg1.groupby('MONTH').YEAR.value_counts().unstack().plot(kind='line')
# Out:
# <AxesSubplot:xlabel='MONTH'>

# %% [markdown]
# ### Categorize the Internet Service based on Upload and Download speeds, Jitter, Latency
# ### and Packet Loss

# %%
WinnipegArea_InternetCategory = WinnipegAreaData_from2019_AreaCode


InternetCategory = []

for value in range(len(WinnipegArea_InternetCategory)):
    if((WinnipegArea_InternetCategory.loc[value, 'DOWNLOAD SPEED'] >= 50) 
    and (WinnipegArea_InternetCategory.loc[value, 'UPLOAD SPEED'] >= 10) 
    and (WinnipegArea_InternetCategory.loc[value, 'JITTER'] <= 5) 
    and (WinnipegArea_InternetCategory.loc[value, 'LATENCY'] <= 50) 
    and (WinnipegArea_InternetCategory.loc[value, 'PACKET LOSS'] <= 0.25)):
        
        internetStatus = "High-Speed Internet"
        
    else:
        
        internetStatus = "Low-Speed Internet"
        
    InternetCategory.append(internetStatus) 
    
WinnipegArea_InternetCategory["INTERNET_CATEGORY"] = InternetCategory

# %%
WinnipegArea_InternetCategory
# Out:
#         TEST ID  YEAR MONTH DAY  GEO LATITUDE  GEO LONGITUDE  DOWNLOAD SPEED  \
# 0      805747.0  2019     9  15     49.908017     -97.069539          193.17
# 1      805777.0  2019     9  15     49.855453     -97.287733           57.92
# 2      805828.0  2019     9  16     49.821856     -97.195052            2.17
# 3      808371.0  2019     9  21     49.869896     -97.155372           14.34
# 4      810587.0  2019     9  29     49.877336     -97.182648            2.33
# ...         ...   ...   ...  ..           ...            ...             ...
# 3047  1615719.0  2022    12  10     49.919200     -97.126300           40.23
# 3048  1615791.0  2022    12  10     49.829862     -97.185759           82.13
# 3049  1615795.0  2022    12  10     49.931980     -97.180791           43.99
# 3050  1615849.0  2022    12  10     49.774494     -97.187254          118.67
# 3051  1615978.0  2022    12  10     49.951400     -97.113300          264.96
#
#       UPLOAD SPEED  JITTER  LATENCY  ...  IPV6 SUPPORTED  DNSSEC SUPPORTED  \
# 0            19.75    1.48    34.36  ...            True             False
# 1            16.05    2.81    40.71  ...            True             False
# 2            10.92   11.99    51.75  ...           False             False
# 3             3.74    2.07    62.16  ...           False             False
# 4             1.82   29.84    72.49  ...           False             False
# ...            ...     ...      ...  ...             ...               ...
# 3047          4.49    0.18    59.98  ...           False             False
# 3048         14.36    0.20    53.23  ...           False              True
# 3049          3.80    0.04    44.40  ...           False             False
# 3050          9.98   23.54    71.83  ...            True             False
# 3051         69.69    0.42    68.67  ...            True             False
#
#      TEST SERVER                                   browser_test_url  \
# 0       Winnipeg                       https://performance.cira.ca/
# 1       Winnipeg                       https://performance.cira.ca/
# 2      Vancouver                       https://performance.cira.ca/
# 3       Winnipeg                       https://performance.cira.ca/
# 4       Winnipeg                       https://performance.cira.ca/
# ...          ...                                                ...
# 3047     Toronto                   https://performance.cira.ca/mini
# 3048     Toronto                       https://performance.cira.ca/
# 3049     Toronto                        http://performance.cira.ca/
# 3050     Toronto  https://performance.cira.ca/?utm_campaign=corp...
# 3051     Toronto                   https://performance.cira.ca/mini
#
#      HEATMAP_MUNICIPALITY HEATMAP_CENSUS_TRACTS   TEST DATE TEST TIME  \
# 0                Winnipeg            6020130.02   9/15/2019     16:46
# 1                Winnipeg            6020521.01   9/15/2019     20:08
# 2                Winnipeg            6020500.11   9/16/2019      1:06
# 3                Winnipeg            6020003.00   9/21/2019      4:22
# 4                Winnipeg            6020008.00   9/29/2019     17:56
# ...                   ...                   ...         ...       ...
# 3047             Winnipeg            6020041.00  12/10/2022      5:15
# 3048             Winnipeg            6020510.06  12/10/2022     13:29
# 3049             Winnipeg            6020050.02  12/10/2022     13:38
# 3050             Winnipeg            6020500.13  12/10/2022     17:57
# 3051             Winnipeg            6020553.00  12/10/2022     23:31
#
#       AREA CODE    INTERNET_CATEGORY
# 0           R2K   Low-Speed Internet
# 1           R3R  High-Speed Internet
# 2           R3Y   Low-Speed Internet
# 3           R3M   Low-Speed Internet
# 4           R3N   Low-Speed Internet
# ...         ...                  ...
# 3047        R2W   Low-Speed Internet
# 3048        R3P   Low-Speed Internet
# 3049        R2X   Low-Speed Internet
# 3050        R3Y   Low-Speed Internet
# 3051        R2V   Low-Speed Internet
#
# [3052 rows x 28 columns]

# %% [markdown]
# ### Extract the data for the R2W Area of Winnipeg

# %%
WinnipegArea_R2W_AreaCode = WinnipegArea_InternetCategory[WinnipegArea_InternetCategory['AREA CODE'] == "R2W"]

# %%
WinnipegArea_R2W_AreaCode
# Out:
#         TEST ID  YEAR MONTH DAY  GEO LATITUDE  GEO LONGITUDE  DOWNLOAD SPEED  \
# 14     817329.0  2019    11  27     49.924392     -97.151115          220.82
# 54     829116.0  2020     1   3     49.912529     -97.140032           17.21
# 353    900755.0  2020     5  15     49.920513     -97.126566            9.12
# 364    902174.0  2020     5  16     49.921162     -97.118409           20.49
# 365    902175.0  2020     5  16     49.921162     -97.118409            8.85
# ...         ...   ...   ...  ..           ...            ...             ...
# 3035  1612775.0  2022    12   5     49.919200     -97.126300          167.24
# 3037  1613822.0  2022    12   6     49.919200     -97.126300           97.93
# 3038  1614664.0  2022    12   7     49.919200     -97.126300           10.65
# 3046  1615701.0  2022    12  10     49.919200     -97.126300           59.87
# 3047  1615719.0  2022    12  10     49.919200     -97.126300           40.23
#
#       UPLOAD SPEED  JITTER  LATENCY  ...  IPV6 SUPPORTED  DNSSEC SUPPORTED  \
# 14           15.57    1.70    41.93  ...           False             False
# 54            1.81    0.81    58.25  ...           False             False
# 353           9.21    1.14    45.51  ...           False             False
# 364           3.21   29.59    57.92  ...           False             False
# 365           2.21    0.82    63.00  ...           False             False
# ...            ...     ...      ...  ...             ...               ...
# 3035         15.19    0.69    30.52  ...           False             False
# 3037         10.77    4.39    98.71  ...           False              True
# 3038          0.85    1.08    61.42  ...           False             False
# 3046         87.54    0.88    56.71  ...           False             False
# 3047          4.49    0.18    59.98  ...           False             False
#
#      TEST SERVER                  browser_test_url HEATMAP_MUNICIPALITY  \
# 14      Winnipeg      https://performance.cira.ca/             Winnipeg
# 54      Winnipeg      https://performance.cira.ca/             Winnipeg
# 353     Winnipeg      https://performance.cira.ca/             Winnipeg
# 364     Winnipeg      https://performance.cira.ca/             Winnipeg
# 365     Winnipeg      https://performance.cira.ca/             Winnipeg
# ...          ...                               ...                  ...
# 3035     Toronto  https://performance.cira.ca/mini             Winnipeg
# 3037     Toronto  https://performance.cira.ca/mini             Winnipeg
# 3038     Toronto  https://performance.cira.ca/mini             Winnipeg
# 3046     Toronto  https://performance.cira.ca/mini             Winnipeg
# 3047     Toronto  https://performance.cira.ca/mini             Winnipeg
#
#      HEATMAP_CENSUS_TRACTS   TEST DATE TEST TIME  AREA CODE  \
# 14               6020045.0  11/27/2019     23:24        R2W
# 54               6020034.0    1/3/2020      0:17        R2W
# 353              6020041.0   5/15/2020      1:26        R2W
# 364              6020041.0   5/16/2020      1:10        R2W
# 365              6020041.0   5/16/2020      1:10        R2W
# ...                    ...         ...       ...        ...
# 3035             6020041.0   12/5/2022      7:59        R2W
# 3037             6020041.0   12/6/2022      1:58        R2W
# 3038             6020041.0   12/7/2022     18:38        R2W
# 3046             6020041.0  12/10/2022      3:38        R2W
# 3047             6020041.0  12/10/2022      5:15        R2W
#
#         INTERNET_CATEGORY
# 14    High-Speed Internet
# 54     Low-Speed Internet
# 353    Low-Speed Internet
# 364    Low-Speed Internet
# 365    Low-Speed Internet
# ...                   ...
# 3035   Low-Speed Internet
# 3037   Low-Speed Internet
# 3038   Low-Speed Internet
# 3046   Low-Speed Internet
# 3047   Low-Speed Internet
#
# [118 rows x 28 columns]

# %%
WinnipegArea_R2W_AreaCode.reset_index(inplace = True)

# %%
WinnipegArea_R2W_AreaCode.drop(columns = ['index'], inplace = True)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
WinnipegArea_R2W_AreaCode
# Out:
#        TEST ID  YEAR MONTH DAY  GEO LATITUDE  GEO LONGITUDE  DOWNLOAD SPEED  \
# 0     817329.0  2019    11  27     49.924392     -97.151115          220.82
# 1     829116.0  2020     1   3     49.912529     -97.140032           17.21
# 2     900755.0  2020     5  15     49.920513     -97.126566            9.12
# 3     902174.0  2020     5  16     49.921162     -97.118409           20.49
# 4     902175.0  2020     5  16     49.921162     -97.118409            8.85
# ..         ...   ...   ...  ..           ...            ...             ...
# 113  1612775.0  2022    12   5     49.919200     -97.126300          167.24
# 114  1613822.0  2022    12   6     49.919200     -97.126300           97.93
# 115  1614664.0  2022    12   7     49.919200     -97.126300           10.65
# 116  1615701.0  2022    12  10     49.919200     -97.126300           59.87
# 117  1615719.0  2022    12  10     49.919200     -97.126300           40.23
#
#      UPLOAD SPEED  JITTER  LATENCY  ...  IPV6 SUPPORTED  DNSSEC SUPPORTED  \
# 0           15.57    1.70    41.93  ...           False             False
# 1            1.81    0.81    58.25  ...           False             False
# 2            9.21    1.14    45.51  ...           False             False
# 3            3.21   29.59    57.92  ...           False             False
# 4            2.21    0.82    63.00  ...           False             False
# ..            ...     ...      ...  ...             ...               ...
# 113         15.19    0.69    30.52  ...           False             False
# 114         10.77    4.39    98.71  ...           False              True
# 115          0.85    1.08    61.42  ...           False             False
# 116         87.54    0.88    56.71  ...           False             False
# 117          4.49    0.18    59.98  ...           False             False
#
#     TEST SERVER                  browser_test_url HEATMAP_MUNICIPALITY  \
# 0      Winnipeg      https://performance.cira.ca/             Winnipeg
# 1      Winnipeg      https://performance.cira.ca/             Winnipeg
# 2      Winnipeg      https://performance.cira.ca/             Winnipeg
# 3      Winnipeg      https://performance.cira.ca/             Winnipeg
# 4      Winnipeg      https://performance.cira.ca/             Winnipeg
# ..          ...                               ...                  ...
# 113     Toronto  https://performance.cira.ca/mini             Winnipeg
# 114     Toronto  https://performance.cira.ca/mini             Winnipeg
# 115     Toronto  https://performance.cira.ca/mini             Winnipeg
# 116     Toronto  https://performance.cira.ca/mini             Winnipeg
# 117     Toronto  https://performance.cira.ca/mini             Winnipeg
#
#     HEATMAP_CENSUS_TRACTS   TEST DATE TEST TIME  AREA CODE  \
# 0               6020045.0  11/27/2019     23:24        R2W
# 1               6020034.0    1/3/2020      0:17        R2W
# 2               6020041.0   5/15/2020      1:26        R2W
# 3               6020041.0   5/16/2020      1:10        R2W
# 4               6020041.0   5/16/2020      1:10        R2W
# ..                    ...         ...       ...        ...
# 113             6020041.0   12/5/2022      7:59        R2W
# 114             6020041.0   12/6/2022      1:58        R2W
# 115             6020041.0   12/7/2022     18:38        R2W
# 116             6020041.0  12/10/2022      3:38        R2W
# 117             6020041.0  12/10/2022      5:15        R2W
#
#        INTERNET_CATEGORY
# 0    High-Speed Internet
# 1     Low-Speed Internet
# 2     Low-Speed Internet
# 3     Low-Speed Internet
# 4     Low-Speed Internet
# ..                   ...
# 113   Low-Speed Internet
# 114   Low-Speed Internet
# 115   Low-Speed Internet
# 116   Low-Speed Internet
# 117   Low-Speed Internet
#
# [118 rows x 28 columns]

# %%
# Obtaining / Retrieving the data for ISP and INTERNET CATEGORY in the R2W Area of Winnipeg

WinnipegArea_R2W_AreaISPs = WinnipegArea_R2W_AreaCode[['ISP', 'INTERNET_CATEGORY']].value_counts(sort = False)

# %%
WinnipegArea_R2W_AreaISPs
# Out:
# ISP                       INTERNET_CATEGORY
# ACN                       Low-Speed Internet      1
# Altima Telecom            Low-Speed Internet      2
# Bell Canada               High-Speed Internet     1
#                           Low-Speed Internet     35
# Bell MTS                  Low-Speed Internet      4
# CIK Telecom               Low-Speed Internet      1
# Cipherkey Exchange Corp.  Low-Speed Internet      3
# Cloudflare, Inc.          Low-Speed Internet      1
# Shaw Communications       High-Speed Internet    16
#                           Low-Speed Internet     49
# TekSavvy Solutions, Inc.  High-Speed Internet     1
#                           Low-Speed Internet      4
# dtype: int64

# %%
WinnipegArea_R2W_AreaISPs = WinnipegArea_R2W_AreaCode[['ISP', 'INTERNET_CATEGORY']]

# %%
WinnipegArea_R2W_AreaISPs_cross = pd.crosstab(WinnipegArea_R2W_AreaISPs.ISP, WinnipegArea_R2W_AreaISPs['INTERNET_CATEGORY'])

# %%
WinnipegArea_R2W_AreaISPs_cross
# Out:
# INTERNET_CATEGORY         High-Speed Internet  Low-Speed Internet
# ISP
# ACN                                         0                   1
# Altima Telecom                              0                   2
# Bell Canada                                 1                  35
# Bell MTS                                    0                   4
# CIK Telecom                                 0                   1
# Cipherkey Exchange Corp.                    0                   3
# Cloudflare, Inc.                            0                   1
# Shaw Communications                        16                  49
# TekSavvy Solutions, Inc.                    1                   4

# %%
# Horizontal Bar chart of the Internet Category for each ISP in the R2W area of Winnipeg
# All the Number of ISPs with R2W area of Winnipeg, from 2019 and beyond.

WinnipegArea_R2W_AreaISPs_cross.plot(kind = 'barh')
# Out:
# <AxesSubplot:ylabel='ISP'>

# %%
WinnipegArea_R2W_AreaISPs_cross["High-Speed Internet"]
# Out:
# ISP
# ACN                          0
# Altima Telecom               0
# Bell Canada                  1
# Bell MTS                     0
# CIK Telecom                  0
# Cipherkey Exchange Corp.     0
# Cloudflare, Inc.             0
# Shaw Communications         16
# TekSavvy Solutions, Inc.     1
# Name: High-Speed Internet, dtype: int64

# %%
WinnipegArea_R2W_AreaISPs_cross["Low-Speed Internet"]
# Out:
# ISP
# ACN                          1
# Altima Telecom               2
# Bell Canada                 35
# Bell MTS                     4
# CIK Telecom                  1
# Cipherkey Exchange Corp.     3
# Cloudflare, Inc.             1
# Shaw Communications         49
# TekSavvy Solutions, Inc.     4
# Name: Low-Speed Internet, dtype: int64
