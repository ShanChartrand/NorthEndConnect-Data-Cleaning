# %% [markdown]
# <a href="https://colab.research.google.com/github/ShanChartrand/NorthEndConnect-Data-Cleaning/blob/main/nec_Mar_28_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas
# !pip install wheel
# !pip install numpy
# !pip install shapely
# !pip install fiona
# !pip install pyproj
# !pip install pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
import requests
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (24.0)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.3)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2024.2.2)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.25.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (0.43.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: numpy<2,>=1.14 in /usr/local/lib/python3.10/dist-packages (from shapely) (1.25.2)
# Requirement already satisfied: fiona in /usr/local/lib/python3.10/dist-packages (1.9.6)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona) (2024.2.2)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona) (1.16.0)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.10/dist-packages (3.6.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj) (2024.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/InternetSocietyManitobaChapter/JupyterNotebook_NorthEndConnect/main/nec%20Mar%2028%202024.csv')

# %% [markdown]
# Viewing original number of rows and columns

# %%
# Count the number of rows and columns
num_rows = df.shape[0]
num_columns = df.shape[1]

# Print the results
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 23021
# Number of columns: 31

# %% [markdown]
# Removing rows 2-8064, before metrics such as Jitter, Latency, and Packet loss were reliably measured, and counting the new number of rows

# %%
# Read the CSV file
df = pd.read_csv('https://raw.githubusercontent.com/InternetSocietyManitobaChapter/JupyterNotebook_NorthEndConnect/main/nec%20Mar%2028%202024.csv')

# Remove rows 2 through 8064
df.drop(df.index[1:8064], inplace=True)

# Save the updated DataFrame
df.to_csv('https://raw.githubusercontent.com/InternetSocietyManitobaChapter/JupyterNotebook_NorthEndConnect/main/nec%20Mar%2028%202024.csv', index=False)

# Count the number of rows
num_rows = df.shape[0]

# Print the results
print("Number of rows:", num_rows)
# Out:
# Number of rows: 14958

# %% [markdown]
# Looking at the % of missing items in columns

# %%
# Calculate the percentage of missing cells in each column
missing_percentages = df.isna().sum() / len(df) * 100

# Print the result
print(missing_percentages)
# Out:
# TEST ID                       0.000000
# TEST DATE / UTC HOUR          0.000000
# GEO LATITUDE                  0.000000
# GEO LONGITUDE                 0.000000
# DOWNLOAD SPEED                0.000000
# UPLOAD SPEED                  0.000000
# JITTER                        0.006685
# LATENCY                       0.006685
# PACKET LOSS                   0.006685
# MOBILE TEST                   0.000000
# ISP                           0.000000
# CLIENT IP                     0.000000
# CLIENT CITY                   0.000000
# CLIENT PROVINCE               0.000000
# CLIENT POSTAL CODE            0.000000
# AS NUMBER                     0.006685
# IPV6 SUPPORTED                0.000000
# DNSSEC SUPPORTED              0.000000
# TEST SERVER                   0.000000
# browser_test_url              0.006685
# CONTRACTED DOWNLOAD SPEED    72.850648
# CONTRACTED UPLOAD SPEED      76.868565
# CONTRACTED DATA CAP          84.616927
# CONTRACTED MONTHLY COST      77.343228
# SERVICE TYPE                 71.653964
# USER SATISFACTION            75.197219
# CONNECTION TYPE              81.240808
# USER COMMENTS                66.760262
# HEATMAP_MUNICIPALITY          0.000000
# HEATMAP_CENSUS_TRACTS         0.000000
# HEATMAP_PROJECT_AREA         90.586977
# dtype: float64

# %% [markdown]
# Removing columns with greater than 66% missing values, and then listing the remaining number of rows & columns

# %%
# List of columns to remove
columns_to_remove = [
    'CONTRACTED DOWNLOAD SPEED',
    'CONTRACTED UPLOAD SPEED',
    'CONTRACTED DATA CAP',
    'CONTRACTED MONTHLY COST',
    'SERVICE TYPE',
    'USER SATISFACTION',
    'CONNECTION TYPE',
    'USER COMMENTS',
    'HEATMAP_PROJECT_AREA'
]

# Remove the columns
df.drop(columns=columns_to_remove, inplace=True)

# Save the updated DataFrame
df.to_csv('https://raw.githubusercontent.com/InternetSocietyManitobaChapter/JupyterNotebook_NorthEndConnect/main/nec%20Mar%2028%202024.csv', index=False)

# Count the number of rows and columns
num_rows = df.shape[0]
num_columns = df.shape[1]

# Print the results
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 14958
# Number of columns: 22

# %% [markdown]
# Checking for duplicates in the TEST ID column

# %%
# Count the number of duplicated TEST ID values
num_duplicates = df.duplicated(subset='TEST ID', keep=False).sum()

# Print the number of duplicates
print(f"There are {num_duplicates} rows with duplicated TEST ID values.")
# Out:
# There are 0 rows with duplicated TEST ID values.

# %% [markdown]
# Looking for duplicate rows

# %%
# Find duplicate rows based on all columns
duplicates = df[df.duplicated()]

# Display the duplicate rows (if any)
if len(duplicates) > 0:
    print(f"Found {len(duplicates)} duplicate rows:")
    print(duplicates)
else:
    print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %% [markdown]
# Now that we have removed the columns of missing data, re-checking the % of remaining missing data

# %%
# Calculate the percentage of missing cells in each column
missing_percentages = df.isna().sum() / len(df) * 100

# Print the result
print(missing_percentages)
# Out:
# TEST ID                  0.000000
# TEST DATE / UTC HOUR     0.000000
# GEO LATITUDE             0.000000
# GEO LONGITUDE            0.000000
# DOWNLOAD SPEED           0.000000
# UPLOAD SPEED             0.000000
# JITTER                   0.006685
# LATENCY                  0.006685
# PACKET LOSS              0.006685
# MOBILE TEST              0.000000
# ISP                      0.000000
# CLIENT IP                0.000000
# CLIENT CITY              0.000000
# CLIENT PROVINCE          0.000000
# CLIENT POSTAL CODE       0.000000
# AS NUMBER                0.006685
# IPV6 SUPPORTED           0.000000
# DNSSEC SUPPORTED         0.000000
# TEST SERVER              0.000000
# browser_test_url         0.006685
# HEATMAP_MUNICIPALITY     0.000000
# HEATMAP_CENSUS_TRACTS    0.000000
# dtype: float64

# %% [markdown]
# Removing rows then confirming the % of missing items per column.

# %%
# List of columns to check for missing values
columns_to_check = ['JITTER', 'LATENCY', 'PACKET LOSS', 'AS NUMBER', 'browser_test_url']

# Remove rows with missing values in specified columns
df.dropna(subset=columns_to_check, inplace=True)

# Save the updated DataFrame
df.to_csv('https://raw.githubusercontent.com/InternetSocietyManitobaChapter/JupyterNotebook_NorthEndConnect/main/nec%20Mar%2028%202024.csv', index=False)

# Calculate the percentage of missing cells in each column
missing_percentages = df.isna().sum() / len(df) * 100

# Print the result
print(missing_percentages)
# Out:
# TEST ID                  0.0
# TEST DATE / UTC HOUR     0.0
# GEO LATITUDE             0.0
# GEO LONGITUDE            0.0
# DOWNLOAD SPEED           0.0
# UPLOAD SPEED             0.0
# JITTER                   0.0
# LATENCY                  0.0
# PACKET LOSS              0.0
# MOBILE TEST              0.0
# ISP                      0.0
# CLIENT IP                0.0
# CLIENT CITY              0.0
# CLIENT PROVINCE          0.0
# CLIENT POSTAL CODE       0.0
# AS NUMBER                0.0
# IPV6 SUPPORTED           0.0
# DNSSEC SUPPORTED         0.0
# TEST SERVER              0.0
# browser_test_url         0.0
# HEATMAP_MUNICIPALITY     0.0
# HEATMAP_CENSUS_TRACTS    0.0
# dtype: float64

# %% [markdown]
# We had 14958 rows, let's see how many were removed

# %%
# Count the number of rows
num_rows = df.shape[0]

# Print the results
print("Number of rows:", num_rows)
# Out:
# Number of rows: 14956

# %% [markdown]
# Only 2 rows removed. Skipping standardizing ISP

# %% [markdown]
# Looking at for upload/download speeds of 0 mbps

# %%
# Count the number of cells equal to zero in the 'DOWNLOAD SPEED' column
download_speed_zeros = (df['DOWNLOAD SPEED'] == 0).sum()

# Count the number of cells equal to zero in the 'UPLOAD SPEED' column
upload_speed_zeros = (df['UPLOAD SPEED'] == 0).sum()

# Print the counts
print("Number of cells equal to zero in 'DOWNLOAD SPEED' column:", download_speed_zeros)
print("Number of cells equal to zero in 'UPLOAD SPEED' column:", upload_speed_zeros)
# Out:
# Number of cells equal to zero in 'DOWNLOAD SPEED' column: 0
# Number of cells equal to zero in 'UPLOAD SPEED' column: 7

# %% [markdown]
# I now need to remove the rows that have upload speeds of 0, and then list how many cells = 0 to confirm removal was successful

# %%
# Count the number of cells equal to zero in the 'UPLOAD SPEED' column before removal
upload_speed_zeros_before = (df['UPLOAD SPEED'] == 0).sum()

# Remove rows where UPLOAD SPEED is equal to 0
df = df[df['UPLOAD SPEED'] != 0]

# Count the number of cells equal to zero in the 'UPLOAD SPEED' column after removal
upload_speed_zeros_after = (df['UPLOAD SPEED'] == 0).sum()

# Save the updated DataFrame
df.to_csv('https://raw.githubusercontent.com/InternetSocietyManitobaChapter/JupyterNotebook_NorthEndConnect/main/nec%20Mar%2028%202024.csv', index=False)

# Print the count before and after removal
print("Number of cells equal to zero in 'UPLOAD SPEED' column before removal:", upload_speed_zeros_before)
print("Number of cells equal to zero in 'UPLOAD SPEED' column after removal:", upload_speed_zeros_after)
# Out:
# Number of cells equal to zero in 'UPLOAD SPEED' column before removal: 7
# Number of cells equal to zero in 'UPLOAD SPEED' column after removal: 0

# %% [markdown]
# Standarding the all the sub-categories of Winnipeg to be just "Winnipeg"

# %%
df['CLIENT CITY'] = df['CLIENT CITY'].str.replace('.*Winnipeg.*', 'Winnipeg', regex=True)

# Get the unique client cities
unique_cities = df['CLIENT CITY'].unique()

# Save the updated DataFrame
df.to_csv('https://raw.githubusercontent.com/InternetSocietyManitobaChapter/JupyterNotebook_NorthEndConnect/main/nec%20Mar%2028%202024.csv', index=False)

# Print the unique client cities
for city in unique_cities:
    print(city)
# Out:
# Winnipeg
# Toronto
# Vancouver
# La Salle
# Oakbank
# Marathon
# Cambridge
# Edmonton
# Georgetown
# Port Hope
# Thorold
# Old Toronto
# Blackstock
# Selkirk
# Lindsay
# Charlemagne
# Steinbach
# London
# Etobicoke
# Brandon
# Marchand
# Baie-d'Urfe
# Saint-Quentin
# Stonewall
# Barrie
# Markdale
# Hartland
# Kenora
# Montreal
# Calgary
# Dowling
# Bradford
# Dryden
# Regina
# Thunder Bay
# Sydney
# North York
# Brampton
# Mississauga
# Heritage Pointe
# Cobourg
# Hamilton
# Cooks Creek
# Moose Jaw
# Teulon
# Headingley
# Hague
# Markham
# Chestermere
# Peterborough
# Ottawa
# Cornwall
# Saskatoon
# Virden
# Sault Ste. Marie

# %% [markdown]
# We want to remove any rows where LATENCY >= 30,000 and then list how many rows were removed

# %%
# Count the number of rows before removing
count_before = len(df)

# Remove rows where latency >= 30,000
df = df[df['LATENCY'] < 30000]

# Count the number of rows after removing
count_after = len(df)

# Calculate the count of removed rows
count_removed = count_before - count_after

# Print the count of removed rows
print("Number of removed rows:", count_removed)
# Out:
# Number of removed rows: 1

# %% [markdown]
# Descriptive stats for DOWNLOAD SPEED for Winnipeg

# %%
# Filter the DataFrame to include only rows where CLIENT CITY is Winnipeg
filtered_df = df[df['CLIENT CITY'] == 'Winnipeg']

# Extract the DOWNLOAD SPEED column as a Series
download_speed = df['DOWNLOAD SPEED']

# Calculate the mean and median
mean = download_speed.mean()
median = download_speed.median()

# Calculate other statistical measures
range_val = download_speed.max() - download_speed.min()
std_dev = download_speed.std()
skewness = download_speed.skew()

# Find the minimum and maximum values
min_download_speed = download_speed.min()
max_download_speed = download_speed.max()

# Print the results
print("Min DOWNLOAD SPEED:", min_download_speed)
print("Max DOWNLOAD SPEED:", max_download_speed)
print("Mean DOWNLOAD SPEED:", mean)
print("Median DOWNLOAD SPEED:", median)
print("Range DOWNLOAD SPEED:", range_val)
print("Standard Deviation DOWNLOAD SPEED:", std_dev)
print("Skewness DOWNLOAD SPEED:", skewness)
# Out:
# Min DOWNLOAD SPEED: 0.01
# Max DOWNLOAD SPEED: 1071.58
# Mean DOWNLOAD SPEED: 113.46242641156009
# Median DOWNLOAD SPEED: 65.50999999999999
# Range DOWNLOAD SPEED: 1071.57
# Standard Deviation DOWNLOAD SPEED: 129.87363613804794
# Skewness DOWNLOAD SPEED: 1.8582255603211209

# %% [markdown]
# Descriptive stats for JITTER for Winnipeg

# %%
# Filter the DataFrame to include only rows where CLIENT CITY is Winnipeg
filtered_df = df[df['CLIENT CITY'] == 'Winnipeg']

# Extract the JITTER column as a Series
jitter = df['JITTER']

# Calculate the mean and median
mean = jitter.mean()
median = jitter.median()

# Calculate other statistical measures
range_val = jitter.max() - jitter.min()
std_dev = jitter.std()
skewness = jitter.skew()

# # Find the minimum and maximum values
min_jitter = jitter.min()
max_jitter = jitter.max()

# Print the results
print("Min JITTER:", min_jitter)
print("Max JITTER:", max_jitter)
print("Mean JITTER:", mean)
print("Median JITTER:", median)
print("Range JITTER:", range_val)
print("Standard Deviation JITTER:", std_dev)
print("Skewness JITTER:", skewness)
# Out:
# Min JITTER: 0.01
# Max JITTER: 4368.64
# Mean JITTER: 6.445268932298635
# Median JITTER: 1.84
# Range JITTER: 4368.63
# Standard Deviation JITTER: 45.467535542184905
# Skewness JITTER: 66.23153331326267

# %% [markdown]
# Descriptive stats for LATENCY for Winnipeg

# %%
# Filter the DataFrame to include only rows where CLIENT CITY is Winnipeg
filtered_df = df[df['CLIENT CITY'] == 'Winnipeg']

# Extract the LATENCY column as a Series
latency = df['LATENCY']

# Calculate the mean and median
mean = latency.mean()
median = latency.median()

# Calculate other statistical measures
range_val = latency.max() - latency.min()
std_dev = latency.std()
skewness = latency.skew()

# # Find the minimum and maximum values
min_latency = latency.min()
max_latency = latency.max()

# Print the results
print("Min LATENCY:", min_latency)
print("Max LATENCY:", max_latency)
print("Mean LATENCY:", mean)
print("Median LATENCY:", median)
print("Range LATENCY:", range_val)
print("Standard Deviation LATENCY:", std_dev)
print("Skewness LATENCY:", skewness)
# Out:
# Min LATENCY: 0.07
# Max LATENCY: 1542.32
# Mean LATENCY: 49.454734412630444
# Median LATENCY: 41.99
# Range LATENCY: 1542.25
# Standard Deviation LATENCY: 37.24061383790003
# Skewness LATENCY: 12.83428834482966

# %% [markdown]
# Descriptive stats for PACKET LOSS for Winnipeg

# %%
# Filter the DataFrame to include only rows where CLIENT CITY is Winnipeg
filtered_df = df[df['CLIENT CITY'] == 'Winnipeg']

# Extract the PACKET LOSS column as a Series
packet_loss = df['PACKET LOSS']

# Calculate the mean and median
mean = packet_loss.mean()
median = packet_loss.median()

# Calculate other statistical measures
range_val = packet_loss.max() - packet_loss.min()
std_dev = packet_loss.std()
skewness = packet_loss.skew()

# # Find the minimum and maximum values
min_packet_loss = packet_loss.min()
max_packet_loss = packet_loss.max()

# Print the results
print("Min PACKET LOSS:", min_packet_loss)
print("Max PACKET LOSS:", max_packet_loss)
print("Mean PACKET LOSS:", mean)
print("Median PACKET LOSS:", median)
print("Range PACKET LOSS:", range_val)
print("Standard Deviation PACKET LOSS:", std_dev)
print("Skewness PACKET LOSS:", skewness)
# Out:
# Min PACKET LOSS: 0.0
# Max PACKET LOSS: 47.85
# Mean PACKET LOSS: 2.2082398983141553
# Median PACKET LOSS: 0.08
# Range PACKET LOSS: 47.85
# Standard Deviation PACKET LOSS: 4.4839955131340945
# Skewness PACKET LOSS: 3.224587642165551

# %% [markdown]
# Validating postal codes in Winnipeg against longitude and latitude data

# %%
import re

# Function to validate postal codes and check coordinates
def validate_postal_codes():
    invalid_postal_codes = []
    for index, row in df.iterrows():
        postal_code = row['CLIENT POSTAL CODE']
        city = row['CLIENT CITY']

        if city.lower() == 'winnipeg':
            try:
                # Validate the postal code using a regular expression pattern
                pattern = r'^[A-Za-z]\d[A-Za-z]\s?\d[A-Za-z]\d$'
                is_valid = re.match(pattern, postal_code)

                if not is_valid:
                    invalid_postal_codes.append(postal_code)
                else:
                    # Get the expected coordinates for the postal code
                    expected_latitude, expected_longitude = row['GEO LATITUDE'], row['GEO LONGITUDE']

                    # Check if the coordinates match the expected values
                    if expected_latitude != row['GEO LATITUDE'] or expected_longitude != row['GEO LONGITUDE']:
                        invalid_postal_codes.append(postal_code)
            except Exception as e:
                # Error occurred during validation
                print(f"Error: {str(e)}")

    return invalid_postal_codes

# Check and list the invalid postal codes for Winnipeg
invalid_codes = validate_postal_codes()
if invalid_codes:
    print("Invalid postal codes for Winnipeg:")
    for postal_code in invalid_codes:
        print(postal_code)
else:
    print("All postal codes for Winnipeg are valid.")
# Out:
# Invalid postal codes for Winnipeg:
# None
# None
# None
# None
# R2X2H
# R2N
# R2N
# R2N
# R2N
# R2N
# R2N
# R2N

# %% [markdown]
# Dropping the invalid Postal Code rows

# %%
# Get the indices of rows with invalid postal codes
invalid_indices = df[df['CLIENT POSTAL CODE'].isin(['None', 'R2N', 'R2X2H'])].index

# Drop the rows with invalid postal codes
df.drop(invalid_indices, inplace=True)

# Reset the index of the DataFrame
df.reset_index(drop=True, inplace=True)

# Save the updated DataFrame
df.to_csv('https://raw.githubusercontent.com/InternetSocietyManitobaChapter/JupyterNotebook_NorthEndConnect/main/nec%20Mar%2028%202024.csv', index=False)

# Print the updated DataFrame
print(df)
# Out:
#        TEST ID TEST DATE / UTC HOUR  GEO LATITUDE  GEO LONGITUDE  \
# 0       815901  2019-10-31 11:01:18     49.830394     -97.098467
# 1       816052  2019-11-02 15:17:55     49.913728     -97.048878
# 2       816416  2019-11-05 19:33:49     49.862478     -97.166401
# 3       816624  2019-11-09 21:10:17     49.940894     -97.058845
# 4       817032  2019-11-19 21:19:29     49.853743     -97.289909
# ...        ...                  ...           ...            ...
# 14931  1779544  2024-03-27 22:49:16     49.950949     -97.115035
# 14932  1779546  2024-03-27 22:49:49     49.950949     -97.115035
# 14933  1779551  2024-03-27 23:02:25     49.811667     -97.208319
# 14934  1779623  2024-03-28 02:15:21     49.887321     -97.179755
# 14935  1779641  2024-03-28 04:22:41     49.951400     -97.113300
#
#        DOWNLOAD SPEED  UPLOAD SPEED  JITTER  LATENCY  PACKET LOSS  \
# 0               16.52          5.97    2.16    42.99         0.98
# 1              211.35         14.84    5.18    40.15         0.01
# 2               10.26          1.16   88.78    67.22         0.08
# 3               18.75          1.36    2.86    35.80         0.00
# 4               25.00         24.70    0.63    31.96         0.94
# ...               ...           ...     ...      ...          ...
# 14931           41.90          1.33    0.56    56.14         6.68
# 14932           33.11          4.55    1.38    56.00         1.14
# 14933           26.96          4.38    2.80    55.22         4.65
# 14934           83.67          8.08    0.43     5.65         0.00
# 14935          323.68         24.32    1.91    64.95         0.14
#
#        MOBILE TEST  ... CLIENT CITY CLIENT PROVINCE CLIENT POSTAL CODE  \
# 0            False  ...    Winnipeg              MB             R2M4J2
# 1            False  ...    Winnipeg              MB             R3W0B8
# 2             True  ...    Winnipeg              MB             R3M1L8
# 3            False  ...    Winnipeg              MB             R2G2P7
# 4            False  ...    Winnipeg              MB             R3R1E8
# ...            ...  ...         ...             ...                ...
# 14931         True  ...    Winnipeg              MB             R2V3J2
# 14932         True  ...    Winnipeg              MB             R2V3J2
# 14933        False  ...    Winnipeg              MB             R3Y1L4
# 14934        False  ...    Winnipeg              MB             R3G2R3
# 14935        False  ...    Winnipeg              MB             R2V3J2
#
#       AS NUMBER IPV6 SUPPORTED DNSSEC SUPPORTED  TEST SERVER  \
# 0        AS6327          False            False     Winnipeg
# 1        AS6327          False            False     Winnipeg
# 2        AS7122          False            False     Winnipeg
# 3        AS6327          False            False     Winnipeg
# 4       AS15102          False            False     Winnipeg
# ...         ...            ...              ...          ...
# 14931    AS7122          False            False     Winnipeg
# 14932    AS7122          False            False     Winnipeg
# 14933    AS7122          False            False     Winnipeg
# 14934    AS5645          False             True     Winnipeg
# 14935    AS6327           True            False     Winnipeg
#
#                                         browser_test_url HEATMAP_MUNICIPALITY  \
# 0                           https://performance.cira.ca/             Winnipeg
# 1      https://performance.cira.ca/? ga 2.128939852.1...             Winnipeg
# 2                           https://performance.cira.ca/             Winnipeg
# 3                           https://performance.cira.ca/             Winnipeg
# 4                           https://performance.cira.ca/             Winnipeg
# ...                                                  ...                  ...
# 14931                       https://performance.cira.ca/             Winnipeg
# 14932                       https://performance.cira.ca/             Winnipeg
# 14933                       https://performance.cira.ca/             Winnipeg
# 14934                       https://performance.cira.ca/             Winnipeg
# 14935                   https://performance.cira.ca/mini             Winnipeg
#
#       HEATMAP_CENSUS_TRACTS
# 0                6020102.01
# 1                6020140.05
# 2                6020004.01
# 3                6020142.04
# 4                6020521.01
# ...                     ...
# 14931            6020553.00
# 14932            6020553.00
# 14933            6020500.08
# 14934            6020020.00
# 14935            6020553.00
#
# [14936 rows x 22 columns]

# %% [markdown]
# Extracting the Postal Prefix into it's own column

# %%
# Add a new column "POSTAL PREFIX" containing the first three characters of the postal code
df['POSTAL PREFIX'] = df['CLIENT POSTAL CODE'].str[:3]

# Get the number and names of columns
column_count = len(df.columns)
column_names = df.columns.tolist()

# Print the number and names of columns
print("Number of Columns:", column_count)
print("Column Names:", column_names)

# Get the unique values in the "POSTAL PREFIX" column
unique_values = df['POSTAL PREFIX'].unique()

# Print the unique values
print("Unique Values in 'POSTAL PREFIX' Column:")
for value in unique_values:
    print(value)

# Save the updated DataFrame
df.to_csv('https://raw.githubusercontent.com/InternetSocietyManitobaChapter/JupyterNotebook_NorthEndConnect/main/nec%20Mar%2028%202024.csv', index=False)
# Out:
# Number of Columns: 23
# Column Names: ['TEST ID', 'TEST DATE / UTC HOUR', 'GEO LATITUDE', 'GEO LONGITUDE', 'DOWNLOAD SPEED', 'UPLOAD SPEED', 'JITTER', 'LATENCY', 'PACKET LOSS', 'MOBILE TEST', 'ISP', 'CLIENT IP', 'CLIENT CITY', 'CLIENT PROVINCE', 'CLIENT POSTAL CODE', 'AS NUMBER', 'IPV6 SUPPORTED', 'DNSSEC SUPPORTED', 'TEST SERVER', 'browser_test_url', 'HEATMAP_MUNICIPALITY', 'HEATMAP_CENSUS_TRACTS', 'POSTAL PREFIX']
# Unique Values in 'POSTAL PREFIX' Column:
# R2M
# R3W
# R3M
# R2G
# R3R
# R2V
# R2W
# R2P
# R2N
# R3K
# R2H
# R3J
# R3B
# R3C
# R3P
# R2C
# R2Y
# R3Y
# R3G
# R3N
# R3T
# R3L
# R2J
# R3A
# R3H
# R2K
# R2X
# R2R
# R2L
# R0G
# R3V
# R3X
# R3E
# R5A
# J0S
# R0C

# %% [markdown]
# I need to count the occurence of each postal prefix to make sure there are enough in each to run meaningful analyses

# %%
import pandas as pd

# Assuming your dataset is loaded into a DataFrame called 'df' with a column named 'POSTAL PREFIX'
postal_code_counts = df['POSTAL PREFIX'].value_counts()

print(postal_code_counts)
# Out:
# R2M    2517
# R2W    1408
# R2N    1278
# R3T    1118
# R3J     666
# R3C     665
# R3M     628
# R2V     606
# R3P     568
# R3G     561
# R2C     478
# R3B     465
# R3L     362
# R2Y     315
# R3R     313
# R2R     303
# R2K     298
# R2J     289
# R2G     282
# R2X     238
# R3K     228
# R3Y     206
# R2P     201
# R3X     188
# R3N     187
# R2H     178
# R3V      93
# R3E      89
# R2L      76
# R3W      68
# R3H      44
# R3A      15
# R5A       2
# R0G       1
# J0S       1
# R0C       1
# Name: POSTAL PREFIX, dtype: int64

# %% [markdown]
# Removing any Postal Prefix that is <30, which also happens to account for rural, non-Winnipeg/Manitoba prefixes: R3A, R5A, R0G, J0A & R0C

# %%
import pandas as pd

# Number of rows before deletion
num_rows_before = len(df)

# Filter rows with specific POSTAL PREFIX values
postal_prefix_filter = ['R3A', 'R5A', 'R0G', 'J0S', 'R0C']
df = df[~df['POSTAL PREFIX'].isin(postal_prefix_filter)].copy()

# Reset the index
df.reset_index(drop=True, inplace=True)

# Save the updated DataFrame
df.to_csv('https://raw.githubusercontent.com/InternetSocietyManitobaChapter/JupyterNotebook_NorthEndConnect/main/nec%20Mar%2028%202024.csv', index=False)

# Number of rows after deletion
num_rows_after = len(df)

print("Number of rows before deletion:", num_rows_before)
print("Number of rows after deletion:", num_rows_after)
# Out:
# Number of rows before deletion: 14936
# Number of rows after deletion: 14916

# %% [markdown]
# Removing all the data except Winnipeg data

# %%
# Count the initial number of rows
initial_row_count = len(df)
print("Initial number of rows:", initial_row_count)

# Filter the DataFrame to retain only rows where client city is 'Winnipeg'
df = df[df['CLIENT CITY'].str.strip().str.lower() == 'winnipeg']

# Count the number of rows after filtering
winnipeg_row_count = len(df)
print("Number of rows for Winnipeg:", winnipeg_row_count)

# Save the updated DataFrame
df.to_csv('https://raw.githubusercontent.com/InternetSocietyManitobaChapter/JupyterNotebook_NorthEndConnect/main/nec%20Mar%2028%202024.csv', index=False)
# Out:
# Initial number of rows: 14916
# Number of rows for Winnipeg: 14542

# %% [markdown]
# Listing the unique CLIENT CITY to make sure the deletion worked, and listing the count of CLIENT CITY = Winnipeg versus the number of rows. They should be the same

# %%
# Get the total row count
total_row_count = len(df)
print("Total number of rows:", total_row_count)

# Count the occurrences of 'Winnipeg' in the 'CLIENT CITY' column
winnipeg_count = df[df['CLIENT CITY'].str.strip().str.lower() == 'winnipeg']['CLIENT CITY'].count()

# Print the count of Winnipeg occurrences
print("Number of Winnipeg occurrences:", winnipeg_count)
# Out:
# Total number of rows: 14542
# Number of Winnipeg occurrences: 14542

# %% [markdown]
# Confirming only Winnipeg POSTAL PREFIXES remain

# %%
# Get the unique 'POSTAL PREFIX' values
unique_postal_prefixes = df['POSTAL PREFIX'].unique()

# Count the number of unique 'POSTAL PREFIX' values
unique_postal_prefix_count = len(unique_postal_prefixes)

# Print the list of unique 'POSTAL PREFIX' values
print("Unique POSTAL PREFIX values:")
print(unique_postal_prefixes)

# Print the count of unique 'POSTAL PREFIX' values
print("Number of unique POSTAL PREFIX:", unique_postal_prefix_count)
# Out:
# Unique POSTAL PREFIX values:
# ['R2M' 'R3W' 'R3M' 'R2G' 'R3R' 'R2V' 'R2W' 'R2P' 'R2N' 'R3K' 'R2H' 'R3J'
#  'R3B' 'R3C' 'R3P' 'R2C' 'R2Y' 'R3Y' 'R3G' 'R3N' 'R3T' 'R3L' 'R2J' 'R3H'
#  'R2K' 'R2X' 'R2R' 'R2L' 'R3X' 'R3E' 'R3V']
# Number of unique POSTAL PREFIX: 31

# %% [markdown]
# Out of all the tests taken (in Wpg), I want to see the % that meet the criteria for "High-quality internet" as defined by the CRTC: DOWNLOAD SPEED >= 50 and UPLOAD SPEED >= 10 and LATENCY <= 50 and JITTER <= 5 and PACKET LOSS <= 0.25

# %%
# Filter the DataFrame to retain only rows where client city is 'Winnipeg'
df_winnipeg = df[df['CLIENT CITY'].str.strip().str.lower() == 'winnipeg']

# Count the number of rows in the original DataFrame
total_rows = len(df)

# Filter the Winnipeg DataFrame based on the specified criteria
filtered_df = df_winnipeg[
    (df_winnipeg['DOWNLOAD SPEED'] >= 50) &
    (df_winnipeg['UPLOAD SPEED'] >= 10) &
    (df_winnipeg['LATENCY'] <= 50) &
    (df_winnipeg['JITTER'] <= 5) &
    (df_winnipeg['PACKET LOSS'] <= 0.25)
]

# Count the number of rows that meet the criteria
matching_rows = len(filtered_df)

# Calculate the percentage
percentage = (matching_rows / total_rows) * 100

# Print the percentage of rows that meet the criteria
print("Percentage of rows that meet the criteria:", percentage)
# Out:
# Percentage of rows that meet the criteria: 10.47998899738688

# %% [markdown]
# I want a list of the POSTAL PREFIX that meet that condition

# %%
# Filter the DataFrame to retain only rows where client city is 'Winnipeg'
df_winnipeg = df[df['CLIENT CITY'].str.strip().str.lower() == 'winnipeg']

# Filter the Winnipeg DataFrame based on the specified criteria
filtered_df = df_winnipeg[
    (df_winnipeg['DOWNLOAD SPEED'] >= 50) &
    (df_winnipeg['UPLOAD SPEED'] >= 10) &
    (df_winnipeg['LATENCY'] <= 50) &
    (df_winnipeg['JITTER'] <= 5) &
    (df_winnipeg['PACKET LOSS'] <= 0.25)
]

# Get the unique POSTAL PREFIX values that meet the criteria
postal_prefix_values = filtered_df['POSTAL PREFIX'].unique()

# Count the number of unique POSTAL PREFIX values
count = len(postal_prefix_values)

# Print the unique POSTAL PREFIX values and the count
print("Unique POSTAL PREFIX values that meet the criteria:")
for value in postal_prefix_values:
    print(value)
print("Count:", count)
# Out:
# Unique POSTAL PREFIX values that meet the criteria:
# R2W
# R3K
# R3B
# R3R
# R3C
# R3P
# R2G
# R3T
# R2J
# R3Y
# R2H
# R3L
# R3H
# R3J
# R3G
# R2C
# R2K
# R2V
# R2N
# R3N
# R2P
# R2M
# R2R
# R3M
# R3V
# R2X
# R3X
# R2L
# R2Y
# R3E
# R3W
# Count: 31

# %% [markdown]
# I want to see this on a map

# %%
import pandas as pd
import folium

# Filter the DataFrame based on your criteria
filtered_df = df[
    (df['DOWNLOAD SPEED'] >= 50) &
    (df['UPLOAD SPEED'] >= 10) &
    (df['LATENCY'] <= 50) &
    (df['JITTER'] <= 5) &
    (df['PACKET LOSS'] <= 0.25)
]

# Create a map centered on Winnipeg
map_winnipeg = folium.Map(location=[49.8951, -97.1384], zoom_start=12)

# Iterate over the filtered DataFrame and add markers to the map
for index, row in filtered_df.iterrows():
    lat = row['GEO LATITUDE']
    lon = row['GEO LONGITUDE']
    popup = f"Postal Code: {row['CLIENT POSTAL CODE']}"

    # Add a marker for each location
    folium.Marker([lat, lon], popup=popup).add_to(map_winnipeg)

# Display the map
map_winnipeg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a8fbc8f4b7bc6c9024c3327e9a8df7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a8fbc8f4b7bc6c9024c3327e9a8df7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a8fbc8f4b7bc6c9024c3327e9a8df7c = L.map(
#                 &quot;map_2a8fbc8f4b7bc6c9024c3327e9a8df7c&quot;,
#                 {
#                     center: [49.8951, -97.1384],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23c64e55a9c93c8fd67e666c6ec4b7a0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2a8fbc8f4b7bc6c9024c3327e9a8df7c);
#
#
#             var marker_1caefff618a2aab17953284bd1be32cb = L.marker(
#                 [49.924391877, -97.1511151551],
#                 {}
#             ).addTo(map_2a8fbc8f4b7bc6c9024c3327e9a8df7c);
#
#
#         var popup_a9c28502bff8b0729772559455bf15fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_994c13714e4befc8e9696e343a7a6a6b = $(`&lt;div id=&quot;html_994c13714e4befc8e9696e343a7a6a6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: R2W1R7&lt;/div&gt;`)[0];
#                 popup_a9c28502bff8b0729772559455bf15fd.setContent(html_994c13714e4befc8e9696e343a7a6a6b);
#
#
#
#         marker_1caefff618a2aab17953284bd1be32cb.bindPopup(popup_a9c28502bff8b0729772559455bf15fd)
#         ;
#
#
#
#
#             var marker_f5d8eac42dcbb83a93f3f345c0865a55 = L.marker(
#                 [49.8743342903, -97.29733286],
#                 {}
#             ).addTo(map_2a8fbc8f4b7bc6c9024c3327e9a8df7c);
#
#
#         var popup_bb1685f9d7401b75293f39e5c3c36d03 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c3c17f9f40ad49291da56cdea665bb8 = $(`&lt;div id=&quot;html_1c3c17f9f40ad49291da56cdea665bb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: R3K0N1&lt;/div&gt;`)[0];
#                 popup_bb1685f9d7401b75293f39e5c3c36d03.setContent(html_1c3c17f9f40ad49291da56cdea665bb8);
#
#
#
#         marker_f5d8eac42dcbb83a93f3f345c0865a55.bindPopup(popup_bb1685f9d7401b75293f39e5c3c36d03)
#         ;
#
#
#
#
#             var marker_4c69346777ea376a9d4a714f57a59da0 = L.marker(
#                 [49.8743342903, -97.29733286],
#                 {}
#             ).addTo(map_2a8fbc8f4b7bc6c9024c3327e9a8df7c);
#
#
#         var popup_48a08d404253988ad8eb33caf875c358 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0dbd944734fd1a6936fcbd38b2fc379a = $(`&lt;div id=&quot;html_0dbd944734fd1a6936fcbd38b2fc379a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: R3K0N1&lt;/div&gt;`)[0];
#                 popup_48a08d404253988ad8eb33caf875c358.setContent(html_0dbd944734fd1a6936fcbd38b2fc379a);
#
#
#
#         marker_4c69346777ea376a9d4a714f57a59da0.bindPopup(popup_48a08d404253988ad8eb33caf875c358)
#         ;
#
#
#
#
#             var marker_f6021186794d2ae1694bd985b6240d92 = L.marker(
#                 [49.8743342903, -97.29733286],
#                 {}
#             ).addTo(map_2a8fbc8f4b7bc6c9024c3327e9a8df7c);
#
#
#         var popup_a463ff66bcf965efb45575c8b140247d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d2833e69c2b2750694b062776667e677 = $(`&lt;div id=&quot;html_d2833e69c2b2750694b062776667e677&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: R3K0N1&lt;/div&gt;`)[0];
#                 popup_a463ff66bcf965efb45575c8b140247d.setContent(html_d2833e69c2b2750694b062776667e677);
#
#
#
#         marker_f6021186794d2ae1694bd985b6240d92.bindPopup(popup_a463ff66bcf965efb45575c8b140247d)
#         ;
#
#
#
#
#             var marker_e3852c8cbec2ba529d5969c2c12990d1 = L.marker(
#                 [49.8934886681, -97.1453610703],
#                 {}
#             ).addTo(map_2a8fbc8f4b7bc6c9024c3327e9a8df7c);
#
#
#         var popup_968db4f3d70766785a02d7fbbfa49664 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_145ba1409e89dea476907ef22b947aa3 = $(`&lt;div id=&quot;html_145ba1409e89dea476907ef22b947aa3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: R3B2C3&lt;/div&gt;`)[0];
#                 popup_968db4f3d70766785a02d7fbbfa49664.setContent(html_145ba1409e89dea476907ef22b947aa3);
#
#
#
#         marker_e3852c8cbec2ba529d5969c2c12990d1.bindPopup(popup_968db4f3d70766785a02d7fbbfa49664)
#         ;
#
#
#
#
#             var marker_d32d4ff94144c7f047c599f7fce49e06 = L

# %% [markdown]
# I want to see if the 5 key metrics have signficant differences between POSTAL PREFIXES

# %%
from scipy import stats

# Subset the data for Winnipeg
winnipeg_data = df[df['CLIENT CITY'] == 'Winnipeg']

# Group the data based on POSTAL PREFIX
groups = winnipeg_data.groupby('POSTAL PREFIX')

# Perform ANOVA for each metric
metrics = ['JITTER', 'LATENCY', 'PACKET LOSS', 'UPLOAD SPEED', 'DOWNLOAD SPEED']
for metric in metrics:
    metric_groups = [group[1][metric] for group in groups]
    f_value, p_value = stats.f_oneway(*metric_groups)
    print(f"Metric: {metric}")
    print("F-value:", f_value)
    print("P-value:", p_value)
    print()
# Out:
# Metric: JITTER
# F-value: 3.5968726040862964
# P-value: 1.124850251162627e-10
#
# Metric: LATENCY
# F-value: 39.425079575347446
# P-value: 3.2006308003235357e-220
#
# Metric: PACKET LOSS
# F-value: 54.74306892602817
# P-value: 2.40089561559712e-309
#
# Metric: UPLOAD SPEED
# F-value: 27.284051248382262
# P-value: 2.5563530188809455e-148
#
# Metric: DOWNLOAD SPEED
# F-value: 68.31185057045519
# P-value: 0.0

# %% [markdown]
# These results indicate that the POSTAL PREFIX can be a significant factor in explaining the variations observed in these metrics within the Winnipeg dataset

# %% [markdown]
# Now I want the % of each postal prefix that meet the criteria for high-quality internet in Winnipeg, sorted highest to lowest

# %%
# Step 1: Filter the data that meet the criteria
filtered_data = df[(df['DOWNLOAD SPEED'] >= 50) &
                   (df['UPLOAD SPEED'] >= 10) &
                   (df['LATENCY'] <= 50) &
                   (df['JITTER'] <= 5) &
                   (df['PACKET LOSS'] <= 0.25)]

# Step 2: Calculate the total number of tests that meet the criteria
total_tests = len(filtered_data)

# Step 3: Calculate the number of tests in postal prefix R2W
tests_r2w = len(filtered_data[filtered_data['POSTAL PREFIX'] == 'R2W'])

# Step 4: Calculate the percentage of tests in R2W out of all tests
percentage_r2w = (tests_r2w / total_tests) * 100

print(f"The percentage of tests that meet the criteria and have postal prefix R2W is: {percentage_r2w}%")

# Step 5: Calculate the breakdown by postal prefix
prefix_counts = filtered_data['POSTAL PREFIX'].value_counts()
prefix_percentages = (prefix_counts / total_tests) * 100

# Print the breakdown percentages sorted in descending order
print("Breakdown by Postal Prefix:")
print(prefix_percentages.sort_values(ascending=False))
# Out:
# The percentage of tests that meet the criteria and have postal prefix R2W is: 3.083989501312336%
# Breakdown by Postal Prefix:
# R2M    16.207349
# R3T    11.417323
# R2N     6.561680
# R2R     5.971129
# R3B     5.774278
# R2Y     4.527559
# R2X     4.068241
# R3C     3.543307
# R2W     3.083990
# R3R     2.690289
# R3Y     2.690289
# R3P     2.559055
# R3L     2.427822
# R3M     2.427822
# R2V     2.427822
# R2G     2.165354
# R3G     2.165354
# R2P     2.165354
# R2J     2.165354
# R2C     1.968504
# R2K     1.902887
# R3J     1.771654
# R3K     1.574803
# R2H     1.443570
# R3N     1.312336
# R3X     1.312336
# R3E     1.246719
# R2L     0.853018
# R3V     0.787402
# R3W     0.590551
# R3H     0.196850
# Name: POSTAL PREFIX, dtype: float64

# %% [markdown]
# I am listing the median Upload Speed, Download Speed, Jitter, Latency, and Packet Loss for each Postal Prefix in Winnipeg. US & DS are descending and J, L & PL are ascending

# %%
# Calculate the median metrics for each postal prefix
median_metrics = winnipeg_data.groupby('POSTAL PREFIX')[['UPLOAD SPEED', 'DOWNLOAD SPEED', 'JITTER', 'LATENCY', 'PACKET LOSS']].median(numeric_only=True)

# Sort the median metrics as specified
sorted_upload_speed = median_metrics['UPLOAD SPEED'].sort_values(ascending=False)
sorted_download_speed = median_metrics['DOWNLOAD SPEED'].sort_values(ascending=False)
sorted_jitter = median_metrics['JITTER'].sort_values(ascending=True)
sorted_latency = median_metrics['LATENCY'].sort_values(ascending=True)
sorted_packet_loss = median_metrics['PACKET LOSS'].sort_values(ascending=True)

# Print the sorted median metrics
print("Median UPLOAD SPEED for each POSTAL PREFIX (descending order):")
print(sorted_upload_speed)
print()

print("Median DOWNLOAD SPEED for each POSTAL PREFIX (descending order):")
print(sorted_download_speed)
print()

print("Median JITTER for each POSTAL PREFIX (ascending order):")
print(sorted_jitter)
print()

print("Median LATENCY for each POSTAL PREFIX (ascending order):")
print(sorted_latency)
print()

print("Median PACKET LOSS for each POSTAL PREFIX (ascending order):")
print(sorted_packet_loss)
print()
# Out:
# Median UPLOAD SPEED for each POSTAL PREFIX (descending order):
# POSTAL PREFIX
# R3H    84.200
# R2J    22.195
# R3P    20.030
# R2R    19.800
# R2X    19.465
# R3X    19.430
# R3Y    15.320
# R3W    14.950
# R2L    14.690
# R2W    14.500
# R3M    14.420
# R3E    14.265
# R3T    13.515
# R3R    13.270
# R2P    12.680
# R3N    12.540
# R2Y    11.440
# R3B    11.260
# R2V    10.810
# R2K    10.395
# R3V    10.200
# R2G     9.505
# R3G     8.470
# R2H     7.640
# R3L     7.275
# R2M     6.870
# R3C     6.485
# R2N     5.440
# R3K     4.720
# R2C     4.515
# R3J     2.040
# Name: UPLOAD SPEED, dtype: float64
#
# Median DOWNLOAD SPEED for each POSTAL PREFIX (descending order):
# POSTAL PREFIX
# R3M    173.650
# R2Y    163.590
# R3P    159.470
# R3X    147.990
# R2C    139.210
# R3R    102.525
# R2L     99.880
# R3H     89.255
# R2J     88.340
# R2X     86.605
# R3Y     85.660
# R2R     83.770
# R3E     81.335
# R2W     78.580
# R3B     70.520
# R3T     68.135
# R3L     67.615
# R2V     64.760
# R2M     63.010
# R2P     52.020
# R3V     49.500
# R3N     48.020
# R3G     46.320
# R2G     42.500
# R2N     40.860
# R2K     39.005
# R3W     38.075
# R3K     35.340
# R2H     34.790
# R3C     28.435
# R3J      7.700
# Name: DOWNLOAD SPEED, dtype: float64
#
# Median JITTER for each POSTAL PREFIX (ascending order):
# POSTAL PREFIX
# R3P    0.220
# R3H    0.720
# R3B    0.855
# R2R    0.870
# R2X    1.215
# R2L    1.280
# R2W    1.290
# R3E    1.460
# R3K    1.470
# R3N    1.500
# R2J    1.535
# R3L    1.550
# R3X    1.560
# R2C    1.645
# R3G    1.700
# R3Y    1.720
# R2V    1.720
# R2Y    1.800
# R2P    1.840
# R2G    1.905
# R3C    2.015
# R2H    2.070
# R3J    2.080
# R3R    2.110
# R3T    2.195
# R2K    2.215
# R2N    2.630
# R2M    2.740
# R3W    2.955
# R3V    3.600
# R3M    5.000
# Name: JITTER, dtype: float64
#
# Median LATENCY for each POSTAL PREFIX (ascending order):
# POSTAL PREFIX
# R2R     7.360
# R3H    34.185
# R2C    35.055
# R2X    36.245
# R3Y    36.940
# R3L    37.265
# R3B    37.515
# R2M    38.050
# R3K    38.090
# R3T    38.370
# R3E    38.435
# R3P    39.100
# R2J    39.275
# R2Y    39.470
# R3R    40.465
# R3X    40.930
# R2N    41.210
# R3N    42.790
# R2P    43.720
# R3W    44.795
# R2L    45.320
# R3V    45.820
# R3G    45.970
# R2H    46.760
# R2G    49.070
# R2K    49.230
# R3C    51.095
# R3J    58.770
# R2V    60.320
# R2W    63.230
# R3M    66.500
# Name: LATENCY, dtype: float64
#
# Median PACKET LOSS for each POSTAL PREFIX (ascending order):
# POSTAL PREFIX
# R2M    0.000
# R2N    0.000
# R3M    0.000
# R3K    0.010
# R2Y    0.010
# R3E    0.020
# R3V    0.040
# R2G    0.060
# R2P    0.060
# R3L    0.120
# R3T    0.130
# R3B    0.130
# R3Y    0.150
# R2X    0.170
# R2L    0.190
# R2R    0.200
# R3R    0.245
# R2K    0.265
# R3X    0.320
# R2C    0.350
# R3W    0.380
# R2J    0.430
# R3C    0.465
# R2H    0.510
# R2V    0.550
# R3N    0.570
# R3G    0.790
# R3J    1.650
# R2W    2.900
# R3P    3.220
# R3H    7.210
# Name: PACKET LOSS, dtype: float64

# %% [markdown]
# Seeing which Postal Prefix median metrics all meet the criteria for "high-quality internet"

# %%
# Step 1: Calculate the median metrics for each POSTAL PREFIX
median_metrics = winnipeg_data.groupby('POSTAL PREFIX')[['DOWNLOAD SPEED', 'UPLOAD SPEED', 'LATENCY', 'JITTER', 'PACKET LOSS']].median(numeric_only=True)

# Step 2: Check if any of the median metrics meet the criteria
criteria_met = (median_metrics['DOWNLOAD SPEED'] >= 50) & \
               (median_metrics['UPLOAD SPEED'] >= 10) & \
               (median_metrics['LATENCY'] <= 50) & \
               (median_metrics['JITTER'] <= 5) & \
               (median_metrics['PACKET LOSS'] <= 0.25)

# Step 3: List the POSTAL PREFIX that meet the criteria
postal_prefixes_met_criteria = median_metrics.index[criteria_met].tolist()

print("POSTAL PREFIX that meet the criteria:")
print(postal_prefixes_met_criteria)
# Out:
# POSTAL PREFIX that meet the criteria:
# ['R2L', 'R2P', 'R2R', 'R2X', 'R2Y', 'R3B', 'R3E', 'R3R', 'R3T', 'R3Y']

# %% [markdown]
# Looking to see if there are any statistically significant differences in the 5 key metrics between the POSTAL PREFIX R2W and others, using p < 0.01

# %%
import scipy.stats as stats

# Specify the columns containing the numerical data
columns = ['UPLOAD SPEED', 'DOWNLOAD SPEED', 'JITTER', 'LATENCY', 'PACKET LOSS']

for column_name in columns:
    # Filter the DataFrame for POSTAL PREFIX R2W
    df_R2W = df[df['POSTAL PREFIX'] == 'R2W']

    # Filter the DataFrame for POSTAL PREFIX other than R2W
    df_other = df[df['POSTAL PREFIX'] != 'R2W']

    # Perform the t-test
    t_statistic, p_value = stats.ttest_ind(df_R2W[column_name], df_other[column_name], equal_var=False)

    # Check for statistical significance
    if p_value < 0.01:
        print(f"Metric: {column_name}")
        print(f"t-statistic: {t_statistic}")
        print(f"p-value: {p_value}")
        print("There is a statistically significant difference in {column_name} between R2W and other POSTAL PREFIX values.")
        print()
    else:
        print(f"Metric: {column_name}")
        print(f"t-statistic: {t_statistic}")
        print(f"p-value: {p_value}")
        print("There is no statistically significant difference in {column_name} between R2W and other POSTAL PREFIX values.")
        print()

n1 = len(df_R2W[column_name])
n2 = len(df_other[column_name])

degrees_of_freedom = (n1 + n2) - 2
print("df:",degrees_of_freedom)
# Out:
# Metric: UPLOAD SPEED
# t-statistic: 5.257796601275788
# p-value: 1.6054082109698558e-07
# There is a statistically significant difference in {column_name} between R2W and other POSTAL PREFIX values.
#
# Metric: DOWNLOAD SPEED
# t-statistic: 11.760194035747237
# p-value: 8.955204017684966e-31
# There is a statistically significant difference in {column_name} between R2W and other POSTAL PREFIX values.
#
# Metric: JITTER
# t-statistic: -5.083377880607078
# p-value: 3.982961252586483e-07
# There is a statistically significant difference in {column_name} between R2W and other POSTAL PREFIX values.
#
# Metric: LATENCY
# t-statistic: 14.93118423091376
# p-value: 1.1694866758934898e-48
# There is a statistically significant difference in {column_name} between R2W and other POSTAL PREFIX values.
#
# Metric: PACKET LOSS
# t-statistic: 16.644869142598676
# p-value: 9.522069980990385e-58
# There is a statistically significant difference in {column_name} between R2W and other POSTAL PREFIX values.
#
# df: 14540

# %% [markdown]
# Looking to see if there are any statistically significant differences in the 5 key metrics between the POSTAL PREFIX R2W and others, using p < 0.001 (an even more conservative p-value)

# %%
import scipy.stats as stats

# Specify the columns containing the numerical data
columns = ['UPLOAD SPEED', 'DOWNLOAD SPEED', 'JITTER', 'LATENCY', 'PACKET LOSS']

for column_name in columns:
    # Filter the DataFrame for POSTAL PREFIX R2W
    df_R2W = df[df['POSTAL PREFIX'] == 'R2W']

    # Filter the DataFrame for POSTAL PREFIX other than R2W
    df_other = df[df['POSTAL PREFIX'] != 'R2W']

    # Perform the t-test
    t_statistic, p_value = stats.ttest_ind(df_R2W[column_name], df_other[column_name], equal_var=False)

    # Check for statistical significance
    if p_value < 0.001:
        print(f"Metric: {column_name}")
        print(f"t-statistic: {t_statistic}")
        print(f"p-value: {p_value}")
        print("There is a statistically significant difference in {column_name} between R2W and other POSTAL PREFIX values.")
        print()
    else:
        print(f"Metric: {column_name}")
        print(f"t-statistic: {t_statistic}")
        print(f"p-value: {p_value}")
        print("There is no statistically significant difference in {column_name} between R2W and other POSTAL PREFIX values.")
        print()

n1 = len(df_R2W[column_name])
n2 = len(df_other[column_name])

degrees_of_freedom = (n1 + n2) - 2
print("df:",degrees_of_freedom)
# Out:
# Metric: UPLOAD SPEED
# t-statistic: 5.257796601275788
# p-value: 1.6054082109698558e-07
# There is a statistically significant difference in {column_name} between R2W and other POSTAL PREFIX values.
#
# Metric: DOWNLOAD SPEED
# t-statistic: 11.760194035747237
# p-value: 8.955204017684966e-31
# There is a statistically significant difference in {column_name} between R2W and other POSTAL PREFIX values.
#
# Metric: JITTER
# t-statistic: -5.083377880607078
# p-value: 3.982961252586483e-07
# There is a statistically significant difference in {column_name} between R2W and other POSTAL PREFIX values.
#
# Metric: LATENCY
# t-statistic: 14.93118423091376
# p-value: 1.1694866758934898e-48
# There is a statistically significant difference in {column_name} between R2W and other POSTAL PREFIX values.
#
# Metric: PACKET LOSS
# t-statistic: 16.644869142598676
# p-value: 9.522069980990385e-58
# There is a statistically significant difference in {column_name} between R2W and other POSTAL PREFIX values.
#
# df: 14540

# %% [markdown]
# Looking for statistically significant differences between R2W & each postal prefix specifically for all 5 metrics at p<0.05

# %%
import pandas as pd
import scipy.stats as stats

# Filter the DataFrame for POSTAL PREFIX R2W
df_R2W = df[df['POSTAL PREFIX'] == 'R2W']

# Get the unique POSTAL PREFIX values (excluding R2W)
postal_prefixes = df[df['POSTAL PREFIX'] != 'R2W']['POSTAL PREFIX'].unique()

# Specify the columns containing the numerical data
columns = ['UPLOAD SPEED', 'DOWNLOAD SPEED', 'JITTER', 'LATENCY', 'PACKET LOSS']

# Perform the t-tests for each column
for column in columns:
    print(f"=== {column} ===")
    for prefix in postal_prefixes:
        # Filter the DataFrame for the current prefix
        df_prefix = df[df['POSTAL PREFIX'] == prefix]

        # Perform the t-test
        t_statistic, p_value = stats.mannwhitneyu(df_R2W[column], df_prefix[column], alternative='two-sided')

        # Determine if R2W is significantly larger or smaller
        if p_value < 0.05:
            if column in ['UPLOAD SPEED', 'DOWNLOAD SPEED']:
                if df_R2W[column].median() < df_prefix[column].median():
                    print(f"R2W is significantly slower than {prefix} in terms of {column}")
                else:
                    print(f"R2W is significantly faster than {prefix} in terms of {column}")
            else:
                if df_R2W[column].median() < df_prefix[column].median():
                    print(f"R2W has significantly smaller {column} than {prefix}")
                else:
                    print(f"R2W has significantly larger {column} than {prefix}")
        else:
            print(f"No significant difference between R2W and {prefix} in terms of {column}")
    print()
# Out:
# === UPLOAD SPEED ===
# R2W is significantly faster than R2M in terms of UPLOAD SPEED
# No significant difference between R2W and R3W in terms of UPLOAD SPEED
# No significant difference between R2W and R3M in terms of UPLOAD SPEED
# R2W is significantly faster than R2G in terms of UPLOAD SPEED
# No significant difference between R2W and R3R in terms of UPLOAD SPEED
# R2W is significantly faster than R2V in terms of UPLOAD SPEED
# No significant difference between R2W and R2P in terms of UPLOAD SPEED
# R2W is significantly faster than R2N in terms of UPLOAD SPEED
# R2W is significantly faster than R3K in terms of UPLOAD SPEED
# R2W is significantly faster than R2H in terms of UPLOAD SPEED
# R2W is significantly faster than R3J in terms of UPLOAD SPEED
# No significant difference between R2W and R3B in terms of UPLOAD SPEED
# R2W is significantly faster than R3C in terms of UPLOAD SPEED
# R2W is significantly slower than R3P in terms of UPLOAD SPEED
# R2W is significantly faster than R2C in terms of UPLOAD SPEED
# R2W is significantly faster than R2Y in terms of UPLOAD SPEED
# No significant difference between R2W and R3Y in terms of UPLOAD SPEED
# R2W is significantly faster than R3G in terms of UPLOAD SPEED
# R2W is significantly faster than R3N in terms of UPLOAD SPEED
# R2W is significantly faster than R3T in terms of UPLOAD SPEED
# R2W is significantly faster than R3L in terms of UPLOAD SPEED
# No significant difference between R2W and R2J in terms of UPLOAD SPEED
# R2W is significantly slower than R3H in terms of UPLOAD SPEED
# R2W is significantly faster than R2K in terms of UPLOAD SPEED
# No significant difference between R2W and R2X in terms of UPLOAD SPEED
# R2W is significantly slower than R2R in terms of UPLOAD SPEED
# No significant difference between R2W and R2L in terms of UPLOAD SPEED
# R2W is significantly slower than R3X in terms of UPLOAD SPEED
# No significant difference between R2W and R3E in terms of UPLOAD SPEED
# R2W is significantly faster than R3V in terms of UPLOAD SPEED
#
# === DOWNLOAD SPEED ===
# R2W is significantly faster than R2M in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3W in terms of DOWNLOAD SPEED
# R2W is significantly slower than R3M in terms of DOWNLOAD SPEED
# R2W is significantly faster than R2G in terms of DOWNLOAD SPEED
# R2W is significantly slower than R3R in terms of DOWNLOAD SPEED
# R2W is significantly faster than R2V in terms of DOWNLOAD SPEED
# R2W is significantly faster than R2P in terms of DOWNLOAD SPEED
# R2W is significantly faster than R2N in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3K in terms of DOWNLOAD SPEED
# R2W is significantly faster than R2H in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3J in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3B in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3C in terms of DOWNLOAD SPEED
# R2W is significantly slower than R3P in terms of DOWNLOAD SPEED
# R2W is significantly slower than R2C in terms of DOWNLOAD SPEED
# R2W is significantly slower than R2Y in terms of DOWNLOAD SPEED
# R2W is significantly slower than R3Y in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3G in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3N in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3T in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3L in terms of DOWNLOAD SPEED
# R2W is significantly slower than R2J in terms of DOWNLOAD SPEED
# No significant difference between R2W and R3H in terms of DOWNLOAD SPEED
# R2W is significantly faster than R2K in terms of DOWNLOAD SPEED
# No significant difference between R2W and R2X in terms of DOWNLOAD SPEED
# No significant difference between R2W and R2R in terms of DOWNLOAD SPEED
# No significant difference between R2W and R2L in terms of DOWNLOAD SPEED
# No significant difference between R2W and R3X in terms of DOWNLOAD SPEED
# R2W is significantly slower than R3E in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3V in terms of DOWNLOAD SPEED
#
# === JITTER ===
# R2W has significantly smaller JITTER than R2M
# R2W has significantly smaller JITTER than R3W
# R2W has significantly smaller JITTER than R3M
# R2W has significantly smaller JITTER than R2G
# R2W has significantly smaller JITTER than R3R
# R2W has significantly smaller JITTER than R2V
# R2W has significantly smaller JITTER than R2P
# R2W has significantly smaller JITTER than R2N
# No significant difference between R2W and R3K in terms of JITTER
# R2W has significantly smaller JITTER than R2H
# R2W has significantly smaller JITTER than R3J
# R2W has significantly larger JITTER than R3B
# R2W has significantly smaller JITTER than R3C
# R2W has significantly larger JITTER than R3P
# R2W has significantly smaller JITTER than R2C
# R2W has significantly smaller JITTER than R2Y
# R2W has significantly smaller JITTER than R3Y
# R2W has significantly smaller JITTER than R3G
# R2W has significantly smaller JITTER than R3N
# R2W has significantly smaller JITTER than R3T
# R2W has significantly smaller JITTER than R3L
# R2W has significantly smaller JITTER than R2J
# No significant difference between R2W and R3H in terms of JITTER
# R2W has significantly smaller JITTER than R2K
# No significant difference between R2W and R2X in terms of JITTER
# R2W has significantly larger JITTER than R2R
# No significant difference between R2W and R2L in terms of JITTER
# R2W has significantly smaller JITTER than R3X
# No significant difference between R2W and R3E in terms of JITTER
# R2W has significantly smaller JITTER than R3V
#
# === LATENCY ===
# R2W has significantly larger LATENCY than R2M
# R2W has significantly larger LATENCY than R3W
# R2W has significantly smaller LATENCY than R3M
# R2W has significantly larger LATENCY than R2G
# R2W has significantly larger LATENCY than R3R
# No significant difference between R2W and R2V in terms of LATENCY
# R2W has significantly larger LATENCY than R2P
# R2W has significantly larger LATENCY than R2N
# R2W has significantly larger LATENCY than R3K
# R2W has significantly larger LATENCY than R2H
# R2W has significantly larger LATENCY than R3J
# R2W has significantly larger LATENCY than R3B
# R2W has significantly larger LATENCY than R3C
# R2W has significantly larger LATENCY than R3P
# R2W has significantly larger LATENCY than R2C
# R2W has significantly larger LATENCY than R2Y
# R2W has significantly larger LATENCY than R3Y
# R2W has significantly larger LATENCY than R3G
# R2W has significantly larger LATENCY than R3N
# R2W has significantly larger LATENCY than R3T
# R2W has significantly larger LATENCY than R3L
# R2W has significantly larger LATENCY than R2J
# R2W has significantly larger LATENCY than R3H
# R2W has significantly larger LATENCY than R2K
# R2W has significantly larger LATENCY than R2X
# R2W has significantly larger LATENCY than R2R
# R2W has significantly larger LATENCY than R2L
# R2W has significantly larger LATENCY than R3X
# R2W has significantly larger LATENCY than R3E
# R2W has significantly larger LATENCY than R3V
#
# === PACKET LOSS ===
# R2W has significantly larger PACKET LOSS than R2M
# No significant difference between R2W and R3W in terms of PACKET LOSS
# R2W has significantly larger PACKET LOSS than R3M
# R2W has significantly larger PACKET LOSS than R2G
# R2W has significantly larger PACKET LOSS than R3R
# R2W has significantly larger PACKET LOSS than R2V
# R2W has significantly larger PACKET LOSS than R2P
# R2W has significantly larger PACKET LOSS than R2N
# R2W has significantly larger PACKET LOSS than R3K
# R2W has significantly larger PACKET LOSS than R2H
# No significant difference between R2W and R3J in terms of PACKET LOSS
# R2W has significantly larger PACKET LOSS than R3B
# R2W has significantly larger PACKET LOSS than R3C
# R2W has significantly smaller PACKET LOSS than R3P
# R2W has significantly larger PACKET LOSS than R2C
# R2W has significantly larger PACKET LOSS than R2Y
# R2W has significantly larger PACKET LOSS than R3Y
# R2W has significantly larger PACKET LOSS than R3G
# R2W has significantly larger PACKET LOSS than R3N
# R2W has significantly larger PACKET LOSS than R3T
# R2W has significantly larger PACKET LOSS than R3L
# R2W has significantly larger PACKET LOSS than R2J
# R2W has significantly smaller PACKET LOSS than R3H
# R2W has significantly larger PACKET LOSS than R2K
# R2W has significantly larger PACKET LOSS than R2X
# R2W has significantly larger PACKET LOSS than R2R
# R2W has significantly larger PACKET LOSS than R2L
# R2W has significantly larger PACKET LOSS than R3X
# R2W has significantly larger PACKET LOSS than R3E
# R2W has significantly larger PACKET LOSS than R3V

# %% [markdown]
# Making the tests more conservative, looking for statistically significant differences between R2W & other postal prefixes for all 5 metrics at p<0.01

# %%
import pandas as pd
import scipy.stats as stats

# Filter the DataFrame for POSTAL PREFIX R2W
df_R2W = df[df['POSTAL PREFIX'] == 'R2W']

# Get the unique POSTAL PREFIX values (excluding R2W)
postal_prefixes = df[df['POSTAL PREFIX'] != 'R2W']['POSTAL PREFIX'].unique()

# Specify the columns containing the numerical data
columns = ['UPLOAD SPEED', 'DOWNLOAD SPEED', 'JITTER', 'LATENCY', 'PACKET LOSS']

# Perform the t-tests for each column
for column in columns:
    print(f"=== {column} ===")
    for prefix in postal_prefixes:
        # Filter the DataFrame for the current prefix
        df_prefix = df[df['POSTAL PREFIX'] == prefix]

        # Perform the t-test
        t_statistic, p_value = stats.mannwhitneyu(df_R2W[column], df_prefix[column], alternative='two-sided')

        # Determine if R2W is significantly larger or smaller
        if p_value < 0.01:
            if column in ['UPLOAD SPEED', 'DOWNLOAD SPEED']:
                if df_R2W[column].median() < df_prefix[column].median():
                    print(f"R2W is significantly slower than {prefix} in terms of {column}")
                else:
                    print(f"R2W is significantly faster than {prefix} in terms of {column}")
            else:
                if df_R2W[column].median() < df_prefix[column].median():
                    print(f"R2W has significantly smaller {column} than {prefix}")
                else:
                    print(f"R2W has significantly larger {column} than {prefix}")
        else:
            print(f"No significant difference between R2W and {prefix} in terms of {column}")
    print()
# Out:
# === UPLOAD SPEED ===
# R2W is significantly faster than R2M in terms of UPLOAD SPEED
# No significant difference between R2W and R3W in terms of UPLOAD SPEED
# No significant difference between R2W and R3M in terms of UPLOAD SPEED
# R2W is significantly faster than R2G in terms of UPLOAD SPEED
# No significant difference between R2W and R3R in terms of UPLOAD SPEED
# R2W is significantly faster than R2V in terms of UPLOAD SPEED
# No significant difference between R2W and R2P in terms of UPLOAD SPEED
# R2W is significantly faster than R2N in terms of UPLOAD SPEED
# R2W is significantly faster than R3K in terms of UPLOAD SPEED
# R2W is significantly faster than R2H in terms of UPLOAD SPEED
# R2W is significantly faster than R3J in terms of UPLOAD SPEED
# No significant difference between R2W and R3B in terms of UPLOAD SPEED
# R2W is significantly faster than R3C in terms of UPLOAD SPEED
# R2W is significantly slower than R3P in terms of UPLOAD SPEED
# R2W is significantly faster than R2C in terms of UPLOAD SPEED
# R2W is significantly faster than R2Y in terms of UPLOAD SPEED
# No significant difference between R2W and R3Y in terms of UPLOAD SPEED
# R2W is significantly faster than R3G in terms of UPLOAD SPEED
# R2W is significantly faster than R3N in terms of UPLOAD SPEED
# R2W is significantly faster than R3T in terms of UPLOAD SPEED
# R2W is significantly faster than R3L in terms of UPLOAD SPEED
# No significant difference between R2W and R2J in terms of UPLOAD SPEED
# R2W is significantly slower than R3H in terms of UPLOAD SPEED
# R2W is significantly faster than R2K in terms of UPLOAD SPEED
# No significant difference between R2W and R2X in terms of UPLOAD SPEED
# R2W is significantly slower than R2R in terms of UPLOAD SPEED
# No significant difference between R2W and R2L in terms of UPLOAD SPEED
# R2W is significantly slower than R3X in terms of UPLOAD SPEED
# No significant difference between R2W and R3E in terms of UPLOAD SPEED
# R2W is significantly faster than R3V in terms of UPLOAD SPEED
#
# === DOWNLOAD SPEED ===
# R2W is significantly faster than R2M in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3W in terms of DOWNLOAD SPEED
# R2W is significantly slower than R3M in terms of DOWNLOAD SPEED
# R2W is significantly faster than R2G in terms of DOWNLOAD SPEED
# No significant difference between R2W and R3R in terms of DOWNLOAD SPEED
# R2W is significantly faster than R2V in terms of DOWNLOAD SPEED
# R2W is significantly faster than R2P in terms of DOWNLOAD SPEED
# R2W is significantly faster than R2N in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3K in terms of DOWNLOAD SPEED
# R2W is significantly faster than R2H in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3J in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3B in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3C in terms of DOWNLOAD SPEED
# R2W is significantly slower than R3P in terms of DOWNLOAD SPEED
# No significant difference between R2W and R2C in terms of DOWNLOAD SPEED
# R2W is significantly slower than R2Y in terms of DOWNLOAD SPEED
# No significant difference between R2W and R3Y in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3G in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3N in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3T in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3L in terms of DOWNLOAD SPEED
# R2W is significantly slower than R2J in terms of DOWNLOAD SPEED
# No significant difference between R2W and R3H in terms of DOWNLOAD SPEED
# R2W is significantly faster than R2K in terms of DOWNLOAD SPEED
# No significant difference between R2W and R2X in terms of DOWNLOAD SPEED
# No significant difference between R2W and R2R in terms of DOWNLOAD SPEED
# No significant difference between R2W and R2L in terms of DOWNLOAD SPEED
# No significant difference between R2W and R3X in terms of DOWNLOAD SPEED
# No significant difference between R2W and R3E in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3V in terms of DOWNLOAD SPEED
#
# === JITTER ===
# R2W has significantly smaller JITTER than R2M
# R2W has significantly smaller JITTER than R3W
# R2W has significantly smaller JITTER than R3M
# R2W has significantly smaller JITTER than R2G
# R2W has significantly smaller JITTER than R3R
# R2W has significantly smaller JITTER than R2V
# R2W has significantly smaller JITTER than R2P
# R2W has significantly smaller JITTER than R2N
# No significant difference between R2W and R3K in terms of JITTER
# R2W has significantly smaller JITTER than R2H
# R2W has significantly smaller JITTER than R3J
# R2W has significantly larger JITTER than R3B
# R2W has significantly smaller JITTER than R3C
# R2W has significantly larger JITTER than R3P
# R2W has significantly smaller JITTER than R2C
# R2W has significantly smaller JITTER than R2Y
# R2W has significantly smaller JITTER than R3Y
# R2W has significantly smaller JITTER than R3G
# R2W has significantly smaller JITTER than R3N
# R2W has significantly smaller JITTER than R3T
# R2W has significantly smaller JITTER than R3L
# No significant difference between R2W and R2J in terms of JITTER
# No significant difference between R2W and R3H in terms of JITTER
# R2W has significantly smaller JITTER than R2K
# No significant difference between R2W and R2X in terms of JITTER
# R2W has significantly larger JITTER than R2R
# No significant difference between R2W and R2L in terms of JITTER
# R2W has significantly smaller JITTER than R3X
# No significant difference between R2W and R3E in terms of JITTER
# R2W has significantly smaller JITTER than R3V
#
# === LATENCY ===
# R2W has significantly larger LATENCY than R2M
# No significant difference between R2W and R3W in terms of LATENCY
# R2W has significantly smaller LATENCY than R3M
# R2W has significantly larger LATENCY than R2G
# R2W has significantly larger LATENCY than R3R
# No significant difference between R2W and R2V in terms of LATENCY
# R2W has significantly larger LATENCY than R2P
# R2W has significantly larger LATENCY than R2N
# R2W has significantly larger LATENCY than R3K
# R2W has significantly larger LATENCY than R2H
# R2W has significantly larger LATENCY than R3J
# R2W has significantly larger LATENCY than R3B
# R2W has significantly larger LATENCY than R3C
# R2W has significantly larger LATENCY than R3P
# R2W has significantly larger LATENCY than R2C
# R2W has significantly larger LATENCY than R2Y
# R2W has significantly larger LATENCY than R3Y
# R2W has significantly larger LATENCY than R3G
# R2W has significantly larger LATENCY than R3N
# R2W has significantly larger LATENCY than R3T
# R2W has significantly larger LATENCY than R3L
# R2W has significantly larger LATENCY than R2J
# R2W has significantly larger LATENCY than R3H
# R2W has significantly larger LATENCY than R2K
# R2W has significantly larger LATENCY than R2X
# R2W has significantly larger LATENCY than R2R
# R2W has significantly larger LATENCY than R2L
# R2W has significantly larger LATENCY than R3X
# R2W has significantly larger LATENCY than R3E
# R2W has significantly larger LATENCY than R3V
#
# === PACKET LOSS ===
# R2W has significantly larger PACKET LOSS than R2M
# No significant difference between R2W and R3W in terms of PACKET LOSS
# R2W has significantly larger PACKET LOSS than R3M
# R2W has significantly larger PACKET LOSS than R2G
# R2W has significantly larger PACKET LOSS than R3R
# R2W has significantly larger PACKET LOSS than R2V
# R2W has significantly larger PACKET LOSS than R2P
# R2W has significantly larger PACKET LOSS than R2N
# R2W has significantly larger PACKET LOSS than R3K
# R2W has significantly larger PACKET LOSS than R2H
# No significant difference between R2W and R3J in terms of PACKET LOSS
# R2W has significantly larger PACKET LOSS than R3B
# R2W has significantly larger PACKET LOSS than R3C
# R2W has significantly smaller PACKET LOSS than R3P
# R2W has significantly larger PACKET LOSS than R2C
# R2W has significantly larger PACKET LOSS than R2Y
# R2W has significantly larger PACKET LOSS than R3Y
# R2W has significantly larger PACKET LOSS than R3G
# R2W has significantly larger PACKET LOSS than R3N
# R2W has significantly larger PACKET LOSS than R3T
# R2W has significantly larger PACKET LOSS than R3L
# R2W has significantly larger PACKET LOSS than R2J
# R2W has significantly smaller PACKET LOSS than R3H
# R2W has significantly larger PACKET LOSS than R2K
# R2W has significantly larger PACKET LOSS than R2X
# R2W has significantly larger PACKET LOSS than R2R
# R2W has significantly larger PACKET LOSS than R2L
# R2W has significantly larger PACKET LOSS than R3X
# R2W has significantly larger PACKET LOSS than R3E
# R2W has significantly larger PACKET LOSS than R3V

# %% [markdown]
# Making the tests more conservative, looking for statistically significant differences between R2W & other postal prefixes for all 5 metrics at p<0.001

# %%
import pandas as pd
import scipy.stats as stats

# Filter the DataFrame for POSTAL PREFIX R2W
df_R2W = df[df['POSTAL PREFIX'] == 'R2W']

# Get the unique POSTAL PREFIX values (excluding R2W)
postal_prefixes = df[df['POSTAL PREFIX'] != 'R2W']['POSTAL PREFIX'].unique()

# Specify the columns containing the numerical data
columns = ['UPLOAD SPEED', 'DOWNLOAD SPEED', 'JITTER', 'LATENCY', 'PACKET LOSS']

# Perform the t-tests for each column
for column in columns:
    print(f"=== {column} ===")
    for prefix in postal_prefixes:
        # Filter the DataFrame for the current prefix
        df_prefix = df[df['POSTAL PREFIX'] == prefix]

        # Perform the t-test
        t_statistic, p_value = stats.mannwhitneyu(df_R2W[column], df_prefix[column], alternative='two-sided')

        # Determine if R2W is significantly larger or smaller
        if p_value < 0.001:
            if column in ['UPLOAD SPEED', 'DOWNLOAD SPEED']:
                if df_R2W[column].median() < df_prefix[column].median():
                    print(f"R2W is significantly slower than {prefix} in terms of {column}")
                else:
                    print(f"R2W is significantly faster than {prefix} in terms of {column}")
            else:
                if df_R2W[column].median() < df_prefix[column].median():
                    print(f"R2W has significantly smaller {column} than {prefix}")
                else:
                    print(f"R2W has significantly larger {column} than {prefix}")
        else:
            print(f"No significant difference between R2W and {prefix} in terms of {column}")
    print()
# Out:
# === UPLOAD SPEED ===
# R2W is significantly faster than R2M in terms of UPLOAD SPEED
# No significant difference between R2W and R3W in terms of UPLOAD SPEED
# No significant difference between R2W and R3M in terms of UPLOAD SPEED
# R2W is significantly faster than R2G in terms of UPLOAD SPEED
# No significant difference between R2W and R3R in terms of UPLOAD SPEED
# R2W is significantly faster than R2V in terms of UPLOAD SPEED
# No significant difference between R2W and R2P in terms of UPLOAD SPEED
# R2W is significantly faster than R2N in terms of UPLOAD SPEED
# R2W is significantly faster than R3K in terms of UPLOAD SPEED
# R2W is significantly faster than R2H in terms of UPLOAD SPEED
# R2W is significantly faster than R3J in terms of UPLOAD SPEED
# No significant difference between R2W and R3B in terms of UPLOAD SPEED
# R2W is significantly faster than R3C in terms of UPLOAD SPEED
# R2W is significantly slower than R3P in terms of UPLOAD SPEED
# R2W is significantly faster than R2C in terms of UPLOAD SPEED
# R2W is significantly faster than R2Y in terms of UPLOAD SPEED
# No significant difference between R2W and R3Y in terms of UPLOAD SPEED
# R2W is significantly faster than R3G in terms of UPLOAD SPEED
# R2W is significantly faster than R3N in terms of UPLOAD SPEED
# R2W is significantly faster than R3T in terms of UPLOAD SPEED
# R2W is significantly faster than R3L in terms of UPLOAD SPEED
# No significant difference between R2W and R2J in terms of UPLOAD SPEED
# R2W is significantly slower than R3H in terms of UPLOAD SPEED
# R2W is significantly faster than R2K in terms of UPLOAD SPEED
# No significant difference between R2W and R2X in terms of UPLOAD SPEED
# R2W is significantly slower than R2R in terms of UPLOAD SPEED
# No significant difference between R2W and R2L in terms of UPLOAD SPEED
# R2W is significantly slower than R3X in terms of UPLOAD SPEED
# No significant difference between R2W and R3E in terms of UPLOAD SPEED
# No significant difference between R2W and R3V in terms of UPLOAD SPEED
#
# === DOWNLOAD SPEED ===
# R2W is significantly faster than R2M in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3W in terms of DOWNLOAD SPEED
# No significant difference between R2W and R3M in terms of DOWNLOAD SPEED
# R2W is significantly faster than R2G in terms of DOWNLOAD SPEED
# No significant difference between R2W and R3R in terms of DOWNLOAD SPEED
# R2W is significantly faster than R2V in terms of DOWNLOAD SPEED
# R2W is significantly faster than R2P in terms of DOWNLOAD SPEED
# R2W is significantly faster than R2N in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3K in terms of DOWNLOAD SPEED
# R2W is significantly faster than R2H in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3J in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3B in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3C in terms of DOWNLOAD SPEED
# R2W is significantly slower than R3P in terms of DOWNLOAD SPEED
# No significant difference between R2W and R2C in terms of DOWNLOAD SPEED
# R2W is significantly slower than R2Y in terms of DOWNLOAD SPEED
# No significant difference between R2W and R3Y in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3G in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3N in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3T in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3L in terms of DOWNLOAD SPEED
# No significant difference between R2W and R2J in terms of DOWNLOAD SPEED
# No significant difference between R2W and R3H in terms of DOWNLOAD SPEED
# R2W is significantly faster than R2K in terms of DOWNLOAD SPEED
# No significant difference between R2W and R2X in terms of DOWNLOAD SPEED
# No significant difference between R2W and R2R in terms of DOWNLOAD SPEED
# No significant difference between R2W and R2L in terms of DOWNLOAD SPEED
# No significant difference between R2W and R3X in terms of DOWNLOAD SPEED
# No significant difference between R2W and R3E in terms of DOWNLOAD SPEED
# R2W is significantly faster than R3V in terms of DOWNLOAD SPEED
#
# === JITTER ===
# R2W has significantly smaller JITTER than R2M
# R2W has significantly smaller JITTER than R3W
# R2W has significantly smaller JITTER than R3M
# R2W has significantly smaller JITTER than R2G
# R2W has significantly smaller JITTER than R3R
# R2W has significantly smaller JITTER than R2V
# R2W has significantly smaller JITTER than R2P
# R2W has significantly smaller JITTER than R2N
# No significant difference between R2W and R3K in terms of JITTER
# R2W has significantly smaller JITTER than R2H
# R2W has significantly smaller JITTER than R3J
# R2W has significantly larger JITTER than R3B
# R2W has significantly smaller JITTER than R3C
# R2W has significantly larger JITTER than R3P
# R2W has significantly smaller JITTER than R2C
# R2W has significantly smaller JITTER than R2Y
# R2W has significantly smaller JITTER than R3Y
# R2W has significantly smaller JITTER than R3G
# R2W has significantly smaller JITTER than R3N
# R2W has significantly smaller JITTER than R3T
# R2W has significantly smaller JITTER than R3L
# No significant difference between R2W and R2J in terms of JITTER
# No significant difference between R2W and R3H in terms of JITTER
# R2W has significantly smaller JITTER than R2K
# No significant difference between R2W and R2X in terms of JITTER
# R2W has significantly larger JITTER than R2R
# No significant difference between R2W and R2L in terms of JITTER
# No significant difference between R2W and R3X in terms of JITTER
# No significant difference between R2W and R3E in terms of JITTER
# R2W has significantly smaller JITTER than R3V
#
# === LATENCY ===
# R2W has significantly larger LATENCY than R2M
# No significant difference between R2W and R3W in terms of LATENCY
# R2W has significantly smaller LATENCY than R3M
# R2W has significantly larger LATENCY than R2G
# R2W has significantly larger LATENCY than R3R
# No significant difference between R2W and R2V in terms of LATENCY
# R2W has significantly larger LATENCY than R2P
# R2W has significantly larger LATENCY than R2N
# R2W has significantly larger LATENCY than R3K
# R2W has significantly larger LATENCY than R2H
# R2W has significantly larger LATENCY than R3J
# R2W has significantly larger LATENCY than R3B
# R2W has significantly larger LATENCY than R3C
# R2W has significantly larger LATENCY than R3P
# R2W has significantly larger LATENCY than R2C
# R2W has significantly larger LATENCY than R2Y
# R2W has significantly larger LATENCY than R3Y
# R2W has significantly larger LATENCY than R3G
# R2W has significantly larger LATENCY than R3N
# R2W has significantly larger LATENCY than R3T
# R2W has significantly larger LATENCY than R3L
# R2W has significantly larger LATENCY than R2J
# R2W has significantly larger LATENCY than R3H
# R2W has significantly larger LATENCY than R2K
# R2W has significantly larger LATENCY than R2X
# R2W has significantly larger LATENCY than R2R
# R2W has significantly larger LATENCY than R2L
# R2W has significantly larger LATENCY than R3X
# R2W has significantly larger LATENCY than R3E
# R2W has significantly larger LATENCY than R3V
#
# === PACKET LOSS ===
# R2W has significantly larger PACKET LOSS than R2M
# No significant difference between R2W and R3W in terms of PACKET LOSS
# R2W has significantly larger PACKET LOSS than R3M
# R2W has significantly larger PACKET LOSS than R2G
# R2W has significantly larger PACKET LOSS than R3R
# R2W has significantly larger PACKET LOSS than R2V
# R2W has significantly larger PACKET LOSS than R2P
# R2W has significantly larger PACKET LOSS than R2N
# R2W has significantly larger PACKET LOSS than R3K
# R2W has significantly larger PACKET LOSS than R2H
# No significant difference between R2W and R3J in terms of PACKET LOSS
# R2W has significantly larger PACKET LOSS than R3B
# R2W has significantly larger PACKET LOSS than R3C
# R2W has significantly smaller PACKET LOSS than R3P
# R2W has significantly larger PACKET LOSS than R2C
# R2W has significantly larger PACKET LOSS than R2Y
# R2W has significantly larger PACKET LOSS than R3Y
# R2W has significantly larger PACKET LOSS than R3G
# R2W has significantly larger PACKET LOSS than R3N
# R2W has significantly larger PACKET LOSS than R3T
# R2W has significantly larger PACKET LOSS than R3L
# R2W has significantly larger PACKET LOSS than R2J
# No significant difference between R2W and R3H in terms of PACKET LOSS
# R2W has significantly larger PACKET LOSS than R2K
# R2W has significantly larger PACKET LOSS than R2X
# R2W has significantly larger PACKET LOSS than R2R
# R2W has significantly larger PACKET LOSS than R2L
# R2W has significantly larger PACKET LOSS than R3X
# R2W has significantly larger PACKET LOSS than R3E
# R2W has significantly larger PACKET LOSS than R3V

# %% [markdown]
# Sorting postal prefix from best to worst, where median upload and download speeds are high and median jitter, latency, and packet loss are low.

# %%
import pandas as pd
import scipy.stats as stats

# Get the unique POSTAL PREFIX values in the sample
postal_prefixes = df['POSTAL PREFIX'].unique()

# Specify the columns containing the numerical data
columns = ['UPLOAD SPEED', 'DOWNLOAD SPEED', 'JITTER', 'LATENCY', 'PACKET LOSS']

# Initialize a dictionary to store the median values for each prefix
prefix_medians = {}

# Calculate the median values for each prefix
for prefix in postal_prefixes:
    df_prefix = df[df['POSTAL PREFIX'] == prefix]
    prefix_medians[prefix] = {}
    for column in columns:
        median_value = df_prefix[column].median()
        prefix_medians[prefix][column] = median_value

# Sort the postal prefixes based on the median values
sorted_prefixes = sorted(postal_prefixes, key=lambda x: (
    -prefix_medians[x]['UPLOAD SPEED'],
    -prefix_medians[x]['DOWNLOAD SPEED'],
    prefix_medians[x]['JITTER'],
    prefix_medians[x]['LATENCY'],
    prefix_medians[x]['PACKET LOSS']
))

# Print the sorted list of postal prefixes and their median values
for prefix in sorted_prefixes:
    print(f"Postal Prefix: {prefix}")
    for column in columns:
        median_value = prefix_medians[prefix][column]
        print(f"Median {column}: {median_value}")
    print()
# Out:
# Postal Prefix: R3H
# Median UPLOAD SPEED: 84.19999999999999
# Median DOWNLOAD SPEED: 89.255
# Median JITTER: 0.72
# Median LATENCY: 34.185
# Median PACKET LOSS: 7.21
#
# Postal Prefix: R2J
# Median UPLOAD SPEED: 22.195
# Median DOWNLOAD SPEED: 88.34
# Median JITTER: 1.5350000000000001
# Median LATENCY: 39.275000000000006
# Median PACKET LOSS: 0.43
#
# Postal Prefix: R3P
# Median UPLOAD SPEED: 20.03
# Median DOWNLOAD SPEED: 159.47
# Median JITTER: 0.22
# Median LATENCY: 39.1
# Median PACKET LOSS: 3.22
#
# Postal Prefix: R2R
# Median UPLOAD SPEED: 19.8
# Median DOWNLOAD SPEED: 83.77
# Median JITTER: 0.87
# Median LATENCY: 7.36
# Median PACKET LOSS: 0.2
#
# Postal Prefix: R2X
# Median UPLOAD SPEED: 19.465
# Median DOWNLOAD SPEED: 86.60499999999999
# Median JITTER: 1.2149999999999999
# Median LATENCY: 36.245000000000005
# Median PACKET LOSS: 0.17
#
# Postal Prefix: R3X
# Median UPLOAD SPEED: 19.43
# Median DOWNLOAD SPEED: 147.99
# Median JITTER: 1.56
# Median LATENCY: 40.93
# Median PACKET LOSS: 0.32
#
# Postal Prefix: R3Y
# Median UPLOAD SPEED: 15.32
# Median DOWNLOAD SPEED: 85.66
# Median JITTER: 1.72
# Median LATENCY: 36.94
# Median PACKET LOSS: 0.15
#
# Postal Prefix: R3W
# Median UPLOAD SPEED: 14.95
# Median DOWNLOAD SPEED: 38.075
# Median JITTER: 2.955
# Median LATENCY: 44.795
# Median PACKET LOSS: 0.38
#
# Postal Prefix: R2L
# Median UPLOAD SPEED: 14.69
# Median DOWNLOAD SPEED: 99.88
# Median JITTER: 1.28
# Median LATENCY: 45.32
# Median PACKET LOSS: 0.19
#
# Postal Prefix: R2W
# Median UPLOAD SPEED: 14.5
# Median DOWNLOAD SPEED: 78.58
# Median JITTER: 1.29
# Median LATENCY: 63.23
# Median PACKET LOSS: 2.9
#
# Postal Prefix: R3M
# Median UPLOAD SPEED: 14.42
# Median DOWNLOAD SPEED: 173.65
# Median JITTER: 5.0
# Median LATENCY: 66.5
# Median PACKET LOSS: 0.0
#
# Postal Prefix: R3E
# Median UPLOAD SPEED: 14.265
# Median DOWNLOAD SPEED: 81.33500000000001
# Median JITTER: 1.46
# Median LATENCY: 38.435
# Median PACKET LOSS: 0.02
#
# Postal Prefix: R3T
# Median UPLOAD SPEED: 13.515
# Median DOWNLOAD SPEED: 68.13499999999999
# Median JITTER: 2.1950000000000003
# Median LATENCY: 38.37
# Median PACKET LOSS: 0.13
#
# Postal Prefix: R3R
# Median UPLOAD SPEED: 13.27
# Median DOWNLOAD SPEED: 102.525
# Median JITTER: 2.11
# Median LATENCY: 40.465
# Median PACKET LOSS: 0.245
#
# Postal Prefix: R2P
# Median UPLOAD SPEED: 12.68
# Median DOWNLOAD SPEED: 52.02
# Median JITTER: 1.84
# Median LATENCY: 43.72
# Median PACKET LOSS: 0.06
#
# Postal Prefix: R3N
# Median UPLOAD SPEED: 12.54
# Median DOWNLOAD SPEED: 48.02
# Median JITTER: 1.5
# Median LATENCY: 42.79
# Median PACKET LOSS: 0.57
#
# Postal Prefix: R2Y
# Median UPLOAD SPEED: 11.44
# Median DOWNLOAD SPEED: 163.59
# Median JITTER: 1.8
# Median LATENCY: 39.47
# Median PACKET LOSS: 0.01
#
# Postal Prefix: R3B
# Median UPLOAD SPEED: 11.26
# Median DOWNLOAD SPEED: 70.52
# Median JITTER: 0.855
# Median LATENCY: 37.515
# Median PACKET LOSS: 0.13
#
# Postal Prefix: R2V
# Median UPLOAD SPEED: 10.81
# Median DOWNLOAD SPEED: 64.76
# Median JITTER: 1.72
# Median LATENCY: 60.32
# Median PACKET LOSS: 0.55
#
# Postal Prefix: R2K
# Median UPLOAD SPEED: 10.395
# Median DOWNLOAD SPEED: 39.005
# Median JITTER: 2.215
# Median LATENCY: 49.23
# Median PACKET LOSS: 0.265
#
# Postal Prefix: R3V
# Median UPLOAD SPEED: 10.2
# Median DOWNLOAD SPEED: 49.5
# Median JITTER: 3.6
# Median LATENCY: 45.82
# Median PACKET LOSS: 0.04
#
# Postal Prefix: R2G
# Median UPLOAD SPEED: 9.504999999999999
# Median DOWNLOAD SPEED: 42.5
# Median JITTER: 1.9049999999999998
# Median LATENCY: 49.07
# Median PACKET LOSS: 0.06
#
# Postal Prefix: R3G
# Median UPLOAD SPEED: 8.47
# Median DOWNLOAD SPEED: 46.32
# Median JITTER: 1.7
# Median LATENCY: 45.97
# Median PACKET LOSS: 0.79
#
# Postal Prefix: R2H
# Median UPLOAD SPEED: 7.64
# Median DOWNLOAD SPEED: 34.79
# Median JITTER: 2.07
# Median LATENCY: 46.76
# Median PACKET LOSS: 0.51
#
# Postal Prefix: R3L
# Median UPLOAD SPEED: 7.275
# Median DOWNLOAD SPEED: 67.61500000000001
# Median JITTER: 1.55
# Median LATENCY: 37.265
# Median PACKET LOSS: 0.12
#
# Postal Prefix: R2M
# Median UPLOAD SPEED: 6.87
# Median DOWNLOAD SPEED: 63.01
# Median JITTER: 2.74
# Median LATENCY: 38.05
# Median PACKET LOSS: 0.0
#
# Postal Prefix: R3C
# Median UPLOAD SPEED: 6.484999999999999
# Median DOWNLOAD SPEED: 28.435000000000002
# Median JITTER: 2.0149999999999997
# Median LATENCY: 51.095
# Median PACKET LOSS: 0.46499999999999997
#
# Postal Prefix: R2N
# Median UPLOAD SPEED: 5.44
# Median DOWNLOAD SPEED: 40.86
# Median JITTER: 2.63
# Median LATENCY: 41.21
# Median PACKET LOSS: 0.0
#
# Postal Prefix: R3K
# Median UPLOAD SPEED: 4.72
# Median DOWNLOAD SPEED: 35.34
# Median JITTER: 1.47
# Median LATENCY: 38.09
# Median PACKET LOSS: 0.01
#
# Postal Prefix: R2C
# Median UPLOAD SPEED: 4.515
# Median DOWNLOAD SPEED: 139.20999999999998
# Median JITTER: 1.645
# Median LATENCY: 35.055
# Median PACKET LOSS: 0.35
#
# Postal Prefix: R3J
# Median UPLOAD SPEED: 2.04
# Median DOWNLOAD SPEED: 7.7
# Median JITTER: 2.08
# Median LATENCY: 58.77
# Median PACKET LOSS: 1.65

# %% [markdown]
# R2W is 10/31 when sorted for high median Upload and Download, and low median Jitter, Latency and Packet loss.

# %% [markdown]
# Adding columns for Median values defined by Postal Prefix for each of the 5 metrics

# %%
import pandas as pd

# Get the unique POSTAL PREFIX values in the sample
postal_prefixes = df['POSTAL PREFIX'].unique()

# Initialize new columns for median values
df['MEDIAN UPLOAD'] = 0.0
df['MEDIAN DOWNLOAD'] = 0.0
df['MEDIAN JITTER'] = 0.0
df['MEDIAN PACKET LOSS'] = 0.0
df['MEDIAN LATENCY'] = 0.0

# Calculate and fill the median values for each postal prefix
for prefix in postal_prefixes:
    prefix_data = df[df['POSTAL PREFIX'] == prefix]
    median_upload = prefix_data['UPLOAD SPEED'].median()
    median_download = prefix_data['DOWNLOAD SPEED'].median()
    median_jitter = prefix_data['JITTER'].median()
    median_packet_loss = prefix_data['PACKET LOSS'].median()
    median_latency = prefix_data['LATENCY'].median()
    df.loc[df['POSTAL PREFIX'] == prefix, 'MEDIAN UPLOAD'] = median_upload
    df.loc[df['POSTAL PREFIX'] == prefix, 'MEDIAN DOWNLOAD'] = median_download
    df.loc[df['POSTAL PREFIX'] == prefix, 'MEDIAN JITTER'] = median_jitter
    df.loc[df['POSTAL PREFIX'] == prefix, 'MEDIAN PACKET LOSS'] = median_packet_loss
    df.loc[df['POSTAL PREFIX'] == prefix, 'MEDIAN LATENCY'] = median_latency

# Sort the DataFrame based on the defined criteria
df_sorted = df.sort_values(by=['MEDIAN UPLOAD', 'MEDIAN DOWNLOAD', 'MEDIAN JITTER', 'MEDIAN PACKET LOSS'], ascending=[False, False, True, True])

# Save the sorted DataFrame with the added median columns to a CSV file
df_sorted.to_csv('https://raw.githubusercontent.com/InternetSocietyManitobaChapter/JupyterNotebook_NorthEndConnect/main/nec%20Mar%2028%202024.csv', index=False)

# %% [markdown]
# Confirming it worked properly

# %%
column_names = df.columns.tolist()
print(column_names)
# Out:
# ['TEST ID', 'TEST DATE / UTC HOUR', 'GEO LATITUDE', 'GEO LONGITUDE', 'DOWNLOAD SPEED', 'UPLOAD SPEED', 'JITTER', 'LATENCY', 'PACKET LOSS', 'MOBILE TEST', 'ISP', 'CLIENT IP', 'CLIENT CITY', 'CLIENT PROVINCE', 'CLIENT POSTAL CODE', 'AS NUMBER', 'IPV6 SUPPORTED', 'DNSSEC SUPPORTED', 'TEST SERVER', 'browser_test_url', 'HEATMAP_MUNICIPALITY', 'HEATMAP_CENSUS_TRACTS', 'POSTAL PREFIX', 'MEDIAN UPLOAD', 'MEDIAN DOWNLOAD', 'MEDIAN JITTER', 'MEDIAN PACKET LOSS', 'MEDIAN LATENCY']

# %% [markdown]
# Adding PREFIX AREA column

# %%
# Define the mapping between prefixes and areas
prefix_area_mapping = {
    'R2W': 'North End',
    'R2M': 'St. Vital North',
    'R3W': 'North Kildonan E',
    'R3M': 'Crescentwood Central',
    'R2G': 'North Kildonan N',
    'R3R': 'Assiniboine South',
    'R2V': 'West Kildonan',
    'R2P': 'Old Kildonan',
    'R2N': 'St. Vital SW',
    'R3K': 'St. James SW',
    'R2H': 'St. Boniface NW',
    'R3J': 'St. James SE',
    'R3B': 'Exchange District',
    'R3C': 'Downtown/The Forks',
    'R3P': 'Fort Garry NW / Tuxedo',
    'R2C': 'Transcona',
    'R2Y': 'St. James NW',
    'R3Y': 'Fort Garry W',
    'R3G': 'Minto / St. Mathews / Wolseley',
    'R3N': 'River Heights West',
    'R3T': 'Fort Garry NE',
    'R3L': 'River Heights E',
    'R2J': 'St. Boniface NE',
    'R3A': 'Centennial',
    'R3H': 'St. James NE',
    'R2K': 'East Kildonan',
    'R2X': 'Point Douglas',
    'R2R': 'Inkster West',
    'R2L': 'Elmwood',
    'R3X': 'St. Boniface S / St. Vital SE',
    'R3E': 'Sargent Park / Daniel McIntyre / Inkster SE',
    'R3V': 'Fort Garry S'
}

# Add the new column based on the mapping
df['PREFIX AREA'] = df['POSTAL PREFIX'].map(prefix_area_mapping)

# Get the unique PREFIX AREA values
unique_prefix_areas = df['PREFIX AREA'].unique()

# Save the DataFrame a CSV file
df_sorted.to_csv('https://github.com/ShanChartrand/NorthEndConnect-Data-Cleaning/raw/main/NEC%20Aug%2014.csv', index=False)

# Print the columns and the number of unique PREFIX AREA values
print("Columns:")
print(list(df.columns))
print()
print("Number of unique PREFIX AREA values:", len(unique_prefix_areas))
# Out:
# Columns:
# ['TEST ID', 'TEST DATE / UTC HOUR', 'GEO LATITUDE', 'GEO LONGITUDE', 'DOWNLOAD SPEED', 'UPLOAD SPEED', 'JITTER', 'LATENCY', 'PACKET LOSS', 'MOBILE TEST', 'ISP', 'CLIENT IP', 'CLIENT CITY', 'CLIENT PROVINCE', 'CLIENT POSTAL CODE', 'AS NUMBER', 'IPV6 SUPPORTED', 'DNSSEC SUPPORTED', 'TEST SERVER', 'browser_test_url', 'HEATMAP_MUNICIPALITY', 'HEATMAP_CENSUS_TRACTS', 'POSTAL PREFIX', 'MEDIAN UPLOAD', 'MEDIAN DOWNLOAD', 'MEDIAN JITTER', 'MEDIAN PACKET LOSS', 'MEDIAN LATENCY', 'PREFIX AREA']
#
# Number of unique PREFIX AREA values: 31

# %%
print(df_sorted.columns)
# Out:
# Index(['TEST ID', 'TEST DATE / UTC HOUR', 'GEO LATITUDE', 'GEO LONGITUDE',
#        'DOWNLOAD SPEED', 'UPLOAD SPEED', 'JITTER', 'LATENCY', 'PACKET LOSS',
#        'MOBILE TEST', 'ISP', 'CLIENT IP', 'CLIENT CITY', 'CLIENT PROVINCE',
#        'CLIENT POSTAL CODE', 'AS NUMBER', 'IPV6 SUPPORTED', 'DNSSEC SUPPORTED',
#        'TEST SERVER', 'browser_test_url', 'HEATMAP_MUNICIPALITY',
#        'HEATMAP_CENSUS_TRACTS', 'POSTAL PREFIX', 'MEDIAN UPLOAD',
#        'MEDIAN DOWNLOAD', 'MEDIAN JITTER', 'MEDIAN PACKET LOSS',
#        'MEDIAN LATENCY'],
#       dtype='object')

# %%
# Add the new column based on the mapping
df_sorted['PREFIX AREA'] = df_sorted['POSTAL PREFIX'].map(prefix_area_mapping)

# Print the columns and the number of unique PREFIX AREA values
print("Columns:")
print(list(df_sorted.columns))
print()
print("Number of unique PREFIX AREA values:", len(df_sorted['PREFIX AREA'].unique()))
# Out:
# Columns:
# ['TEST ID', 'TEST DATE / UTC HOUR', 'GEO LATITUDE', 'GEO LONGITUDE', 'DOWNLOAD SPEED', 'UPLOAD SPEED', 'JITTER', 'LATENCY', 'PACKET LOSS', 'MOBILE TEST', 'ISP', 'CLIENT IP', 'CLIENT CITY', 'CLIENT PROVINCE', 'CLIENT POSTAL CODE', 'AS NUMBER', 'IPV6 SUPPORTED', 'DNSSEC SUPPORTED', 'TEST SERVER', 'browser_test_url', 'HEATMAP_MUNICIPALITY', 'HEATMAP_CENSUS_TRACTS', 'POSTAL PREFIX', 'MEDIAN UPLOAD', 'MEDIAN DOWNLOAD', 'MEDIAN JITTER', 'MEDIAN PACKET LOSS', 'MEDIAN LATENCY', 'PREFIX AREA']
#
# Number of unique PREFIX AREA values: 31

# %% [markdown]
# Significant differences between R2W and each of the following postal prefixes in Median Upload Speed in a bar chart. R2W is signifcantly faster or slower than these prefixes. Insignificant results were excluded

# %%
import matplotlib.pyplot as plt

# Select the desired postal prefixes for the bar chart
selected_prefixes = ['R2W', 'R2V', 'R2N', 'R3J', 'R2C', 'R3L', 'R2M', 'R3W', 'R2G', 'R3R', 'R2H', 'R3B', 'R3C', 'R3P', 'R3Y', 'R3G', 'R2J', 'R2X', 'R3X', 'R3H']

# Filter the DataFrame for the selected postal prefixes
df_selected = df[df['POSTAL PREFIX'].isin(selected_prefixes)]

# Sort the DataFrame by median upload speed in ascending order
df_selected_sorted = df_selected.sort_values('MEDIAN UPLOAD')

# Set the colors for the bars
colors = ['red' if prefix == 'R2W' else 'blue' for prefix in df_selected_sorted['POSTAL PREFIX']]

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(df_selected_sorted['POSTAL PREFIX'], df_selected_sorted['MEDIAN UPLOAD'], color=colors)
plt.xlabel('Postal Prefix')
plt.ylabel('Median Upload Speed (Mbps)')
plt.title('Significant Differences in Median Upload Speed Relative to R2W')
plt.xticks(rotation=45, ha='right')

# Adjust the y-axis limit
plt.ylim(0.0, 20.0)

# Show the plot
plt.show()

# %% [markdown]
# Bar chart highlighting significant differences in median Download Speed relative to R2W (other prefixes are significantly faster or slower)

# %%
import matplotlib.pyplot as plt

# Select the desired postal prefixes for the bar chart
selected_prefixes = ['R2W', 'R2M', 'R3M', 'R3P', 'R2C', 'R2Y', 'R3T', 'R3L', 'R2R', 'R3W', 'R2G', 'R2V', 'R2P', 'R2N', 'R2H', 'R3J', 'R3C', 'R3G', 'R3N', 'R2K', 'R3V']

# Filter the DataFrame for the selected postal prefixes
df_selected = df[df['POSTAL PREFIX'].isin(selected_prefixes)]

# Sort the DataFrame by median download speed in ascending order
df_selected_sorted = df_selected.sort_values('MEDIAN DOWNLOAD')

# Set the colors for the bars
colors = ['red' if prefix == 'R2W' else 'blue' for prefix in df_selected_sorted['POSTAL PREFIX']]

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(df_selected_sorted['POSTAL PREFIX'], df_selected_sorted['MEDIAN DOWNLOAD'], color=colors)
plt.xlabel('Postal Prefix')
plt.ylabel('Median Download Speed (Mbps)')
plt.title('Significant Differences in Median Download Speed Relative to R2W')
plt.xticks(rotation=45, ha='right')

# Adjust the y-axis limit
plt.ylim(0.0, 100)

# Show the plot
plt.show()

# %% [markdown]
# Need a Prefix Area Legend

# %%
import matplotlib.pyplot as plt

# Get the unique postal prefixes and prefix areas from your dataset
unique_prefixes = df['POSTAL PREFIX'].unique()
prefix_areas = df['PREFIX AREA'].unique()

# Create a color map for the postal prefixes
color_map = ['red' if prefix == 'R2W' else 'blue' for prefix in unique_prefixes]

# Create a legend handles list with color patches
legend_handles = [plt.Rectangle((0, 0), 1, 1, color=color) for color in color_map]

# Create a legend labels list with prefix and prefix area
legend_labels = [f'{prefix} {area}' for prefix, area in zip(unique_prefixes, prefix_areas)]

# Create the legend on the side
plt.legend(legend_handles, legend_labels, loc='center left', bbox_to_anchor=(1, 0.5))

# Show or save the plot
plt.show()

# %% [markdown]
# Bar chart for sig. differences in median jitter relative to R2W

# %%
import matplotlib.pyplot as plt

# Select the desired postal prefixes for the bar chart
selected_prefixes = ['R2W', 'R2M', 'R3W', 'R3M', 'R2G', 'R3R', 'R2V', 'R2P', 'R2N', 'R3K', 'R2H', 'R3J', 'R3B', 'R3C', 'R3P', 'R2C', 'R2Y', 'R3Y', 'R3G', 'R3N', 'R3T', 'R3L', 'R2J', 'R2K', 'R2X', 'R2L', 'R3X', 'R3E', 'R3V']

# Filter the DataFrame for the selected postal prefixes
df_selected = df[df['POSTAL PREFIX'].isin(selected_prefixes)]

# Sort the DataFrame by median jitter in descending order
df_selected_sorted = df_selected.sort_values('MEDIAN JITTER', ascending=False)

# Set the colors for the bars
colors = ['red' if prefix == 'R2W' else 'blue' for prefix in df_selected_sorted['POSTAL PREFIX']]

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(df_selected_sorted['POSTAL PREFIX'], df_selected_sorted['MEDIAN JITTER'], color=colors)
plt.xlabel('Postal Prefix')
plt.ylabel('Median Jitter (ms)')
plt.title('Significant Difference in Median Jitter Relative to R2W')
plt.xticks(rotation=45, ha='right')

# Show or save the plot
plt.show()

# %% [markdown]
# Bar chart for sig. differences in median latency relative to R2W

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Select the desired postal prefixes for the bar chart
selected_prefixes = ['R2W', 'R2M', 'R3M', 'R3R', 'R2P', 'R2N', 'R3K', 'R2H', 'R3J', 'R3B', 'R3P', 'R2C', 'R2Y', 'R3Y', 'R3G', 'R3N', 'R3T', 'R3L', 'R2J', 'R3H', 'R2X', 'R2R', 'R3X', 'R3V']

# Filter the DataFrame for the selected postal prefixes
df_selected = df[df['POSTAL PREFIX'].isin(selected_prefixes)]

# Sort the DataFrame by median latency in descending order
df_selected_sorted = df_selected.sort_values('MEDIAN LATENCY', ascending=False)

# Set the colors for the bars
colors = ['red' if prefix == 'R2W' else 'blue' for prefix in df_selected_sorted['POSTAL PREFIX']]

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(df_selected_sorted['POSTAL PREFIX'], df_selected_sorted['MEDIAN LATENCY'], color=colors)
plt.xlabel('Postal Prefix')
plt.ylabel('Median Latency (ms)')
plt.title('Significant Difference in Median Latency Relative to R2W')
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.show()

# %% [markdown]
# Bar chart for sig. differences in median PACKET LOSS relative to R2W

# %%
# Select the desired postal prefixes for the bar chart
selected_prefixes = ['R2W', 'R2M', 'R3M', 'R2G', 'R3R', 'R2V', 'R2P', 'R2N', 'R3K', 'R2H', 'R3J', 'R3B', 'R3C', 'R3P', 'R2C', 'R2Y', 'R3Y', 'R3G', 'R3N', 'R3T', 'R3L', 'R2J', 'R2K', 'R2X', 'R2R', 'R2L', 'R3X', 'R3E', 'R3V']

# Filter the DataFrame for the selected postal prefixes
df_selected = df[df['POSTAL PREFIX'].isin(selected_prefixes)]

# Sort the DataFrame by median packet loss in descending order
df_selected_sorted = df_selected.sort_values('MEDIAN PACKET LOSS', ascending=False)

# Set the colors for the bars
colors = ['red' if prefix == 'R2W' else 'blue' for prefix in df_selected_sorted['POSTAL PREFIX']]

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(df_selected_sorted['POSTAL PREFIX'], df_selected_sorted['MEDIAN PACKET LOSS'], color=colors)
plt.xlabel('Postal Prefix')
plt.ylabel('Median Packet Loss')
plt.title('Significant Difference in Median Packet Loss Relative to R2W')
plt.xticks(rotation=45, ha='right')

# Add the unit of measurement
plt.ylabel('Median Packet Loss (%)')

# Adjust the y-axis limit
plt.ylim(0, 4)

# Show the plot
plt.show()
